# %%
python -m spacy download en
# Out:
#   File "/tmp/ipykernel_70796/3004318277.py", line 1
#     python -m spacy download en
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
pip install neuralcoref
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting neuralcoref
#   Using cached neuralcoref-4.0.tar.gz (368 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.15.0 in /home/becode/.local/lib/python3.10/site-packages (from neuralcoref) (1.22.0)
# Requirement already satisfied: boto3 in /home/becode/.local/lib/python3.10/site-packages (from neuralcoref) (1.20.39)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/becode/.local/lib/python3.10/site-packages (from neuralcoref) (2.26.0)
# Requirement already satisfied: spacy>=2.1.0 in /home/becode/.local/lib/python3.10/site-packages (from neuralcoref) (3.2.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/becode/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/becode/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/becode/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/becode/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (3.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (1.8.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (0.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (1.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (2.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (21.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (8.0.13)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (4.62.3)
# Requirement already satisfied: jinja2 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (3.0.3)
# Requirement already satisfied: pathy>=0.3.5 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (0.6.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (0.7.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (1.0.1)
# Requirement already satisfied: setuptools in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (60.2.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (0.9.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (3.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/becode/.local/lib/python3.10/site-packages (from spacy>=2.1.0->neuralcoref) (2.0.6)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/becode/.local/lib/python3.10/site-packages (from boto3->neuralcoref) (0.5.0)
# Requirement already satisfied: botocore<1.24.0,>=1.23.39 in /home/becode/.local/lib/python3.10/site-packages (from boto3->neuralcoref) (1.23.39)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/becode/.local/lib/python3.10/site-packages (from boto3->neuralcoref) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/becode/.local/lib/python3.10/site-packages (from botocore<1.24.0,>=1.23.39->boto3->neuralcoref) (2.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/becode/.local/lib/python3.10/site-packages (from packaging>=20.0->spacy>=2.1.0->neuralcoref) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/becode/.local/lib/python3.10/site-packages (from pathy>=0.3.5->spacy>=2.1.0->neuralcoref) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/becode/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy>=2.1.0->neuralcoref) (4.0.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/becode/.local/lib/python3.10/site-packages (from typer<0.5.0,>=0.3.0->spacy>=2.1.0->neuralcoref) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/becode/.local/lib/python3.10/site-packages (from jinja2->spacy>=2.1.0->neuralcoref) (2.0.1)
# Requirement already satisfied: six>=1.5 in /home/becode/.local/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.24.0,>=1.23.39->boto3->neuralcoref) (1.16.0)
# Building wheels for collected packages: neuralcoref
#   Building wheel for neuralcoref (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /usr/local/bin/python3.10 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-xnaf_cv_/neuralcoref_aaf56b26404e4e219cb4ad81d355b09b/setup.py'"'"'; __file__='"'"'/tmp/pip-install-xnaf_cv_/neuralcoref_aaf56b26404e4e219cb4ad81d355b09b/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-vnpcxlse
#        cwd: /tmp/pip-install-xnaf_cv_/neuralcoref_aaf56b26404e4e219cb4ad81d355b09b/
#   Complete output (457 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.10
#   creating build/lib.linux-x86_64-3.10/neuralcoref
#   copying neuralcoref/file_utils.py -> build/lib.linux-x86_64-3.10/neuralcoref
#   copying neuralcoref/__init__.py -> build/lib.linux-x86_64-3.10/neuralcoref
#   creating build/lib.linux-x86_64-3.10/neuralcoref/tests
#   copying neuralcoref/tests/test_neuralcoref.py -> build/lib.linux-x86_64-3.10/neuralcoref/tests
#   copying neuralcoref/tests/__init__.py -> build/lib.linux-x86_64-3.10/neuralcoref/tests
#   creating build/lib.linux-x86_64-3.10/neuralcoref/train
#   copying neuralcoref/train/document.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
#   copying neuralcoref/train/compat.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
#   copying neuralcoref/train/learn.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
#   copying neuralcoref/train/algorithm.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
#   copying neuralcoref/train/utils.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
#   copying neuralcoref/train/dataset.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
#   copying neuralcoref/train/model.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
#   copying neuralcoref/train/__init__.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
#   copying neuralcoref/train/conllparser.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
#   copying neuralcoref/train/evaluator.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
#   running build_ext
#   creating build/temp.linux-x86_64-3.10
#   creating build/temp.linux-x86_64-3.10/neuralcoref
#   gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC -I/usr/local/include/python3.10 -I/tmp/pip-install-xnaf_cv_/neuralcoref_aaf56b26404e4e219cb4ad81d355b09b/include -I/usr/local/include/python3.10 -c neuralcoref/neuralcoref.cpp -o build/temp.linux-x86_64-3.10/neuralcoref/neuralcoref.o -O2 -Wno-strict-prototypes -Wno-unused-function
#   cc1plus: warning: command line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#   In file included from /tmp/pip-install-xnaf_cv_/neuralcoref_aaf56b26404e4e219cb4ad81d355b09b/include/numpy/ndarraytypes.h:1728,
#                    from /tmp/pip-install-xnaf_cv_/neuralcoref_aaf56b26404e4e219cb4ad81d355b09b/include/numpy/ndarrayobject.h:17,
#                    from /tmp/pip-install-xnaf_cv_/neuralcoref_aaf56b26404e4e219cb4ad81d355b09b/include/numpy/arrayobject.h:15,
#                    from neuralcoref/neuralcoref.cpp:607:
#   /tmp/pip-install-xnaf_cv_/neuralcoref_aaf56b26404e4e219cb4ad81d355b09b/include/numpy/npy_deprecated_api.h:11:2: warning: #warning "Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#      11 | #warning "Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION"
#         |  ^~~~~~~
#   neuralcoref/neuralcoref.cpp: In function ‘__pyx_ctuple_int__and_int __pyx_f_11neuralcoref_11neuralcoref_enlarge_span(__pyx_t_5spacy_7structs_TokenC*, int, int, int, int, __pyx_t_11neuralcoref_11neuralcoref_HashesList)’:
#   neuralcoref/neuralcoref.cpp:8989:40: warning: comparison of integer expressions of different signedness: ‘uint32_t’ {aka ‘unsigned int’} and ‘int’ [-Wsign-compare]
#    8989 |     __pyx_t_5 = ((__pyx_v_maxchild_idx > __pyx_v_sent_start) != 0);
#         |                   ~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:9046:40: warning: comparison of integer expressions of different signedness: ‘uint32_t’ {aka ‘unsigned int’} and ‘int’ [-Wsign-compare]
#    9046 |     __pyx_t_5 = ((__pyx_v_minchild_idx < (__pyx_v_sent_end - 1)) != 0);
#         |                   ~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~
#   In file included from /usr/local/include/python3.10/Python.h:87,
#                    from neuralcoref/neuralcoref.cpp:4:
#   neuralcoref/neuralcoref.cpp: In function ‘void __pyx_tp_dealloc_array(PyObject*)’:
#   /usr/local/include/python3.10/object.h:133:58: error: lvalue required as increment operand
#     133 | #define Py_REFCNT(ob) _Py_REFCNT(_PyObject_CAST_CONST(ob))
#         |                                                          ^
#   neuralcoref/neuralcoref.cpp:47321:7: note: in expansion of macro ‘Py_REFCNT’
#   47321 |     ++Py_REFCNT(o);
#         |       ^~~~~~~~~
#   /usr/local/include/python3.10/object.h:133:58: error: lvalue required as decrement operand
#     133 | #define Py_REFCNT(ob) _Py_REFCNT(_PyObject_CAST_CONST(ob))
#         |                                                          ^
#   neuralcoref/neuralcoref.cpp:47323:7: note: in expansion of macro ‘Py_REFCNT’
#   47323 |     --Py_REFCNT(o);
#         |       ^~~~~~~~~
#   neuralcoref/neuralcoref.cpp: In function ‘void __pyx_tp_dealloc_memoryview(PyObject*)’:
#   /usr/local/include/python3.10/object.h:133:58: error: lvalue required as increment operand
#     133 | #define Py_REFCNT(ob) _Py_REFCNT(_PyObject_CAST_CONST(ob))
#         |                                                          ^
#   neuralcoref/neuralcoref.cpp:47610:7: note: in expansion of macro ‘Py_REFCNT’
#   47610 |     ++Py_REFCNT(o);
#         |       ^~~~~~~~~
#   /usr/local/include/python3.10/object.h:133:58: error: lvalue required as decrement operand
#     133 | #define Py_REFCNT(ob) _Py_REFCNT(_PyObject_CAST_CONST(ob))
#         |                                                          ^
#   neuralcoref/neuralcoref.cpp:47612:7: note: in expansion of macro ‘Py_REFCNT’
#   47612 |     --Py_REFCNT(o);
#         |       ^~~~~~~~~
#   neuralcoref/neuralcoref.cpp: In function ‘void __pyx_tp_dealloc__memoryviewslice(PyObject*)’:
#   /usr/local/include/python3.10/object.h:133:58: error: lvalue required as increment operand
#     133 | #define Py_REFCNT(ob) _Py_REFCNT(_PyObject_CAST_CONST(ob))
#         |                                                          ^
#   neuralcoref/neuralcoref.cpp:47849:7: note: in expansion of macro ‘Py_REFCNT’
#   47849 |     ++Py_REFCNT(o);
#         |       ^~~~~~~~~
#   /usr/local/include/python3.10/object.h:133:58: error: lvalue required as decrement operand
#     133 | #define Py_REFCNT(ob) _Py_REFCNT(_PyObject_CAST_CONST(ob))
#         |                                                          ^
#   neuralcoref/neuralcoref.cpp:47851:7: note: in expansion of macro ‘Py_REFCNT’
#   47851 |     --Py_REFCNT(o);
#         |       ^~~~~~~~~
#   neuralcoref/neuralcoref.cpp: In function ‘int __Pyx_modinit_type_init_code()’:
#   neuralcoref/neuralcoref.cpp:49313:54: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49313 |   __pyx_type_11neuralcoref_11neuralcoref_NeuralCoref.tp_print = 0;
#         |                                                      ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49340:112: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49340 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct____pyx_f_11neuralcoref_11neuralcoref_get_span_type.tp_print = 0;
#         |                                                                                                                ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49346:71: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49346 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_1_genexpr.tp_print = 0;
#         |                                                                       ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49352:76: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49352 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_2_get_resolved.tp_print = 0;
#         |                                                                            ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49358:71: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49358 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_3_genexpr.tp_print = 0;
#         |                                                                       ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49364:122: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49364 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_4___pyx_f_11neuralcoref_11neuralcoref_extract_mentions_spans.tp_print = 0;
#         |                                                                                                                          ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49370:71: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49370 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_5_genexpr.tp_print = 0;
#         |                                                                       ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49376:72: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49376 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_6___iter__.tp_print = 0;
#         |                                                                        ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49382:77: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49382 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_7_set_conv_dict.tp_print = 0;
#         |                                                                             ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49388:71: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49388 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_8_genexpr.tp_print = 0;
#         |                                                                       ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49394:68: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49394 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_9_pipe.tp_print = 0;
#         |                                                                    ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49400:72: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49400 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_10_predict.tp_print = 0;
#         |                                                                        ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49406:72: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49406 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_11_genexpr.tp_print = 0;
#         |                                                                        ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49412:72: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49412 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_12_genexpr.tp_print = 0;
#         |                                                                        ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49418:72: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49418 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_13_genexpr.tp_print = 0;
#         |                                                                        ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49424:72: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49424 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_14_genexpr.tp_print = 0;
#         |                                                                        ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49430:72: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49430 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_15_to_disk.tp_print = 0;
#         |                                                                        ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49436:74: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49436 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_16_from_disk.tp_print = 0;
#         |                                                                          ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49442:73: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49442 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_17_to_bytes.tp_print = 0;
#         |                                                                         ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49448:75: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49448 |   __pyx_type_11neuralcoref_11neuralcoref___pyx_scope_struct_18_from_bytes.tp_print = 0;
#         |                                                                           ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49456:26: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49456 |   __pyx_type___pyx_array.tp_print = 0;
#         |                          ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49461:32: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49461 |   __pyx_type___pyx_MemviewEnum.tp_print = 0;
#         |                                ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49476:31: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49476 |   __pyx_type___pyx_memoryview.tp_print = 0;
#         |                               ^~~~~~~~
#   neuralcoref/neuralcoref.cpp:49489:36: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#   49489 |   __pyx_type___pyx_memoryviewslice.tp_print = 0;
#         |                                    ^~~~~~~~
#   In file included from /usr/local/include/python3.10/unicodeobject.h:1046,
#                    from /usr/local/include/python3.10/Python.h:96,
#                    from neuralcoref/neuralcoref.cpp:4:
#   neuralcoref/neuralcoref.cpp: In function ‘int __Pyx_ParseOptionalKeywords(PyObject*, PyObject***, PyObject*, PyObject**, Py_ssize_t, const char*)’:
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#         |       ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51983:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51983 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                      ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#         |       ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51983:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51983 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                      ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#         |                                                    ^
#   neuralcoref/neuralcoref.cpp:51983:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51983 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                      ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#     580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#         |                                             ^~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#         |                                                    ^
#   neuralcoref/neuralcoref.cpp:51983:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51983 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                      ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#     580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#         |                                             ^~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     264 |        PyUnicode_WSTR_LENGTH(op)))
#         |        ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51983:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51983 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                      ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     264 |        PyUnicode_WSTR_LENGTH(op)))
#         |        ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51983:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51983 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                      ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#         |       ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51983:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51983 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                                                    ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#         |       ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51983:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51983 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                                                    ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#         |                                                    ^
#   neuralcoref/neuralcoref.cpp:51983:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51983 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                                                    ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#     580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#         |                                             ^~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#         |                                                    ^
#   neuralcoref/neuralcoref.cpp:51983:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51983 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                                                    ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#     580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#         |                                             ^~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     264 |        PyUnicode_WSTR_LENGTH(op)))
#         |        ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51983:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51983 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                                                    ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     264 |        PyUnicode_WSTR_LENGTH(op)))
#         |        ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51983:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51983 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                                                    ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#         |       ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51999:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                          ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#         |       ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51999:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                          ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#         |                                                    ^
#   neuralcoref/neuralcoref.cpp:51999:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                          ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#     580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#         |                                             ^~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#         |                                                    ^
#   neuralcoref/neuralcoref.cpp:51999:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                          ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#     580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#         |                                             ^~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     264 |        PyUnicode_WSTR_LENGTH(op)))
#         |        ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51999:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                          ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     264 |        PyUnicode_WSTR_LENGTH(op)))
#         |        ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51999:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                          ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#         |       ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51999:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                                                           ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#         |       ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51999:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                                                           ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#         |                                                    ^
#   neuralcoref/neuralcoref.cpp:51999:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                                                           ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#     580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#         |                                             ^~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#         |                                                    ^
#   neuralcoref/neuralcoref.cpp:51999:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                                                           ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#     580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#         |                                             ^~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     264 |        PyUnicode_WSTR_LENGTH(op)))
#         |        ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51999:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                                                           ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#     451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#         |                                                                           ^
#   /usr/local/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#     264 |        PyUnicode_WSTR_LENGTH(op)))
#         |        ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:51999:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#   51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#         |                                                           ^~~~~~~~~~~~~~~~~~
#   /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#     446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#         |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp: In function ‘PyObject* __Pyx_Coroutine_Send(PyObject*, PyObject*)’:
#   neuralcoref/neuralcoref.cpp:53921:19: error: ‘_PyGen_Send’ was not declared in this scope; did you mean ‘_PyGen_yf’?
#   53921 |             ret = _PyGen_Send((PyGenObject*)yf, value == Py_None ? NULL : value);
#         |                   ^~~~~~~~~~~
#         |                   _PyGen_yf
#   neuralcoref/neuralcoref.cpp:53926:19: error: ‘_PyGen_Send’ was not declared in this scope; did you mean ‘_PyGen_yf’?
#   53926 |             ret = _PyGen_Send((PyGenObject*)yf, value == Py_None ? NULL : value);
#         |                   ^~~~~~~~~~~
#         |                   _PyGen_yf
#   neuralcoref/neuralcoref.cpp: In function ‘PyObject* __Pyx_Generator_Next(PyObject*)’:
#   neuralcoref/neuralcoref.cpp:54010:19: error: ‘_PyGen_Send’ was not declared in this scope; did you mean ‘_PyGen_yf’?
#   54010 |             ret = _PyGen_Send((PyGenObject*)yf, NULL);
#         |                   ^~~~~~~~~~~
#         |                   _PyGen_yf
#   neuralcoref/neuralcoref.cpp: In function ‘PyObject* __Pyx_decode_c_string(const char*, Py_ssize_t, Py_ssize_t, const char*, const char*, PyObject* (*)(const char*, Py_ssize_t, const char*))’:
#   neuralcoref/neuralcoref.cpp:55241:45: warning: ‘PyObject* PyUnicode_FromUnicode(const Py_UNICODE*, Py_ssize_t)’ is deprecated [-Wdeprecated-declarations]
#   55241 |         return PyUnicode_FromUnicode(NULL, 0);
#         |                                             ^
#   In file included from /usr/local/include/python3.10/unicodeobject.h:1046,
#                    from /usr/local/include/python3.10/Python.h:96,
#                    from neuralcoref/neuralcoref.cpp:4:
#   /usr/local/include/python3.10/cpython/unicodeobject.h:551:42: note: declared here
#     551 | Py_DEPRECATED(3.3) PyAPI_FUNC(PyObject*) PyUnicode_FromUnicode(
#         |                                          ^~~~~~~~~~~~~~~~~~~~~
#   neuralcoref/neuralcoref.cpp:55241:45: warning: ‘PyObject* PyUnicode_FromUnicode(const Py_UNICODE*, Py_ssize_t)’ is deprecated [-Wdeprecated-declarations]
#   55241 |         return PyUnicode_FromUnicode(NULL, 0);
#         |                                             ^
#   In file included from /usr/local/include/python3.10/unicodeobject.h:1046,
#                    from /usr/local/include/python3.10/Python.h:96,
#                    from neuralcoref/neuralcoref.cpp:4:
#   /usr/local/include/python3.10/cpython/unicodeobject.h:551:42: note: declared here
#     551 | Py_DEPRECATED(3.3) PyAPI_FUNC(PyObject*) PyUnicode_FromUnicode(
#         |                                          ^~~~~~~~~~~~~~~~~~~~~
#   error: command '/usr/bin/gcc' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for neuralcoref
#   Running setup.py clean for neuralcoref
# Failed to build neuralcoref
# Installing collected packages: neuralcoref
#     Running setup.py install for neuralcoref ... error
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/bin/python3.10 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-xnaf_cv_/neuralcoref_aaf56b26404e4e219cb4ad81d355b09b/setup.py'"'"'; __file__='"'"'/tmp/pip-install-xnaf_cv_/neuralcoref_aaf56b26404e4e219cb4ad81d355b09b/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-fbzlgfqv/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/becode/.local/include/python3.10/neuralcoref
#          cwd: /tmp/pip-install-xnaf_cv_/neuralcoref_aaf56b26404e4e219cb4ad81d355b09b/
#     Complete output (459 lines):
#     running install
#     /home/becode/.local/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.10
#     creating build/lib.linux-x86_64-3.10/neuralcoref
#     copying neuralcoref/file_utils.py -> build/lib.linux-x86_64-3.10/neuralcoref
#     copying neuralcoref/__init__.py -> build/lib.linux-x86_64-3.10/neuralcoref
#     creating build/lib.linux-x86_64-3.10/neuralcoref/tests
#     copying neuralcoref/tests/test_neuralcoref.py -> build/lib.linux-x86_64-3.10/neuralcoref/tests
#     copying neuralcoref/tests/__init__.py -> build/lib.linux-x86_64-3.10/neuralcoref/tests
#     creating build/lib.linux-x86_64-3.10/neuralcoref/train
#     copying neuralcoref/train/document.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
#     copying neuralcoref/train/compat.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
#     copying neuralcoref/train/learn.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
#     copying neuralcoref/train/algorithm.py -> build/lib.linux-x86_64-3.10/neuralcoref/train
# ...
#     /usr/local/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#       264 |        PyUnicode_WSTR_LENGTH(op)))
#           |        ^~~~~~~~~~~~~~~~~~~~~
#     neuralcoref/neuralcoref.cpp:51983:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#     51983 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#           |                                                    ^~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#       446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#           |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#       451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#           |                                                                           ^
#     /usr/local/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#       261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#           |       ^~~~~~~~~~~~~~~~~~~~~
#     neuralcoref/neuralcoref.cpp:51999:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#     51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#           |                          ^~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#       446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#           |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#       451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#           |                                                                           ^
#     /usr/local/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#       261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#           |       ^~~~~~~~~~~~~~~~~~~~~
#     neuralcoref/neuralcoref.cpp:51999:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#     51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#           |                          ^~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#       446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#           |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#       262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#           |                                                    ^
#     neuralcoref/neuralcoref.cpp:51999:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#     51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#           |                          ^~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#       580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#           |                                             ^~~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#       262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#           |                                                    ^
#     neuralcoref/neuralcoref.cpp:51999:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#     51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#           |                          ^~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#       580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#           |                                             ^~~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#       451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#           |                                                                           ^
#     /usr/local/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#       264 |        PyUnicode_WSTR_LENGTH(op)))
#           |        ^~~~~~~~~~~~~~~~~~~~~
#     neuralcoref/neuralcoref.cpp:51999:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#     51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#           |                          ^~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#       446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#           |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#       451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#           |                                                                           ^
#     /usr/local/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#       264 |        PyUnicode_WSTR_LENGTH(op)))
#           |        ^~~~~~~~~~~~~~~~~~~~~
#     neuralcoref/neuralcoref.cpp:51999:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#     51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#           |                          ^~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#       446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#           |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#       451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#           |                                                                           ^
#     /usr/local/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#       261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#           |       ^~~~~~~~~~~~~~~~~~~~~
#     neuralcoref/neuralcoref.cpp:51999:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#     51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#           |                                                           ^~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#       446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#           |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#       451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#           |                                                                           ^
#     /usr/local/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#       261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#           |       ^~~~~~~~~~~~~~~~~~~~~
#     neuralcoref/neuralcoref.cpp:51999:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#     51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#           |                                                           ^~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#       446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#           |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#       262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#           |                                                    ^
#     neuralcoref/neuralcoref.cpp:51999:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#     51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#           |                                                           ^~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#       580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#           |                                             ^~~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#       262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#           |                                                    ^
#     neuralcoref/neuralcoref.cpp:51999:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#     51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#           |                                                           ^~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#       580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#           |                                             ^~~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#       451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#           |                                                                           ^
#     /usr/local/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#       264 |        PyUnicode_WSTR_LENGTH(op)))
#           |        ^~~~~~~~~~~~~~~~~~~~~
#     neuralcoref/neuralcoref.cpp:51999:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#     51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#           |                                                           ^~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#       446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#           |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#       451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#           |                                                                           ^
#     /usr/local/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#       264 |        PyUnicode_WSTR_LENGTH(op)))
#           |        ^~~~~~~~~~~~~~~~~~~~~
#     neuralcoref/neuralcoref.cpp:51999:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#     51999 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#           |                                                           ^~~~~~~~~~~~~~~~~~
#     /usr/local/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#       446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#           |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     neuralcoref/neuralcoref.cpp: In function ‘PyObject* __Pyx_Coroutine_Send(PyObject*, PyObject*)’:
#     neuralcoref/neuralcoref.cpp:53921:19: error: ‘_PyGen_Send’ was not declared in this scope; did you mean ‘_PyGen_yf’?
#     53921 |             ret = _PyGen_Send((PyGenObject*)yf, value == Py_None ? NULL : value);
#           |                   ^~~~~~~~~~~
#           |                   _PyGen_yf
#     neuralcoref/neuralcoref.cpp:53926:19: error: ‘_PyGen_Send’ was not declared in this scope; did you mean ‘_PyGen_yf’?
#     53926 |             ret = _PyGen_Send((PyGenObject*)yf, value == Py_None ? NULL : value);
#           |                   ^~~~~~~~~~~
#           |                   _PyGen_yf
#     neuralcoref/neuralcoref.cpp: In function ‘PyObject* __Pyx_Generator_Next(PyObject*)’:
#     neuralcoref/neuralcoref.cpp:54010:19: error: ‘_PyGen_Send’ was not declared in this scope; did you mean ‘_PyGen_yf’?
#     54010 |             ret = _PyGen_Send((PyGenObject*)yf, NULL);
#           |                   ^~~~~~~~~~~
#           |                   _PyGen_yf
#     neuralcoref/neuralcoref.cpp: In function ‘PyObject* __Pyx_decode_c_string(const char*, Py_ssize_t, Py_ssize_t, const char*, const char*, PyObject* (*)(const char*, Py_ssize_t, const char*))’:
#     neuralcoref/neuralcoref.cpp:55241:45: warning: ‘PyObject* PyUnicode_FromUnicode(const Py_UNICODE*, Py_ssize_t)’ is deprecated [-Wdeprecated-declarations]
#     55241 |         return PyUnicode_FromUnicode(NULL, 0);
#           |                                             ^
#     In file included from /usr/local/include/python3.10/unicodeobject.h:1046,
#                      from /usr/local/include/python3.10/Python.h:96,
#                      from neuralcoref/neuralcoref.cpp:4:
#     /usr/local/include/python3.10/cpython/unicodeobject.h:551:42: note: declared here
#       551 | Py_DEPRECATED(3.3) PyAPI_FUNC(PyObject*) PyUnicode_FromUnicode(
#           |                                          ^~~~~~~~~~~~~~~~~~~~~
#     neuralcoref/neuralcoref.cpp:55241:45: warning: ‘PyObject* PyUnicode_FromUnicode(const Py_UNICODE*, Py_ssize_t)’ is deprecated [-Wdeprecated-declarations]
#     55241 |         return PyUnicode_FromUnicode(NULL, 0);
#           |                                             ^
#     In file included from /usr/local/include/python3.10/unicodeobject.h:1046,
#                      from /usr/local/include/python3.10/Python.h:96,
#                      from neuralcoref/neuralcoref.cpp:4:
#     /usr/local/include/python3.10/cpython/unicodeobject.h:551:42: note: declared here
#       551 | Py_DEPRECATED(3.3) PyAPI_FUNC(PyObject*) PyUnicode_FromUnicode(
#           |                                          ^~~~~~~~~~~~~~~~~~~~~
#     error: command '/usr/bin/gcc' failed with exit code 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /usr/local/bin/python3.10 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-xnaf_cv_/neuralcoref_aaf56b26404e4e219cb4ad81d355b09b/setup.py'"'"'; __file__='"'"'/tmp/pip-install-xnaf_cv_/neuralcoref_aaf56b26404e4e219cb4ad81d355b09b/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-fbzlgfqv/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/becode/.local/include/python3.10/neuralcoref Check the logs for full command output.
# Note: you may need to restart the kernel to use updated packages.

# %%
'''
Reference: https://github.com/huggingface/neuralcoref
''' 

import spacy
nlp = spacy.load('en_core_web_sm')

import neuralcoref
neuralcoref.add_to_pipe(nlp)

# Load SpaCy
nlp = spacy.load('en')
# Add neural coref to SpaCy's pipe
neuralcoref.add_to_pipe(nlp)

def coref_resolution(text):
    """Function that executes coreference resolution on a given text"""
    doc = nlp(text)
    # fetches tokens with whitespaces from spacy document
    tok_list = list(token.text_with_ws for token in doc)
    for cluster in doc._.coref_clusters:
        # get tokens from representative cluster name
        cluster_main_words = set(cluster.main.text.split(' '))
        for coref in cluster:
            if coref != cluster.main:  # if coreference element is not the representative element of that cluster
                if coref.text != cluster.main.text and bool(set(coref.text.split(' ')).intersection(cluster_main_words)) == False:
                    # if coreference element text and representative element text are not equal and none of the coreference element words are in representative element. This was done to handle nested coreference scenarios
                    tok_list[coref.start] = cluster.main.text + \
                        doc[coref.end-1].whitespace_
                    for i in range(coref.start+1, coref.end):
                        tok_list[i] = ""

    return "".join(tok_list)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_70796/274740257.py in <module>
#       6 nlp = spacy.load('en_core_web_sm')
#       7
# ----> 8 import neuralcoref
#       9 neuralcoref.add_to_pipe(nlp)
#      10
#
# ModuleNotFoundError: No module named 'neuralcoref'
