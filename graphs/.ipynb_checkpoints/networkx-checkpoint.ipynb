# %% [markdown]
# # Quick graph creation

# %% [markdown]
# ####  Libraries

# %%
import spacy
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

from spacy.tokens import Span 

import networkx as nx
from pyvis import network as net

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline
# Out:
# 2022-01-18 09:49:31.587961: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-18 09:49:31.588006: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/becode/.local/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
from IPython.core.display import display, HTML
g=net.Network(height='400px', width='50%',heading='')
g.add_node(1)
g.add_node(2)
g.add_node(3)
g.add_edge(1,2)
g.add_edge(2,3)
g.show('example.html')
display(HTML('example.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.16.1/vis.css" type="text/css" />
# <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/vis/4.16.1/vis-network.min.js"> </script>
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 50%;
#             height: 400px;
#             background-color: #ffffff;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"id": 1, "label": 1, "shape": "dot"}, {"id": 2, "label": 2, "shape": "dot"}, {"id": 3, "label": 3, "shape": "dot"}]);
#         edges = new vis.DataSet([{"from": 1, "to": 2}, {"from": 2, "to": 3}]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": false,
#             "type": "continuous"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#         network = new vis.Network(container, data, options);
#
#
#
#
#
#
#         return network;
#
#     }
#
#     drawGraph();
#
# </script>
# </body>
# </html>

# %%
kg_df = pd.read_csv("../assets/rel-edges.csv")

# %%
kg_df.head(20 +1)
# Out:
#                      source      relation                 target
# 0                 Tug crews        lifted                The ban
# 1        foreign-flag ships      carrying             containers
# 2                 the ports  disrupted by        The pay dispute
# 3          shipping sources          said              Tug crews
# 4                         ,       imposed            a pay claim
# 5                   The ban     prevented                The ban
# 6                      they          said                The ban
# 7           The pay dispute          went              a hearing
# 8            the disruption         began         cargo handling
# 9                      they          said         the disruption
# 10    The industrial action            is                     of
# 11    The industrial action        called         the NSW Trades
# 12         shipping sources          said                 taking
# 13  the various port unions        appear                     it
# 14                     they          said         cargo handling
# 15                     They          said         cargo handling
# 16                     they           say  The industrial action
# 17           the disruption            go  The industrial action
# 18                       it          have    container movements

# %% [markdown]
# Next, we will use the networkx library to create a network from this dataframe. The nodes will represent the entities and the edges or connections between the nodes will represent the relations between the nodes.
#
# It is going to be a directed graph. In other words, the relation between any connected node pair is not two-way, it is only from one node to another. For example, “John eats pasta”:

# %%
# create a directed-graph from a dataframe
def graph(kg_df):
    G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())
    return G

# %%
G= graph(kg_df)

# %% [markdown]
# Let’s plot the network

# %%
def plot(G):
    plt.figure(figsize=(12,12))
    pos = nx.spring_layout(G)
    edge_labels = nx.get_edge_attributes(G,'relation')
    nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
    nx.draw_networkx_edge_labels(G, pos=pos)
    
    return plt.show()

# %%
plot(G)

# %%
def interactive_graph(G):
    g4 = net.Network(height='400px', width='50%',notebook=True,heading='Graph :)')
    g4.from_nx(G)
    g4.show_buttons(filter_=['physics'])
    g4.show('graph.html')
    disp= display(HTML('graph.html'))
    
    return disp

# %%
interactive_graph(G)
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.16.1/vis.css" type="text/css" />
# <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/vis/4.16.1/vis-network.min.js"> </script>
# <center>
# <h1>Graph :)</h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 50%;
#             height: 400px;
#             background-color: #ffffff;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#         #config {
#             float: left;
#             width: 400px;
#             height: 600px;
#         }
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <div id = "config"></div>
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"id": "Tug crews", "label": "Tug crews", "shape": "dot", "size": 10}, {"id": "The ban", "label": "The ban", "shape": "dot", "size": 10}, {"id": "foreign-flag ships", "label": "foreign-flag ships", "shape": "dot", "size": 10}, {"id": "containers", "label": "containers", "shape": "dot", "size": 10}, {"id": "the ports", "label": "the ports", "shape": "dot", "size": 10}, {"id": "The pay dispute", "label": "The pay dispute", "shape": "dot", "size": 10}, {"id": "a hearing", "label": "a hearing", "shape": "dot", "size": 10}, {"id": "shipping sources", "label": "shipping sources", "shape": "dot", "size": 10}, {"id": "taking", "label": "taking", "shape": "dot", "size": 10}, {"id": ",", "label": ",", "shape": "dot", "size": 10}, {"id": "a pay claim", "label": "a pay claim", "shape": "dot", "size": 10}, {"id": "they", "label": "they", "shape": "dot", "size": 10}, {"id": "the disruption", "label": "the disruption", "shape": "dot", "size": 10}, {"id": "cargo handling", "label": "cargo handling", "shape": "dot", "size": 10}, {"id": "The industrial action", "label": "The industrial action", "shape": "dot", "size": 10}, {"id": "of", "label": "of", "shape": "dot", "size": 10}, {"id": "the NSW Trades", "label": "the NSW Trades", "shape": "dot", "size": 10}, {"id": "the various port unions", "label": "the various port unions", "shape": "dot", "size": 10}, {"id": "it", "label": "it", "shape": "dot", "size": 10}, {"id": "container movements", "label": "container movements", "shape": "dot", "size": 10}, {"id": "They", "label": "They", "shape": "dot", "size": 10}]);
#         edges = new vis.DataSet([{"from": "Tug crews", "relation": "lifted", "to": "The ban", "weight": 1}, {"from": "The ban", "relation": "prevented", "to": "The ban", "weight": 1}, {"from": "foreign-flag ships", "relation": "carrying", "to": "containers", "weight": 1}, {"from": "the ports", "relation": "disrupted by", "to": "The pay dispute", "weight": 1}, {"from": "The pay dispute", "relation": "went", "to": "a hearing", "weight": 1}, {"from": "shipping sources", "relation": "said", "to": "Tug crews", "weight": 1}, {"from": "shipping sources", "relation": "said", "to": "taking", "weight": 1}, {"from": ",", "relation": "imposed", "to": "a pay claim", "weight": 1}, {"from": "they", "relation": "said", "to": "The ban", "weight": 1}, {"from": "they", "relation": "said", "to": "the disruption", "weight": 1}, {"from": "they", "relation": "said", "to": "cargo handling", "weight": 1}, {"from": "they", "relation": "say", "to": "The industrial action", "weight": 1}, {"from": "the disruption", "relation": "began", "to": "cargo handling", "weight": 1}, {"from": "the disruption", "relation": "go", "to": "The industrial action", "weight": 1}, {"from": "The industrial action", "relation": "is", "to": "of", "weight": 1}, {"from": "The industrial action", "relation": "called", "to": "the NSW Trades", "weight": 1}, {"from": "the various port unions", "relation": "appear", "to": "it", "weight": 1}, {"from": "it", "relation": "have", "to": "container movements", "weight": 1}, {"from": "They", "relation": "said", "to": "cargo handling", "weight": 1}]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": true,
#         "filter": [
#             "physics"
#         ]
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": false,
#             "type": "continuous"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#         // if this network requires displaying the configure window,
#         // put it in its div
#         options.configure["container"] = document.getElementById("config");
#
#
#         network = new vis.Network(container, data, options);
#
#
#
#
#
#
#         return network;
#
#     }
#
#     drawGraph();
#
# </script>
# </body>
# </html>

# %% [markdown]
# jaal

# %%
pip install jaal
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jaal in /home/becode/.local/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: pandas>=1.2.1 in /home/becode/.local/lib/python3.10/site-packages (from jaal) (1.3.5)
# Requirement already satisfied: dash-html-components>=1.1.2 in /home/becode/.local/lib/python3.10/site-packages (from jaal) (2.0.0)
# Requirement already satisfied: visdcc>=0.0.40 in /home/becode/.local/lib/python3.10/site-packages (from jaal) (0.0.40)
# Requirement already satisfied: dash-core-components>=1.15.0 in /home/becode/.local/lib/python3.10/site-packages (from jaal) (2.0.0)
# Requirement already satisfied: dash-bootstrap-components<1 in /home/becode/.local/lib/python3.10/site-packages (from jaal) (0.13.1)
# Requirement already satisfied: dash>=1.19.0 in /home/becode/.local/lib/python3.10/site-packages (from jaal) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /home/becode/.local/lib/python3.10/site-packages (from dash>=1.19.0->jaal) (5.5.0)
# Requirement already satisfied: dash-table==5.0.0 in /home/becode/.local/lib/python3.10/site-packages (from dash>=1.19.0->jaal) (5.0.0)
# Requirement already satisfied: Flask>=1.0.4 in /home/becode/.local/lib/python3.10/site-packages (from dash>=1.19.0->jaal) (2.0.2)
# Requirement already satisfied: flask-compress in /home/becode/.local/lib/python3.10/site-packages (from dash>=1.19.0->jaal) (1.10.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/becode/.local/lib/python3.10/site-packages (from pandas>=1.2.1->jaal) (1.22.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/becode/.local/lib/python3.10/site-packages (from pandas>=1.2.1->jaal) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/becode/.local/lib/python3.10/site-packages (from pandas>=1.2.1->jaal) (2021.3)
# Requirement already satisfied: Jinja2>=3.0 in /home/becode/.local/lib/python3.10/site-packages (from Flask>=1.0.4->dash>=1.19.0->jaal) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in /home/becode/.local/lib/python3.10/site-packages (from Flask>=1.0.4->dash>=1.19.0->jaal) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in /home/becode/.local/lib/python3.10/site-packages (from Flask>=1.0.4->dash>=1.19.0->jaal) (2.0.2)
# Requirement already satisfied: click>=7.1.2 in /home/becode/.local/lib/python3.10/site-packages (from Flask>=1.0.4->dash>=1.19.0->jaal) (8.0.3)
# Requirement already satisfied: tenacity>=6.2.0 in /home/becode/.local/lib/python3.10/site-packages (from plotly>=5.0.0->dash>=1.19.0->jaal) (8.0.1)
# Requirement already satisfied: six in /home/becode/.local/lib/python3.10/site-packages (from plotly>=5.0.0->dash>=1.19.0->jaal) (1.16.0)
# Requirement already satisfied: brotli in /home/becode/.local/lib/python3.10/site-packages (from flask-compress->dash>=1.19.0->jaal) (1.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/becode/.local/lib/python3.10/site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash>=1.19.0->jaal) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
kg_df
# Out:
#                      source      relation                 target
# 0                 Tug crews        lifted                The ban
# 1        foreign-flag ships      carrying             containers
# 2                 the ports  disrupted by        The pay dispute
# 3          shipping sources          said              Tug crews
# 4                         ,       imposed            a pay claim
# 5                   The ban     prevented                The ban
# 6                      they          said                The ban
# 7           The pay dispute          went              a hearing
# 8            the disruption         began         cargo handling
# 9                      they          said         the disruption
# 10    The industrial action            is                     of
# 11    The industrial action        called         the NSW Trades
# 12         shipping sources          said                 taking
# 13  the various port unions        appear                     it
# 14                     they          said         cargo handling
# 15                     They          said         cargo handling
# 16                     they           say  The industrial action
# 17           the disruption            go  The industrial action
# 18                       it          have    container movements

# %%
from jaal import Jaal
from jaal.datasets import load_got

#load the data

edge_df, node_df = plot(G)

# add edge labels
edge_df.loc[:, 'source'] = edge_df.loc[:, 'target'].astype(str)
Jaal(edge_df, node_df).plot(directed=True)
node_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_8063/1127045767.py in <module>
#       4 #load the data
#       5
# ----> 6 edge_df, node_df = plot(G)
#       7
#       8 # add edge labels
#
# TypeError: cannot unpack non-iterable NoneType object

# %% [markdown]
# Well, this is not exactly what we were hoping for (still looks quite a sight though!).
#
# It turns out that we have created a graph with all the relations that we had. It becomes really hard to visualize a graph with these many relations or predicates.
#
# So, it’s advisable to use only a few important relations to visualize a graph. I will take one relation at a time. Let’s start with the relation “composed by”

# %% [markdown]
# Ignore this code:

# %%
#G=nx.from_pandas_edgelist(kg_df[kg_df['relation']=="decides"], "source", "target", 
#                          edge_attr=True, create_using=nx.MultiDiGraph())
#
#plt.figure(figsize=(12,12))
#pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
#nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
#plt.show()
