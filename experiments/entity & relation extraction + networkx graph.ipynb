# %% [markdown]
# # Quick graph creation

# %% [markdown]
# #### Libraries

# %%
import spacy
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline
# Out:
# 2022-01-12 12:18:05.207158: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-12 12:18:05.207192: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/becode/.local/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
nlp = spacy.load('en_core_web_sm')
doc1 = nlp("The 22-year-old recently won ATP Challenger tournament.")
for tok in doc1:
  print(tok.text, "...", tok.dep_)
# Out:
# The ... det
# 22 ... nummod
# - ... punct
# year ... npadvmod
# - ... punct
# old ... nsubj
# recently ... advmod
# won ... ROOT
# ATP ... compound
# Challenger ... compound
# tournament ... dobj
# . ... punct

# %% [markdown]
# We wanted to extract “22-year-old” instead.

# %% [markdown]
# The rule can be something like this — extract the subject/object along with its modifiers and also extract the punctuation marks between them.
# In short, we will use dependency parsing to extract entities.

# %% [markdown]
# #### Extract Relations

# %% [markdown]
# Entity extraction is half the job done. To build a knowledge graph, we need edges to connect the nodes (entities) to one another. These edges are the relations between a pair of nodes.

# %%
doc = nlp("Nagal won the first set.")

for tok in doc:
  print(tok.text, "...", tok.dep_)
# Out:
# Nagal ... nsubj
# won ... ROOT
# the ... det
# first ... amod
# set ... dobj
# . ... punct

# %% [markdown]
# To extract the relation, we have to find the ROOT of the sentence (which is also the verb of the sentence). Hence, the relation extracted from this sentence would be “won”.

# %% [markdown]
# #### Build a Knowledge Graph from Text Data

# %% [markdown]
# The following dataset exists of 4,300 sentences from over 500 Wikipedia articles. Each of these sentences contains exactly two entities – one subject and one object.

# %%
# import wikipedia sentences
candidate_sentences = pd.read_csv("wiki_sentences_v2.csv")
candidate_sentences.shape
# Out:
# (4318, 1)

# %%
candidate_sentences
# Out:
#                                                                                                       sentence
# 0                                                 confused and frustrated, connie decides to leave on her own.
# 1                                                            later, a woman’s scream is heard in the distance.
# 2                                                                     christian is then paralyzed by an elder.
# 3                                                                                   the temple is set on fire.
# 4                                                                            outside, the cult wails with him.
# ...                                                                                                        ...
# 4313     confidencial also responded negatively, calling the film a barren drama, unsubtle and self-indulgent.
# 4314                                             and le parisien gave the film their highest five-star rating.
# 4315  the museum collection includes 37,000 film titles, 60,000 posters, 700,000 photographs and 20,000 books.
# 4316                                   its predecessor was the dutch historical film archive, founded in 1946.
# 4317                                                         , 1920'sfilmstar greta garbo by alexander binder,
#
# [4318 rows x 1 columns]

# %% [markdown]
# Inspect a few sentences

# %%
candidate_sentences['sentence'].sample(5)
# Out:
# 2269                                             the 1985 novel always coming home by ursula k.
# 3437                           his impact on the genre was considered prolific and influential.
# 4129                      the film or prints emerge washed and dry and ready to be cut by hand.
# 3221                 but says the film is overshadowed by besson's offscreen personal issues.\n
# 1846    such positive black-and-white projection is now rarely done, except in motion pictures.
# Name: sentence, dtype: object

# %% [markdown]
# check the subject and object of one of these sentences. Ideally, there should be one subject and one object in the sentence

# %%
doc = nlp("Mitsubishi Heavy Industries Ltd MITH.T  (MHI) and C. Itoh and Co Ltd CITT.T have decided to sell  their combined 65 pct stake in Indonesias Pt Triguna Utama  Machinery Industries to Caterpillar")

for tok in doc:
  print(tok.text, "...", tok.dep_)
# Out:
# Mitsubishi ... compound
# Heavy ... compound
# Industries ... compound
# Ltd ... nsubj
# MITH.T ... compound
#   ... dep
# ( ... punct
# MHI ... appos
# ) ... punct
# and ... cc
# C. ... compound
# Itoh ... conj
# and ... cc
# Co ... compound
# Ltd ... compound
# CITT.T ... conj
# have ... aux
# decided ... ROOT
# to ... aux
# sell ... xcomp
#   ... dep
# their ... poss
# combined ... amod
# 65 ... nummod
# pct ... compound
# stake ... dobj
# in ... prep
# Indonesias ... compound
# Pt ... compound
# Triguna ... compound
# Utama ... nmod
#   ... dep
# Machinery ... compound
# Industries ... pobj
# to ... prep
# Caterpillar ... pobj

# %% [markdown]
#  There is only one subject (‘process’) and only one object (‘standard’). You can check for other sentences in a similar manner.

# %% [markdown]
# #### Entity Pairs Extraction

# %% [markdown]
# To build a knowledge graph, the most important things are the nodes and the edges between them.
#
# These nodes are going to be the entities that are present in the Wikipedia sentences. Edges are the relationships connecting these entities to one another. We will extract these elements in an unsupervised manner, i.e., we will use the grammar of the sentences.
#
# The main idea is to go through a sentence and extract the subject and the object as and when they are encountered.

# %% [markdown]
# However, there are a few challenges ⁠— an entity can span across multiple words, eg., “red wine”, and the dependency parsers tag only the individual words as subjects or objects.

# %% [markdown]
# The function below is used to extract the subject and the object (entities) from a sentence while also overcoming the challenges mentioned above.

# %%
sent= "The 22-year-old recently won ATP Challenger tournament."

# %%
def get_entities(sent):
    
    
    ## chunk 1
    ent1 = ""
    ent2 = ""

    prv_tok_dep = ""    # dependency tag of previous token in the sentence
    prv_tok_text = ""   # previous token in the sentence

    prefix = ""
    modifier = ""
    
###########################
    for tok in nlp(sent):
        ## chunk 2
        # if token is a punctuation mark then move on to the next token
        
        if tok.dep_ != "punct":
            # check: token is a compound word or not
            if tok.dep_ == "compound":
                prefix = tok.text
                # if the previous word was also a 'compound' then add the current word to it
                if prv_tok_dep == "compound":
                    prefix = prv_tok_text + " "+ tok.text
                    
            
    # check: token is a modifier or not
        if tok.dep_.endswith("mod") == True:
            modifier = tok.text
    
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
            modifier = prv_tok_text + " "+ tok.text
            
            
        ## chunk 3
        if tok.dep_.find("subj") == True:
            ent1 = modifier +" "+ prefix + " "+ tok.text
            prefix = ""
            modifier = ""
            prv_tok_dep = ""
            prv_tok_text = ""
            
        ## chunk 4
        if tok.dep_.find("obj") == True:
            ent2 = modifier +" "+ prefix +" "+ tok.text
            
        ## chunk 5  
        # update variables
        prv_tok_dep = tok.dep_
        prv_tok_text = tok.text
  ##    ###########################################################

    return [ent1.strip(), ent2.strip()]

# %%
get_entities(sent)
# Out:
# ['year  old', 'Challenger tournament ATP Challenger tournament']

# %% [markdown]
# we can use this function to extract these entity pairs for all the sentences in our data

# %%
entity_pairs = []

for i in tqdm(candidate_sentences["sentence"]):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████████████████████████████████| 4318/4318 [00:37<00:00, 116.06it/s]

# %%
entity_pairs
# Out:
# [['connie', 'own'],
#  ['later  scream', 'distance'],
#  ['christian', 'then  elder'],
#  ['temple', 'fire'],
#  ['', 'cult wails cult him'],
#  ['it', 'religious  awakening'],
#  ['c. mackenzie c. mackenzie', 'craig vincent craig cast'],
#  ['di francia craig di francia', 'action bronson action cast'],
#  ['sebastian  maniscalco', 'later paul ben cast'],
#  ['we', 'just  film'],
#  ['we', 'tests'],
#  ['', 'sales rights sales rights'],
#  ['robbie robertson musician robbie robertson', 'soundtrack'],
#  ['it', 'music tracks music tracks'],
#  ['it', 'reviewed  franchise'],
#  ['she', 'accidentally  mystique'],
#  ['military  forces', 'arrest'],
#  ['train', 'vuk'],
#  ['', 'eberhardt portrays eberhardt portrays'],
#  ['singer', 'men'],
#  ['last  which', 'penn'],
#  ['jessica chastain jessica chastain', 'same  character'],
#  ['mauro fiore mauro fiore', 'cinematographer'],
#  ['filming', 'october'],
#  ['soundtrack', 'digitally  june'],
#  ['album', 'digitally  august'],
#  ['film', 'motion pictures studios motion pictures'],
#  ['it', '136.5 \xa0 136.5 million'],
#  ['film', ''],
#  ['it', 'yoshimitsu banno producer yoshimitsu banno'],
#  ['', 'former vivienne graham employee'],
#  ['monster zero awakens monster which', 'monarch members monarch .'],
#  ['madison', 'mythological  texts'],
#  ['joe morton joe morton', 'older  dr'],
#  ['godzilla', 'king ghidorah king themselves'],
#  ['when  dougherty', 'when  reaction'],
#  ['we', 'godzilla'],
#  ['only  mandate', 'monarch'],
#  ['ten  writers', 'treatment'],
#  ['script', 'year'],
#  ['dougherty', 'filming  production'],
#  ['film', 'this'],
#  ['it', 'big  dinosaurs'],
#  ['other  actors', 'body'],
#  ['scott chambliss designer scott chambliss', 'art directors art directors'],
#  ['single', 'may'],
#  ['tracks', 'bear mccreary bear mccreary'],
#  ['score', 'also  mccreary'],
#  ['poster  trailer', 'december'],
#  ['theatrical  poster', 'april'],
#  ['film', 'originally  june'],
#  ['collectible  tickets', 'two  sizes'],
#  ['4k  release', 'hdr10'],
#  ['retail  exclusives', 'clear  files'],
#  ['such  heroes', 'one  liners'],
#  ['it', 'fiction twist science fiction twist'],
#  ['action films action films', 'stunt work stunt work'],
#  ['examples', 'jones franchise indiana jones franchise'],
#  ['themes', 'horror films horror films'],
#  ['mall cop mall cop', 'recent  trend'],
#  ['they', ''],
#  ['both', 'many  roles'],
#  ['producer', 'also  production'],
#  ['finally  producer', 'marketing'],
#  ['line producer line producer', 'certain  cases'],
#  ['most  producers', 'college'],
#  ['film directors film directors', 'screenwriters'],
#  ['film directors film directors', 'film school film school'],
#  ['directors', 'different  approaches'],
#  ['directors', 'additional  roles'],
#  ['film schools film schools', 'sound  stages'],
#  ['degree course degree course', 'five  years'],
#  ['academy berlin academy berlin', 'tv station brandenburg tv station'],
#  ['', 'la  paris'],
#  ['film awards film awards', 'award ceremonies film award india'],
#  ['awards', 'first  1954'],
#  ['film awards film awards', 'main  categories'],
#  ['he', 'home  apartment'],
#  ['mass  riot', 'gotham'],
#  ['arthur', 'state hospital arkham state hospital'],
#  ['war dogs film war dogs', 'august'],
#  ['we', 'even  joker'],
#  ['then  we', 'that'],
#  ['pereira - dante pereira olson', 'douglas hodge douglas cast'],
#  ['it', 'warner bros warner bros'],
#  ['it', 'eye - eye me'],
#  ['i', 'it'],
#  ['they', 'it'],
#  ['i', 'it'],
#  ['they', 'it'],
#  ['film', 'samuel beckett samuel beckett'],
#  ['shooting script leaf shooting script', '22  may'],
#  ['beckett', 'zero director alan mostel'],
#  ['beckett', 'buster keaton buster keaton'],
#  ['this', 'united states united states'],
#  ['', ''],
#  ['', 'violently camera left'],
#  ['couple', 'other'],
#  ['camera', 'vestibule'],
#  ['camera', 'close - close up'],
#  ['she', 'fumbling  feet'],
#  ['she', 'eyes'],
#  ['coat tails coat tails', 'stairs'],
#  ['simply  mechanics', 'tasks'],
#  ['he', 'them'],
#  ['he', 'eye patch eye patch'],
#  ['he', 'chair'],
#  ['', 'aut percipere percipi aut percipere'],
#  ['he', 'away  himself'],
#  ['e', 'merely  person'],
#  ['e', ''],
#  ['script', 'various  ways'],
#  ['viewers', 'work'],
#  ['particular  beckett', 'particular  project'],
#  ['four  directors', 'series'],
#  ['he', 'book'],
#  ['david heyman david heyman', 'film'],
#  ['acting  experience', 'school plays school plays'],
#  ['barron', 'four  films'],
#  ['executive  producers', 'seghatchian  wigram'],
#  ['he', 'real  passion'],
#  ['directors', 'other'],
#  ['production designer production designer', 'eight  films'],
#  ['so  we', 'substantial  piece'],
#  ['potter series harry potter series', 'four  composers'],
#  ['desplat', 'harry potter harry potter'],
#  ['', '2  2011'],
#  ['they', 'trumps'],
#  ['director', 'last  time'],
#  ['harry potter harry potter', 'muggle  aunt'],
#  ['however  part', '2  2d'],
#  ['2017  johns', 'january'],
#  ['principal  photography', 'august'],
#  ['david ayer david ayer', 'director'],
#  ['', 'barry bruce allen'],
#  ['justice league justice league', 'worldwide  november'],
#  ['aquaman', 'october'],
#  ['production', 'august'],
#  ['mister mind villain mister mind', '- credits mid - scene'],
#  ['month  sequel', 'san diego san diego'],
#  ['production', 'early  december'],
#  ['pedro pascal pedro pascal', 'key  role'],
#  ['filming  locations', 'warner bros warner bros'],
#  ['wonder woman wonder woman', 'june'],
#  ['initial  script', 'michael green michael guggenheim'],
#  ['dan mazeau dan mazeau', 'writer'],
#  ['francis daley john francis daley', 'march'],
#  ['plot', 'force multiverse speed force multiverse'],
#  ['production', 'january'],
#  ['flash', 'sometime  2021'],
#  ['peter safran producer peter who', 'peter safran producer peter safran'],
#  ['production', '2020'],
#  ['aquaman', '2  december'],
#  ['suicide squad suicide squad', 'shortly  superman'],
#  ['2017  johns', 'january'],
#  ['principal  photography', 'august'],
#  ['david ayer david ayer', 'director'],
#  ['', 'barry bruce allen'],
#  ['justice league justice league', 'worldwide  november'],
#  ['aquaman', 'october'],
#  ['production', 'august'],
#  ['mister mind villain mister mind', '- credits mid - scene'],
#  ['month  sequel', 'san diego san diego'],
#  ['production', 'early  december'],
#  ['pedro pascal pedro pascal', 'key  role'],
#  ['filming  locations', 'warner bros warner bros'],
#  ['wonder woman wonder woman', 'june'],
#  ['initial  script', 'michael green michael guggenheim'],
#  ['dan mazeau dan mazeau', 'writer'],
#  ['francis daley john francis daley', 'march'],
#  ['plot', 'force multiverse speed force multiverse'],
#  ['production', 'january'],
#  ['flash', 'sometime  2021'],
#  ['peter safran producer peter who', 'peter safran producer peter safran'],
#  ['production', '2020'],
#  ['aquaman', '2  december'],
#  ['suicide squad suicide squad', 'shortly  superman'],
#  ['', 'two freddie kiss'],
#  ['they', 'minute slot minute slot'],
#  ['2011  production', 'april'],
#  ['whishaw', 'project'],
#  ['i', 'man'],
#  ['discussions', 'him'],
#  ['fletcher', 'producer credit producer credit'],
#  ['vinyl release vinyl release', '8  february'],
#  ['digital  version', ''],
#  ['instead  it', 'threatening  illness'],
#  ['it', 'north america north america'],
#  ['new  markets', 'france'],
#  ['it', 'south korea south korea'],
#  ['they', 'conclusions'],
#  ['horror', 'also  fantasy'],
#  ['prevalent  elements', 'ghosts'],
#  ['it', 'faust legend faust legend'],
#  ['this', 'trick films trick films'],
#  ['trick films trick films', 'special  effects'],
#  ["l'inferno", 'three  artists'],
#  ['series', 'surrealist movement surrealist movement'],
#  ['film', 'five  stories'],
#  ['it', 'german  expressionism'],
#  ['w. murnau f. w. murnau', 'themed  movie'],
#  ['it', 'novel dracula horror novel dracula'],
#  ['this', 'expressionism style expressionism style'],
#  ['they', 'expressionist movement expressionist movement'],
#  ['exaggerated  smile', 'dc  joker'],
#  ['film', 'poorly  audiences'],
#  ['', 'special morality effects'],
#  ['it', 'earlier  film'],
#  ['film', 'well  critics'],
#  ['assistant', 'abnormal  brain'],
#  ['first  one', 'rue morgue rue morgue'],
#  ['it', 'boris karloff boris karloff'],
#  ['first  one', 'july'],
#  ['it', 'blue mystery room'],
#  ['it', 'boris karloff boris karloff'],
#  ['it', 'six  movies'],
#  ['universal  pictures', 'iconic  actors'],
#  ['', 'ruric   ruric screenplay'],
#  ['horror film horror film', 'hit  frankenstein'],
#  ['elsa lanchester actress elsa lanchester', 'bride'],
#  ['he', 'writing'],
#  ['radiation effects radiation effects', 'slowly  him'],
#  ['daughter  gloria', 'title role title role'],
#  ['intervening  criticism', 'intervening  decades'],
#  ['film', 'boris karloff boris karloff'],
#  ['phantom  creeps', ''],
#  ['other  studios', 'lead'],
#  ['fright  factor', 'way'],
#  ['film director film director', 'film gimmick film gimmick'],
#  ['1950s', 'creature  feature'],
#  ['fly', 'vincent price vincent price'],
#  ['film', 'popular  culture'],
#  ['twilight zone phrase twilight zone', 'surreal  experiences'],
#  ['1970s', 'horror films horror films'],
#  ['italian  film', 'nicolas roeg nicolas roeg'],
#  ['murder', 'horror films horror films'],
#  ['poltergeist', 'critics association film critics association'],
#  ['changeling', 'peter medak peter medak'],
#  ['influence', 'still  films'],
#  ['', 'day fiction day fiction'],
#  ['first  shake', 'philippines'],
#  ['horror movies action horror movies', '1980s'],
#  ['horror film fantasy horror which', 'stan winston artist stan winston'],
#  ['', 'horror film fiction horror paul'],
#  ['monster horror monster horror', 'quite  1990s'],
#  ['tremors', 'first  tremors'],
#  ['', 'contrast'],
#  ['others', 'many  awards'],
#  ['it', 'alejandro'],
#  ['book adaptations book adaptations', 'blade series blade series'],
#  ['pronounced  trends', 'horror films horror films'],
#  ['films', 'language countries language countries'],
#  ['notable  film', 'spanish debut filmmaker'],
#  ['cold  prey', 'roar uthaug roar uthaug'],
#  ['others', 'horror film horror film'],
#  ['latter  film', 'sequel'],
#  ['', ''],
#  ['verónica', 'real horror events'],
#  ['death day death day', 'february'],
#  ['themes', 'horror films horror films'],
#  ['category', 'fantasy genre fantasy genre'],
#  ['horror events horror which', 'holiday  season'],
#  ['it', 'christmas'],
#  ['examples', 'all r house'],
#  ['examples', 'frankenstein'],
#  ['common  themes', 'vengeful  ghosts'],
#  ['examples', 'ring'],
#  ['genre', 'science fiction science fiction'],
#  ['examples', 'birds'],
#  ['it', 'most  1964'],
#  ['examples', 'friend request friend request'],
#  ['one', 'side effects side effects'],
#  ['horror films horror films', 'social  controversy'],
#  ['horror movies horror movies', 'positive  endings'],
#  ['comedy - comedy drama', 'love affair love affair'],
#  ['others', ''],
#  ['sometimes  portmanteau', 'words'],
#  ['military  comedies', 'good  morning'],
#  ['film', 'thin  coating'],
#  ['today  it', 'film commerce film commerce'],
#  ['it', 'simple  friends'],
#  ['1968  festival', '19  may'],
#  ['thierry frémaux thierry frémaux', '2007'],
#  ['festival', 'european  films'],
#  ['jill forbes jill forbes', 'european sarah cinema'],
#  ['however  curse', 'black  pearl'],
#  ['second  film', 'pictures logo disney pictures logo'],
#  ['roadshow  studios', 'filming port locations'],
#  ['suddenly  market', 'musicals'],
#  ['many  comedies', 'musical  numbers'],
#  ['', 'box - box office'],
#  ['chicago', 'first  oliver'],
#  ['', 'moulin rouge moulin rouge'],
#  ['musical  films', 'rio'],
#  ['sound film sound film', ''],
#  ['however  colour', 'late  1950s'],
#  ['', 'pagal hai pagal pyaar'],
#  ['movie stars bollywood movie stars', '1990s'],
#  ['juvenile  stars', 'box - box office'],
#  ['american  films', 'greatly  aleksandrov'],
#  ['successful  blend', 'social  message'],
#  ['another', 'popular  films'],
#  ['music', 'singing'],
#  ['here  work', 'spectacle'],
#  ['other  director', 'musical  films'],
#  ['all', 'wife'],
#  ['it', 'most  type'],
#  ['short', 'term'],
#  ['they', 'film grants film grants'],
#  ['it', 'individual'],
#  ['', 'nation'],
#  ['short  comedies', 'typically  serial'],
#  ['animated  cartoons', 'short  subjects'],
#  ['short  films', 'student'],
#  ['they', 'also  period'],
#  ['animated  shorts', 'commercial  distribution'],
#  ['shortstv', 'short television films'],
#  ['such  movies', 'also  internet'],
#  ['it', 'film series it film series'],
#  ['juno rinaldi juno rinaldi', 'adult gretta adult gretta'],
#  ['ideally  we', 'march'],
#  ['part', 'only  kids'],
#  ['sophia lillis sophia lillis', 'jessica chastain jessica chastain'],
#  ['hall exterior town hall exterior', 'derry library derry library'],
#  ['visual  effects', 'atomic  studios'],
#  ['music', 'benjamin wallfisch benjamin wallfisch'],
#  ['it', ''],
#  ['it', 'film series it film series'],
#  ['juno rinaldi juno rinaldi', 'adult gretta adult gretta'],
#  ['ideally  we', 'march'],
#  ['part', 'only  kids'],
#  ['sophia lillis sophia lillis', 'jessica chastain jessica chastain'],
#  ['hall exterior town hall exterior', 'derry library derry library'],
#  ['visual  effects', 'atomic  studios'],
#  ['music', 'benjamin wallfisch benjamin wallfisch'],
#  ['it', ''],
#  ['feature film feature film', 'time'],
#  ['feature film feature film', 'kelly gang kelly gang'],
#  ['early  features', 'noteworthy style events'],
#  ['italian  features', 'last quo pompeii'],
#  ['1913', 'feature film feature film'],
#  ['songs', ''],
#  ['musical  score', 'incidental  stothart'],
#  ['h. cannon h. cannon', 'page outline page outline'],
#  ['part', 'betty jaynes betty jaynes'],
#  ['contract player contract player', 'frank morgan frank september'],
#  ['gale sondergaard gale sondergaard', 'wicked  witch'],
#  ['replacement', 'him'],
#  ['oz sequences oz sequences', 'strip technicolor strip technicolor'],
#  ['arnold gillespie arnold gillespie', 'effects director effects film'],
#  ['', 'tornado scene tornado scene'],
#  ['house', 'small  maquete'],
#  ['cowardly  costume', 'lion skin lion skin'],
#  ['film', 'musical  selections'],
#  ['haley', 'solo parts solo parts'],
#  ['musical  pieces', 'editing process editing process'],
#  ['this', 'ding - ding dong'],
#  ['witch', 'dialogue sequences dialogue sequences'],
#  ['sneak preview sneak preview', 'san bernardino san bernardino'],
#  ['film', 'nationwide  august'],
#  ['it', 'warner bros warner bros'],
#  ['restoration job restoration job', 'focus world focus world'],
#  ['film', 'ultra  hd'],
#  ['2d  version', 'g rating g rating'],
#  ['seven snow dwarfs', 'fantastic  half'],
#  ['film daily film daily', 'parser - parser hidden;margin:1em'],
#  ['major  differences', 'original  book'],
#  ['it', 'james franco james franco'],
#  ['it', 'critical  reception'],
#  ['costume designer costume designer', 'final  design'],
#  ['film version film version', '1982'],
#  ['example', 'police story police story'],
#  ['genre', ''],
#  ['other  examples', 'gunga jumna gunga jumna'],
#  ['they', 'word play word lines'],
#  ['examples', 'angry  men'],
#  ['it', 'sayuthi temat revalina sayuthi temat'],
#  ['rika', 'actor surya actor surya'],
#  ['meanwhile  surya', 'doni   doni affections'],
#  ['individual  characters', 'people bramantyo people bramantyo'],
#  ['film', ''],
#  ['bramantyo', 'cast members cast members'],
#  ['movie musicals movie musicals', 'made  tv'],
#  ['it', 'movie'],
#  ['principal  photography', 'june'],
#  ['first  trailer', 'day  november'],
#  ['final  trailer', 'march'],
#  ['north america north maleficent', 'north america north america'],
#  ['opening weekends opening weekends', 'china'],
#  ['film', 'however  amount'],
#  ['everyone', 'even  presence'],
#  ['it', 'agency'],
#  ['it', 'power'],
#  ['we', 'very  rape'],
#  ['principal  photography', 'august'],
#  ['godfrey reggio director godfrey reggio',
#   'philip glass composer philip music'],
#  ['artistic  merits', 'film music film music'],
#  ['production music production music', 'media producers media producers'],
#  ['us library us library', '250,000  tracks'],
#  ['she', 'strength'],
#  ['garland stops garland zellweger', 'film'],
#  ['she', 'tear'],
#  ['examples', 'killers'],
#  ['this', 'war'],
#  ['title', 'cynical  image'],
#  ['', 'unfortunately  mr'],
#  ['sala   sala we', 'seriously  release'],
#  ['film', 'temporarily  brazil'],
#  ['2012  decision', '5  july'],
#  ['dragan  bjelogrlić', 'film'],
#  ['that', 'something'],
#  ['i', 'it'],
#  ['you', 'serbian  film'],
#  ['i', 'conscience'],
#  ['nota', 'anand shankar anand shankar'],
#  ['film', 'box office box office'],
#  ['', 'game designer video game uk'],
#  ['he', 'house arrest house arrest'],
#  ['varun', 'name rowdy name rowdy'],
#  ['day  she', 'sleeping pills sleeping pills'],
#  ['dam', 'many  lives'],
#  ['vinothan', 'heated  argument'],
#  ['emotional  drama', 'characters'],
#  ['film', 'box office box office'],
#  ['i', 's. shankar s. shankar'],
#  ['soundtrack  score', 'r. rahman a. r. rahman'],
#  ['production design production design', 't. muthuraj t. muthuraj'],
#  ['principal  photography', 'july'],
#  ['main  ambition', 'lingesan  chennai'],
#  ['he', 'diya'],
#  ['well  lingesan', 'diya'],
#  ['diya', 'lingesan  truth'],
#  ['he', 'modelling'],
#  ['eventually body he', 'face'],
#  ['he', 'then  them'],
#  ['they', 'secluded  life'],
#  ['stunt direction stunt direction', 'anl arasu anl arasu'],
#  ['prosthetic  makeup', 'christien tinsley christien tinsley'],
#  ['later  name', 'chopra'],
#  ['film', '14  january'],
#  ['she', 'experience'],
#  ['media rights media rights', 'satellite rights satellite rights'],
#  ['net  collections', 'crores'],
#  ['', 'kanittha kwanyu kanittha kwanyu'],
#  ['atlee kumar atlee kumar', 'film industry tamil film industry'],
#  ['', 'tamil film tamil 2016'],
#  ['atlee kumar atlee kumar', 'film industry tamil film industry'],
#  ['', 'tamil film tamil 2016'],
#  ['film festivals film festivals', 'films'],
#  ['festivals', 'film - film maker'],
#  ['film festivals film festivals', 'world'],
#  ['film festival venice film festival', 'film festival film world'],
#  ['film festival film festival', 'film festival sydney film festival'],
#  ['film festival film festival', 'film festival yorkton film 1947'],
#  ['film festival sundance film festival', 'film festival york film festival'],
#  ['film festival arbor film festival', '1963'],
#  ['film festival film festival', 'uk'],
#  ['film festivals film festivals', 'issues/  subjects'],
#  ['festivals', 'mainstream  films'],
#  ['examples', 'film festivals film festivals'],
#  ['', 'john thimothy john thimothy'],
#  ['hot  docs', 'paul jay filmmaker paul jay'],
#  ['film festival whistler film festival', '80  screenings'],
#  ['film festival film festival', 'film festival film mexico'],
#  ['it', 'film festival film chile'],
#  ['focus', 'american cinema american cinema'],
#  ['film festivals film festivals', 'exclusively  animation'],
#  ['notable  festivals', 'film festival international film festival'],
#  ['they', 'film festivals film world'],
#  ['franchise', 'short  films'],
#  ['it', 'universal  pictures'],
#  ['final  films', '2020'],
#  ['', 'car culture car culture'],
#  ['weta digital company weta digital', 'likeness'],
#  ['ultimately  film', 'april'],
#  ['cast', 'ghost hologram ghost hologram'],
#  ['parkour athletes parkour athletes', 'drivers'],
#  ['following  list', 'website'],
#  ['game', 'mixed  reviews'],
#  ['models', 'eric tscherne designer eric tscherne'],
#  ['franchise', 'short  films'],
#  ['it', 'universal  pictures'],
#  ['final  films', '2020'],
#  ['', 'car culture car culture'],
#  ['weta digital company weta digital', 'likeness'],
#  ['ultimately  film', 'april'],
#  ['cast', 'ghost hologram ghost hologram'],
#  ['parkour athletes parkour athletes', 'drivers'],
#  ['following  list', 'website'],
#  ['game', 'mixed  reviews'],
#  ['models', 'eric tscherne designer eric tscherne'],
#  ['voting system voting system', '1956'],
#  ['filmfare awards filmfare awards', 'first  1954'],
#  ['choice award choice award', 'short  film'],
#  ['so  ceremony', 'next  year'],
#  ['two  reasons', 'change'],
#  ['theme', 'hundred  future'],
#  ['', ''],
#  ['voting system voting system', '1956'],
#  ['filmfare awards filmfare awards', 'first  1954'],
#  ['choice award choice award', 'short  film'],
#  ['so  ceremony', 'next  year'],
#  ['two  reasons', 'change'],
#  ['theme', 'hundred  future'],
#  ['', ''],
#  ['batman series batman series', 'north america north america'],
#  ['film', 'cave'],
#  ['johnny duncan johnny duncan', 'robin'],
#  ['film', 'leslie'],
#  ['late  popularity', 'late  1970s'],
#  ['holden', '1981'],
#  ['nine  rewrites', 'separate  writers'],
#  ['final  salary', '50 million 50 million'],
#  ['rewrites', 'charles warren gems'],
#  ['filming', 'warner bros warner bros'],
#  ['film', 'more  money'],
#  ['arnold schwarzenegger arnold schwarzenegger', 'mr'],
#  ['then  idea', ''],
#  ['he', 'warner bros warner bros'],
#  ['aronofsky', 'franchise'],
#  ['joss whedon joss whedon', 'december'],
#  ['it', 'also  no'],
#  ['knight rises knight rises', 'batman trilogy batman trilogy'],
#  ['anne hathaway anne hathaway', 'selina kyle selina kyle'],
#  ['charles roven charles roven', 'also  film'],
#  ['history', 'killer croc killer croc'],
#  ['film', 'early  2019'],
#  ['calotype process calotype process', 'paper negatives paper negatives'],
#  ['roll film plastic roll film', '1889'],
#  ['it', 'flammable  nitrocellulose'],
#  ['photographic  plates', 'only  blue'],
#  ['however  all', 'these'],
#  ['color film color film', 'plate product glass plate 1907'],
#  ['it', 'snapshot use snapshot use'],
#  ['film', '278  patents'],
#  ['photographic  lenses', 'film'],
#  ['this', 'color film color film'],
#  ['filters', 'film types film types'],
#  ['subject matter subject matter', 'heavy  exposure'],
#  ['automatic  cameras', 'average  density'],
#  ['naming  standard', 'standards authority russian standards authority'],
#  ['film speeds film speeds', 'iso'],
#  ['expensive  lenses', 'quartz'],
#  ['apochromatic  lenses', 'sometimes  spectrum'],
#  ['', 'mm filmkodak mm filmkodak'],
#  ['first  thriller', 'london fog london fog'],
#  ['film', 'bond films james bond films'],
#  ['action scenes action scenes', 'thriller genre thriller genre'],
#  ['such  films', 'silver streak silver streak'],
#  ['such  films', 'rather  policeman'],
#  ['central  topics', 'killers  murders'],
#  ['genre', 'late  1970s'],
#  ['examples', 'pelican  brief'],
#  ['other  examples', 'tall  man'],
#  ['sometimes  protagonist', 'psychic  ability'],
#  ['examples', 'thirteenth  floor'],
#  ['loft', 'van looy erik van looy'],
#  ['', ''],
#  ['he', 'ann'],
#  ['', 'july'],
#  ['loft', 'negative  reviews'],
#  ['brief  saruman', 'gandalf'],
#  ['bilbo', 'sting'],
#  ['fellowship', 'uruk - uruk hai'],
#  ['', 'aragorn  die'],
#  ['gandalf', 'defeated  palantír'],
#  ['sauron', 'capital minas capital minas'],
#  ['gollum', 'frodo  chasm'],
#  ['fellowship', 'ring'],
#  ['peter jackson peter we', 'it'],
#  ['jackson', 'production company film production company'],
#  ['jackson', 'new zealand new zealand'],
#  ['2009  dispute', '8  september'],
#  ['video games video games', 'film series film series'],
#  ['aladdin', 'disney pictures walt disney pictures'],
#  ['aladdin', 'new  life'],
#  ['numan acar numan acar', 'hakim'],
#  ['prince', '1000  dancers'],
#  ['cgi scenes cgi scenes', 'better  notices'],
#  ['international  openings', 'china'],
#  ['you', 'original  film'],
#  ['film', 'july'],
#  ['film', 'may'],
#  ['film', 'may'],
#  ['film', 'may'],
#  ['film', 'june'],
#  ['james mangold james mangold', 'later  film'],
#  ['mark bomback mark bomback', 'then  script'],
#  ['film', 'july'],
#  ['screenplay', 'kinberg'],
#  ['tim miller specialist tim miller', 'april'],
#  ['film', 'february'],
#  ['film', 'may'],
#  ['superheroes', 'risky  missions'],
#  ['additional  filming', 'august'],
#  ['film', 'june'],
#  ['records', 'three  films'],
#  ['morris', 'men'],
#  ['two  films', 'cerebral  tone'],
#  ['later  zombie', 'white zombie white zombie'],
#  ['studio album studio album', 'united states united states'],
#  ['studio album studio album', 'earlier  recordings'],
#  ['he', 'regeneration vendor rat regeneration vendor'],
#  ['live  shows', 'rock theatricality shock rock theatricality'],
#  ['he', 'robert  cummings'],
#  ['younger  brother', 'band powerman band powerman'],
#  ['zombie', 'album rob album rob'],
#  ['studio album studio album', 'sinister  november'],
#  ['second  single', 'single  feel'],
#  ['film', 'theatrically  april'],
#  ['album', 'educated  march'],
#  ['film', 'grossing  date'],
#  ['ii', 'august'],
#  ['series', 'comic  book'],
#  ['hellbilly  deluxe', '2  february'],
#  ['tour', 'officially  december'],
#  ['we', 'plan'],
#  ['album', 'april'],
#  ['album', 'selling album selling date'],
#  ['album', 'april'],
#  ['zombie', 'seriously  heaviest'],
#  ['film', 'release date release date'],
#  ['he', 'white zombie white zombie'],
#  ['later  zombie', 'white zombie white zombie'],
#  ['studio album studio album', 'united states united states'],
#  ['studio album studio album', 'earlier  recordings'],
#  ['he', 'regeneration vendor rat regeneration vendor'],
#  ['live  shows', 'rock theatricality shock rock theatricality'],
#  ['he', 'robert  cummings'],
#  ['younger  brother', 'band powerman band powerman'],
#  ['zombie', 'album rob album rob'],
#  ['studio album studio album', 'sinister  november'],
#  ['second  single', 'single  feel'],
#  ['film', 'theatrically  april'],
#  ['album', 'educated  march'],
#  ['film', 'grossing  date'],
#  ['ii', 'august'],
#  ['series', 'comic  book'],
#  ['hellbilly  deluxe', '2  february'],
#  ['tour', 'officially  december'],
#  ['we', 'plan'],
#  ['album', 'april'],
#  ['album', 'selling album selling date'],
#  ['album', 'april'],
#  ['zombie', 'seriously  heaviest'],
#  ['film', 'release date release date'],
#  ['he', 'white zombie white zombie'],
#  ['parties', 'deal  contracts'],
#  ['step', 'actually  film'],
#  ['actors', 'call times call times'],
#  ['take', 'then  everyone'],
#  ['camera operator camera camera', 'camera operator camera operator'],
#  ['video  film', 'film editor film editor'],
#  ['visual computer effects', 'digitally  artist'],
#  ['film', 'required  exhibition'],
#  ['parties', 'deal  contracts'],
#  ['step', 'actually  film'],
#  ['actors', 'call times call times'],
#  ['take', 'then  everyone'],
#  ['camera operator camera camera', 'camera operator camera operator'],
#  ['video  film', 'film editor film editor'],
#  ['visual computer effects', 'digitally  artist'],
#  ['film', 'required  exhibition'],
#  ['bbfc', 'verification scheme verification scheme'],
#  ['local  authorities', 'films'],
#  ['12a certificate 12a certificate', 'bourne identity bourne identity'],
#  ['turnover', 'vacancies website job vacancies website'],
#  ['bbfc', 'video games video games'],
#  ['bbfc  guidelines', '4–5  years'],
#  ['consultation', 'march'],
#  ['bbfc', 'following  certificates'],
#  ['they', 'licensed  cinemas'],
#  ['language film language film', 'award'],
#  ['film award language film it', 'film award language film award'],
#  ['animated  films', 'also  category'],
#  ['film', 'nomination'],
#  ['one  film', 'country'],
#  ['paradise', 'film award language film award'],
#  ['such  films', 'underground  channels'],
#  ['pornographic  films', 'softcore  pornography'],
#  ['it', 'sexual  activity'],
#  ['two', 'earliest  pioneers'],
#  ['gyrating', 'earliest  films'],
#  ['however  none', 'pornographic  films'],
#  ['entrepreneurs', 'demand'],
#  ['term glamour term glamour', 'modeling  photography'],
#  ['sex films sex films', 'european continent european continent'],
#  ['debbie', 'dallas'],
#  ['nothing', 'this'],
#  ['it', 'industry publications industry publications'],
#  ['film studios film studios', 'also  houston'],
#  ['traditionally  audience', 'pornographic  films'],
#  ['most  actors', 'certain  genres'],
#  ['they', 'normally  jewellery'],
#  ['annie', 'group member support group member'],
#  ['first  you', 'bloody  head'],
#  ['', 'sundance institute sundance institute'],
#  ['film festival sundance film festival', '24  february'],
#  ['it', 'van wagenen sterling van wagenen'],
#  ['capra  award', 'jimmy stewart jimmy stewart'],
#  ['robert redford robert who', 'actor'],
#  ['london festival sundance london festival', 'maker jaguar maker jaguar'],
#  ['2018  events', 'same  venue'],
#  ['war', 'siddharth anand siddharth anand'],
#  ['vaani kapoor vaani kapoor', 'lead  role'],
#  ['who', 'south korea south korea'],
#  ['themes', 'sanchit balhara sanchit balhara'],
#  ['india', 'today  it'],
#  ['it', 'bollywood films bollywood films'],
#  ['production companies film production companies', 'all  world'],
#  ['technical  improvements', 'sound recording sound recording'],
#  ['movies', 'victorian art age'],
#  ['technical  problems', '1923'],
#  ['film', 'painted  slides'],
#  ['first  films', 'device'],
#  ['technique', 'film scrooge film ghost'],
#  ['james williamson james attack', 'mission station china mission station'],
#  ['films', 'scenes'],
#  ['films', 'proper  plots'],
#  ['he', 'silent  films'],
#  ['jacksonville', 'film industry american film industry'],
#  ['film company film company', 'different  approach'],
#  ['trend', 'italy'],
#  ['percy smith f. percy smith',
#   'documentary pioneer nature documentary charles'],
#  ['film companies film companies', '1912'],
#  ['film industry film industry', 'danish  industry'],
#  ['important  man', 'cinema chain cinema chain'],
#  ['khanzhonkov company khanzhonkov company', 'so film 1918'],
#  ['i', 'éclair company éclair company'],
#  ['exhibition venues exhibition venues', 'higher  prices'],
#  ['biggest  success', 'years'],
#  ['', 'wark griffith wark nation'],
#  ['film industry film industry', 'seriously  war'],
#  ['this', 'floodlights'],
#  ['shaped  slits', 'vertical  apertures'],
#  ['new  idea', 'still  photography'],
#  ['untitled  film', 'raymond turner edward raymond turner'],
#  ['technicolor technique technicolor technique', 'subsequently  1916'],
#  ['propaganda films propaganda films', 'desperate  journey'],
#  ['it', 'greatest  time'],
#  ['gimmicks', 'also  audiences'],
#  ['disney', 'peter pan peter beauty'],
#  ['limelight', 'interesting  respect'],
#  ['', 'samurai   samurai blood'],
#  ['hidden  fortress', 'star wars star wars'],
#  ['series', '1962'],
#  ['bonnie', 'new  hollywood'],
#  ['classical  cinema', 'hollywood producers hollywood producers'],
#  ['jeet kune jeet kune', 'style'],
#  ['indian  film', 'time'],
#  ['camera system camera system', 'spy kids spy kids'],
#  ['silent  film', 'recorded  sound'],
#  ['pianists', 'sheet music sheet music'],
#  ['silent  film', 'retroactively  something'],
#  ['town  theatres', 'usually  pianist'],
#  ['', 'groundbreaking w. nation'],
#  ['film  acting', 'day audiences day audiences'],
#  ['vaudeville', 'film actors film actors'],
#  ['', 'silent  films'],
#  ['frame', 'times  screen'],
#  ['', 'bladed era shutters'],
#  ['red', 'mysterious  atmosphere'],
#  ['early  studios', 'city area york city area'],
#  ['others films others films', 'fort lee fort lee'],
#  ['amounts', 'gross  gross'],
#  ['', 'de heer rolf de heer'],
#  ['stage plays stage plays', 'film styles film styles'],
#  ['blancanieves', 'pablo berger pablo berger'],
#  ['short  that', 'film comedies film comedies'],
#  ['sheep', 'positive  reviews'],
#  ['aardman animations aardman animations', 'also  morph'],
#  ['film', 'year'],
#  ['early  forms', 'motion pictures motion pictures'],
#  ['color television color television', 'more  u.s'],
#  ['colour photography colour photography', 'inaccurate  hues'],
#  ['color photography color photography', 'mid-20th century mid-20th century'],
#  ['sometimes  color', 'cover'],
#  ['school yearbooks school yearbooks', 'entirely  black'],
#  ['early  forms', 'motion pictures motion pictures'],
#  ['color television color television', 'more  u.s'],
#  ['colour photography colour photography', 'inaccurate  hues'],
#  ['color photography color photography', 'mid-20th century mid-20th century'],
#  ['sometimes  color', 'cover'],
#  ['school yearbooks school yearbooks', 'entirely  black'],
#  ['it', 'film series it film series'],
#  ['wyatt oleff wyatt oleff', 'stephen bogaert stephen roles'],
#  ['it', 'horror film horror time'],
#  ['kajganich', 'warner bros warner bros'],
#  ['now  they', 'scary  clown'],
#  ['it', 'all  core'],
#  ['i', 'different  approach'],
#  ['kids', 'really  bill'],
#  ['it', 'alexa xt arri alexa xt'],
#  ['look', 'lenses'],
#  ['he', 'natural  look'],
#  ['it', 'like  quality'],
#  ['so  i', 'away  it'],
#  ['it', 'just  sync'],
#  ['overall  response', 'face'],
#  ['internationally  film', '10,560  screens'],
#  ['hollywood reporter hollywood reporter', ''],
#  ['feeling skarsgård feeling performance', 'awards season awards season'],
#  ['clown', 'bill skarsgård bill nightmares'],
#  ['ideally  we', 'march'],
#  ['part', 'only  kids'],
#  ['cinema historians cinema historians', 'category'],
#  ['sensibility', 'warner bros warner bros'],
#  ['falcon   falcon glass', ''],
#  ['one', 'others'],
#  ['it', 'british century subsidiary'],
#  ['film genre film genre', 'cold  war'],
#  ['black christopher debut', 'classic  noir'],
#  ['', ''],
#  ['', 'implacable groundstar conspiracy investigator'],
#  ['film noir film noir', 'many  manners'],
#  ['dead carl men', ''],
#  ['noir parodies noir parodies', 'darker  tones'],
#  ['final  act', 'parodic  strain'],
#  ['still  others', 'mood'],
#  ['survey', 'identifying  characteristics'],
#  ['faces', 'partially  darkness'],
#  ['', 'hollywood filmmaking hollywood filmmaking'],
#  ['robert montgomery robert montgomery', 'only  mirrors'],
#  ['', 'different  ways'],
#  ['archetypal  characters', 'film noirs film noirs'],
#  ['bars', 'frequently gambling action'],
#  ['soundtrack', 'vidyasagar'],
#  ['film', 'box office box office'],
#  ['camera film camera film', 'standard  perforations'],
#  ['135  film', 'emulsion types emulsion types'],
#  ['perforation size perforation size',
#   'specification ks-1870 specification ks-1870'],
#  ['this', '38.00  mm'],
#  ['exposure rolls exposure rolls', 'daily  press'],
#  ['mm exposures mm exposures', '1914'],
#  ['23 daylight loading mm', 'stereo format stereo format'],
#  ['', 'kine exakta kine 1936'],
#  ['gods', 'łukasz palkowski łukasz palkowski'],
#  ['afi', 'private  funding'],
#  ['prior  leaders', 'george stevens director george stevens'],
#  ['training program film training program',
#   'afi conservatory afi conservatory'],
#  ['first  class', 'filmmakers'],
#  ['richard gladstein producer richard gladstein', 'july'],
#  ['afi catalog afi catalog', '1968'],
#  ['afi awards afi awards', 'outstanding  films'],
#  ['awards', 'competitive  excellence'],
#  ['', 'market partner market fest'],
#  ['additional  sponsors', 'american airlines american airlines'],
#  ['', 'documentary festival documentary washington'],
#  ['festival', 'documentary enthusiasts documentary enthusiasts'],
#  ['silver theatre silver center', 'silver image spring'],
#  ['defeat brixton defeat who', 'afterwards  director'],
#  ['group', 'victory'],
#  ['pelenise tuisano lori pelenise tuisano', 'sefina hobbs sefina hobbs'],
#  ['', 'portray luke portray cousins'],
#  ['character', 'future  film'],
#  ['most  filming', 'shepperton studios shepperton studios'],
#  ['', 'officially  january'],
#  ['same  method', 'mclaren'],
#  ['idris elba idris elba', 'human  abilities'],
#  ['finally  they', 'destruction'],
#  ['latter', 'cyber  clearangle'],
#  ['second  trailer', 'april'],
#  ['final  trailer', 'june'],
#  ['3d conversion reald 3d conversion', 'film'],
#  ['defeat brixton defeat who', 'afterwards  director'],
#  ['group', 'victory'],
#  ['pelenise tuisano lori pelenise tuisano', 'sefina hobbs sefina hobbs'],
#  ['', 'portray luke portray cousins'],
#  ['character', 'future  film'],
#  ['most  filming', 'shepperton studios shepperton studios'],
#  ['', 'officially  january'],
#  ['same  method', 'mclaren'],
#  ['idris elba idris elba', 'human  abilities'],
#  ['finally  they', 'destruction'],
#  ['latter', 'cyber  clearangle'],
#  ['second  trailer', 'april'],
#  ['final  trailer', 'june'],
#  ['3d conversion reald 3d conversion', 'film'],
#  ['film', 'long  camera'],
#  ['films', 'scenes'],
#  ['many  directors', 'artistic  bond'],
#  ['', 'montage   montage technique'],
#  ['classic  examples', 'rocky'],
#  ['two  shots', 'tone value tone value'],
#  ['assistant  editors', 'visual  work'],
#  ['budget features budget features', 'one  assistant'],
#  ['aspects job aspects job', 'database management database management'],
#  ['assistant editing assistant editing', 'career path career path'],
#  ['avn awards avn awards', 'magazine avn trade magazine avn'],
#  ['they', 'porn'],
#  ['xrco awards xrco awards', 'critics organization critics organization'],
#  ['arcade attractions penny arcade attractions', 'topless  women'],
#  ['casey donovan casey donovan', 'pornographic  hit'],
#  ['they', 'commonly  20s'],
#  ['a', 'boxcover'],
#  ['she', 'power'],
#  ['five  she', 'phone calls phone calls'],
#  ['she', 'phone calls phone calls'],
#  ['you', 'gangbangs'],
#  ['they', 'phone call phone call'],
#  ['so  it', 'anal girl toy'],
#  ['most  actresses', 'adult industry adult industry'],
#  ['they', 'anyone'],
#  ['contract girls contract girls', '$  60,000'],
#  ['average  male', '$  40,000'],
#  ['claims', 'health authorities health authorities'],
#  ['breakdown voltage breakdown voltage', 'dielectric  films'],
#  ['this', 'current  rating'],
#  ['film', 'less  material'],
#  ['film capacitors film capacitors',
#   'foil construction metal foil construction'],
#  ['foil capacitors metal foil capacitors', 'healing  properties'],
#  ['special  type', 'mku capacitors mku capacitors'],
#  ['characteristics', 'film materials film materials'],
#  ['they', 'metallized  wound'],
#  ['table', 'smaller capacitance 50'],
#  ['they', 'metallized  wound'],
#  ['they', 'metallized  types'],
#  ['they', 'metallized  types'],
#  ['absorption performance dielectric absorption performance',
#   'dielectric  capacitors'],
#  ['ptfe', 'trademark teflon dupont trademark teflon'],
#  ['wound', ''],
#  ['film capacitors series film capacitors', '2012'],
#  ['film capacitor film capacitor', 'kapton capacitorcl11 kapton dhgate'],
#  ['iec standards iec standards', 'european  standards'],
#  ['many  manufacturers', 'standard  abbreviations'],
#  ['capacitance tolerance capacitance tolerance', 'particular  application'],
#  ['derating  factors', 'voltages'],
#  ['peak value peak value', 'alternating voltage alternating voltage'],
#  ['film capacitors film capacitors', 'alternating  voltage'],
#  ['capacitors', 'effect'],
#  ['', 'capacitor \n capacitor s'],
#  ['dissipation factor dissipation factor', 'film capacitors film capacitors'],
#  ['film capacitors film capacitors', 'aging  processes'],
#  ['main  advantages', 'film capacitors film capacitors'],
#  ['', 'capacitor construction esr capacitor construction'],
#  ['important  criteria', 'application'],
#  ['snubber capacitors snubber capacitors',
#   'construction features construction features'],
#  ['ac  capacitors', ''],
#  ['discharge capacitors discharge capacitors', 'current  surges'],
#  ['power capacitors power capacitors', 'physical  dimensions'],
#  ['most  animations', 'generated  imagery'],
#  ['animation', 'technology interfaces information technology interfaces'],
#  ['little winsor nemo', 'detailed  drawings'],
#  ['', 'cutout animation cutout animation'],
#  ['terrytoons', 'tom terrific tom terrific'],
#  ['animation market animation market', '2008'],
#  ['today  drawings', 'computer system computer system'],
#  ['3d  animation', 'digitally  animator'],
#  ['animator', 'polygon mesh polygon mesh'],
#  ['traits', 'live  action'],
#  ['list', 'awardees'],
#  ['most  animations', 'generated  imagery'],
#  ['animation', 'technology interfaces information technology interfaces'],
#  ['little winsor nemo', 'detailed  drawings'],
#  ['', 'cutout animation cutout animation'],
#  ['terrytoons', 'tom terrific tom terrific'],
#  ['animation market animation market', '2008'],
#  ['today  drawings', 'computer system computer system'],
#  ['3d  animation', 'digitally  animator'],
#  ['animator', 'polygon mesh polygon mesh'],
#  ['traits', 'live  action'],
#  ['list', 'awardees'],
#  ['area', 'jubilee hills jubilee hills'],
#  ['train station train station', 'hitec  city'],
#  ['film cameras film roll', 'film cameras film cameras'],
#  ['where  film', 'advantages'],
#  ['imaging systems imaging systems', 'cost emphases cost emphases'],
#  ['digital  cameras', 'film equivalents film equivalents'],
#  ['prices', 'intense  competition'],
#  ['', 'giacomo ciarrapico giacomo ciarrapico'],
#  ['it', 'series boris television series boris'],
#  ['schwarzenegger', 'later  role'],
#  ['story', 'miller'],
#  ['', 'script'],
#  ['she', 'harder  anybody'],
#  ['supervisor neil effects supervisor neil', 'set  piece'],
#  ['', 'october'],
#  ['certain  scenes', 'rated  violence'],
#  ['it', 'internet comments internet comments'],
#  ['theatrical  trailers', 'august'],
#  ['game', 'september'],
#  ['t-800 model t-800 model', 'mortal  kombat'],
#  ['schwarzenegger', 'later  role'],
#  ['story', 'miller'],
#  ['', 'script'],
#  ['she', 'harder  anybody'],
#  ['supervisor neil effects supervisor neil', 'set  piece'],
#  ['', 'october'],
#  ['certain  scenes', 'rated  violence'],
#  ['it', 'internet comments internet comments'],
#  ['theatrical  trailers', 'august'],
#  ['game', 'september'],
#  ['t-800 model t-800 model', 'mortal  kombat'],
#  ['suspense', 'plot element plot element'],
#  ['mystery films mystery films', 'mainly  crime'],
#  ['women', 'films'],
#  ['mystery films mystery films', 'silent  era'],
#  ['film', 'more  1953'],
#  ['two  films', 'now  1909'],
#  ['story', 'again  1993'],
#  ...]

# %% [markdown]
# clean the entity pairs..

# %% [markdown]
# #### Relation / Predicate Extraction

# %% [markdown]
# This is going to be a very interesting aspect of this article. Our hypothesis is that the predicate is actually the main verb in a sentence.

# %% [markdown]
# The function below is capable of capturing such predicates from the sentences. Here, I have used spaCy’s rule-based matching

# %%
sent= "The 22-year-old recently won ATP Challenger tournament."

# %%
def get_relation(sent):
    
    doc = nlp(sent)
    
    # Matcher class object 
    matcher = Matcher(nlp.vocab)
    
    #define the pattern 
    pattern = [{'DEP':'ROOT'}, 
               {'DEP':'prep','OP':"?"},
               {'DEP':'agent','OP':"?"},  
               {'POS':'ADJ','OP':"?"}] 
    
    matcher.add("matching_1", [pattern]) 
    matches = matcher(doc)
    
    k = len(matches) - 1
    
    span = doc[matches[k][1]:matches[k][2]] 
    
    return(span)

# %%
get_relation(sent)
# Out:
# won

# %%
#get_relation("John completed the task")

# %%
relations = [get_relation(i) for i in tqdm(candidate_sentences['sentence'])]
# Out:
#   0%|                                                  | 0/4318 [00:00<?, ?it/s]
#
#
#   0%|                                        | 11/4318 [00:00<00:41, 102.94it/s]
#
#
#   1%|▏                                       | 23/4318 [00:00<00:39, 109.16it/s]
#
#
#   1%|▎                                       | 34/4318 [00:00<00:40, 106.26it/s]
#
#
#   1%|▍                                       | 46/4318 [00:00<00:39, 109.24it/s]
#
#
#   1%|▌                                       | 57/4318 [00:00<00:39, 106.88it/s]
#
#
#   2%|▋                                       | 68/4318 [00:00<00:40, 104.60it/s]
#
#
#   2%|▋                                       | 79/4318 [00:00<00:40, 104.43it/s]
#
#
#   2%|▊                                       | 91/4318 [00:00<00:39, 106.29it/s]
#
#
#   2%|▉                                      | 103/4318 [00:00<00:38, 109.76it/s]
#
#
#   3%|█                                      | 115/4318 [00:01<00:38, 109.85it/s]
#
#
#   3%|█▏                                     | 126/4318 [00:01<00:39, 106.38it/s]
#
#
#   3%|█▏                                     | 137/4318 [00:01<00:40, 104.19it/s]
#
#
#   3%|█▎                                     | 148/4318 [00:01<00:41, 100.21it/s]
#
#
#   4%|█▍                                      | 159/4318 [00:01<00:42, 97.33it/s]
#
#
#   4%|█▌                                      | 169/4318 [00:01<00:42, 97.11it/s]
#
#
#   4%|█▋                                      | 179/4318 [00:01<00:43, 94.34it/s]
#
#
#   4%|█▊                                      | 189/4318 [00:01<00:43, 94.86it/s]
#
#
#   5%|█▊                                      | 200/4318 [00:01<00:42, 97.00it/s]
#
#
#   5%|█▉                                      | 211/4318 [00:02<00:41, 99.13it/s]
#
#
#   5%|██                                     | 222/4318 [00:02<00:40, 101.14it/s]
#
#
#   5%|██                                     | 233/4318 [00:02<00:39, 102.99it/s]
#
#
#   6%|██▏                                    | 244/4318 [00:02<00:39, 103.14it/s]
#
#
#   6%|██▎                                    | 255/4318 [00:02<00:39, 103.18it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_54206/1981568529.py in <module>
# ----> 1 relations = [get_relation(i) for i in tqdm(candidate_sentences['sentence'])]
#
# /tmp/ipykernel_54206/1981568529.py in <listcomp>(.0)
# ----> 1 relations = [get_relation(i) for i in tqdm(candidate_sentences['sentence'])]
#
# /tmp/ipykernel_54206/2049241620.py in get_relation(sent)
#      17     k = len(matches) - 1
#      18
# ---> 19     span = doc[matches[k][1]:matches[k][2]]
#      20
#      21     return(span)
#
# IndexError: list index out of range
#   6%|██▎                                    | 255/4318 [00:17<00:39, 103.18it/s]

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_54206/2917381578.py in <module>
# ----> 1 pd.Series(relations).value_counts()[:50]
#
# NameError: name 'relations' is not defined

# %% [markdown]
# #### Build a Knowledge Graph

# %% [markdown]
# We will finally create a knowledge graph from the extracted entities (subject-object pairs) and the predicates (relation between entities).
#
# Let’s create a dataframe of entities and predicates

# %%
entity_pairs
# Out:
# [['connie', 'own'],
#  ['later  scream', 'distance'],
#  ['christian', 'then  elder'],
#  ['temple', 'fire'],
#  ['', 'cult wails cult him'],
#  ['it', 'religious  awakening'],
#  ['c. mackenzie c. mackenzie', 'craig vincent craig cast'],
#  ['di francia craig di francia', 'action bronson action cast'],
#  ['sebastian  maniscalco', 'later paul ben cast'],
#  ['we', 'just  film'],
#  ['we', 'tests'],
#  ['', 'sales rights sales rights'],
#  ['robbie robertson musician robbie robertson', 'soundtrack'],
#  ['it', 'music tracks music tracks'],
#  ['it', 'reviewed  franchise'],
#  ['she', 'accidentally  mystique'],
#  ['military  forces', 'arrest'],
#  ['train', 'vuk'],
#  ['', 'eberhardt portrays eberhardt portrays'],
#  ['singer', 'men'],
#  ['last  which', 'penn'],
#  ['jessica chastain jessica chastain', 'same  character'],
#  ['mauro fiore mauro fiore', 'cinematographer'],
#  ['filming', 'october'],
#  ['soundtrack', 'digitally  june'],
#  ['album', 'digitally  august'],
#  ['film', 'motion pictures studios motion pictures'],
#  ['it', '136.5 \xa0 136.5 million'],
#  ['film', ''],
#  ['it', 'yoshimitsu banno producer yoshimitsu banno'],
#  ['', 'former vivienne graham employee'],
#  ['monster zero awakens monster which', 'monarch members monarch .'],
#  ['madison', 'mythological  texts'],
#  ['joe morton joe morton', 'older  dr'],
#  ['godzilla', 'king ghidorah king themselves'],
#  ['when  dougherty', 'when  reaction'],
#  ['we', 'godzilla'],
#  ['only  mandate', 'monarch'],
#  ['ten  writers', 'treatment'],
#  ['script', 'year'],
#  ['dougherty', 'filming  production'],
#  ['film', 'this'],
#  ['it', 'big  dinosaurs'],
#  ['other  actors', 'body'],
#  ['scott chambliss designer scott chambliss', 'art directors art directors'],
#  ['single', 'may'],
#  ['tracks', 'bear mccreary bear mccreary'],
#  ['score', 'also  mccreary'],
#  ['poster  trailer', 'december'],
#  ['theatrical  poster', 'april'],
#  ['film', 'originally  june'],
#  ['collectible  tickets', 'two  sizes'],
#  ['4k  release', 'hdr10'],
#  ['retail  exclusives', 'clear  files'],
#  ['such  heroes', 'one  liners'],
#  ['it', 'fiction twist science fiction twist'],
#  ['action films action films', 'stunt work stunt work'],
#  ['examples', 'jones franchise indiana jones franchise'],
#  ['themes', 'horror films horror films'],
#  ['mall cop mall cop', 'recent  trend'],
#  ['they', ''],
#  ['both', 'many  roles'],
#  ['producer', 'also  production'],
#  ['finally  producer', 'marketing'],
#  ['line producer line producer', 'certain  cases'],
#  ['most  producers', 'college'],
#  ['film directors film directors', 'screenwriters'],
#  ['film directors film directors', 'film school film school'],
#  ['directors', 'different  approaches'],
#  ['directors', 'additional  roles'],
#  ['film schools film schools', 'sound  stages'],
#  ['degree course degree course', 'five  years'],
#  ['academy berlin academy berlin', 'tv station brandenburg tv station'],
#  ['', 'la  paris'],
#  ['film awards film awards', 'award ceremonies film award india'],
#  ['awards', 'first  1954'],
#  ['film awards film awards', 'main  categories'],
#  ['he', 'home  apartment'],
#  ['mass  riot', 'gotham'],
#  ['arthur', 'state hospital arkham state hospital'],
#  ['war dogs film war dogs', 'august'],
#  ['we', 'even  joker'],
#  ['then  we', 'that'],
#  ['pereira - dante pereira olson', 'douglas hodge douglas cast'],
#  ['it', 'warner bros warner bros'],
#  ['it', 'eye - eye me'],
#  ['i', 'it'],
#  ['they', 'it'],
#  ['i', 'it'],
#  ['they', 'it'],
#  ['film', 'samuel beckett samuel beckett'],
#  ['shooting script leaf shooting script', '22  may'],
#  ['beckett', 'zero director alan mostel'],
#  ['beckett', 'buster keaton buster keaton'],
#  ['this', 'united states united states'],
#  ['', ''],
#  ['', 'violently camera left'],
#  ['couple', 'other'],
#  ['camera', 'vestibule'],
#  ['camera', 'close - close up'],
#  ['she', 'fumbling  feet'],
#  ['she', 'eyes'],
#  ['coat tails coat tails', 'stairs'],
#  ['simply  mechanics', 'tasks'],
#  ['he', 'them'],
#  ['he', 'eye patch eye patch'],
#  ['he', 'chair'],
#  ['', 'aut percipere percipi aut percipere'],
#  ['he', 'away  himself'],
#  ['e', 'merely  person'],
#  ['e', ''],
#  ['script', 'various  ways'],
#  ['viewers', 'work'],
#  ['particular  beckett', 'particular  project'],
#  ['four  directors', 'series'],
#  ['he', 'book'],
#  ['david heyman david heyman', 'film'],
#  ['acting  experience', 'school plays school plays'],
#  ['barron', 'four  films'],
#  ['executive  producers', 'seghatchian  wigram'],
#  ['he', 'real  passion'],
#  ['directors', 'other'],
#  ['production designer production designer', 'eight  films'],
#  ['so  we', 'substantial  piece'],
#  ['potter series harry potter series', 'four  composers'],
#  ['desplat', 'harry potter harry potter'],
#  ['', '2  2011'],
#  ['they', 'trumps'],
#  ['director', 'last  time'],
#  ['harry potter harry potter', 'muggle  aunt'],
#  ['however  part', '2  2d'],
#  ['2017  johns', 'january'],
#  ['principal  photography', 'august'],
#  ['david ayer david ayer', 'director'],
#  ['', 'barry bruce allen'],
#  ['justice league justice league', 'worldwide  november'],
#  ['aquaman', 'october'],
#  ['production', 'august'],
#  ['mister mind villain mister mind', '- credits mid - scene'],
#  ['month  sequel', 'san diego san diego'],
#  ['production', 'early  december'],
#  ['pedro pascal pedro pascal', 'key  role'],
#  ['filming  locations', 'warner bros warner bros'],
#  ['wonder woman wonder woman', 'june'],
#  ['initial  script', 'michael green michael guggenheim'],
#  ['dan mazeau dan mazeau', 'writer'],
#  ['francis daley john francis daley', 'march'],
#  ['plot', 'force multiverse speed force multiverse'],
#  ['production', 'january'],
#  ['flash', 'sometime  2021'],
#  ['peter safran producer peter who', 'peter safran producer peter safran'],
#  ['production', '2020'],
#  ['aquaman', '2  december'],
#  ['suicide squad suicide squad', 'shortly  superman'],
#  ['2017  johns', 'january'],
#  ['principal  photography', 'august'],
#  ['david ayer david ayer', 'director'],
#  ['', 'barry bruce allen'],
#  ['justice league justice league', 'worldwide  november'],
#  ['aquaman', 'october'],
#  ['production', 'august'],
#  ['mister mind villain mister mind', '- credits mid - scene'],
#  ['month  sequel', 'san diego san diego'],
#  ['production', 'early  december'],
#  ['pedro pascal pedro pascal', 'key  role'],
#  ['filming  locations', 'warner bros warner bros'],
#  ['wonder woman wonder woman', 'june'],
#  ['initial  script', 'michael green michael guggenheim'],
#  ['dan mazeau dan mazeau', 'writer'],
#  ['francis daley john francis daley', 'march'],
#  ['plot', 'force multiverse speed force multiverse'],
#  ['production', 'january'],
#  ['flash', 'sometime  2021'],
#  ['peter safran producer peter who', 'peter safran producer peter safran'],
#  ['production', '2020'],
#  ['aquaman', '2  december'],
#  ['suicide squad suicide squad', 'shortly  superman'],
#  ['', 'two freddie kiss'],
#  ['they', 'minute slot minute slot'],
#  ['2011  production', 'april'],
#  ['whishaw', 'project'],
#  ['i', 'man'],
#  ['discussions', 'him'],
#  ['fletcher', 'producer credit producer credit'],
#  ['vinyl release vinyl release', '8  february'],
#  ['digital  version', ''],
#  ['instead  it', 'threatening  illness'],
#  ['it', 'north america north america'],
#  ['new  markets', 'france'],
#  ['it', 'south korea south korea'],
#  ['they', 'conclusions'],
#  ['horror', 'also  fantasy'],
#  ['prevalent  elements', 'ghosts'],
#  ['it', 'faust legend faust legend'],
#  ['this', 'trick films trick films'],
#  ['trick films trick films', 'special  effects'],
#  ["l'inferno", 'three  artists'],
#  ['series', 'surrealist movement surrealist movement'],
#  ['film', 'five  stories'],
#  ['it', 'german  expressionism'],
#  ['w. murnau f. w. murnau', 'themed  movie'],
#  ['it', 'novel dracula horror novel dracula'],
#  ['this', 'expressionism style expressionism style'],
#  ['they', 'expressionist movement expressionist movement'],
#  ['exaggerated  smile', 'dc  joker'],
#  ['film', 'poorly  audiences'],
#  ['', 'special morality effects'],
#  ['it', 'earlier  film'],
#  ['film', 'well  critics'],
#  ['assistant', 'abnormal  brain'],
#  ['first  one', 'rue morgue rue morgue'],
#  ['it', 'boris karloff boris karloff'],
#  ['first  one', 'july'],
#  ['it', 'blue mystery room'],
#  ['it', 'boris karloff boris karloff'],
#  ['it', 'six  movies'],
#  ['universal  pictures', 'iconic  actors'],
#  ['', 'ruric   ruric screenplay'],
#  ['horror film horror film', 'hit  frankenstein'],
#  ['elsa lanchester actress elsa lanchester', 'bride'],
#  ['he', 'writing'],
#  ['radiation effects radiation effects', 'slowly  him'],
#  ['daughter  gloria', 'title role title role'],
#  ['intervening  criticism', 'intervening  decades'],
#  ['film', 'boris karloff boris karloff'],
#  ['phantom  creeps', ''],
#  ['other  studios', 'lead'],
#  ['fright  factor', 'way'],
#  ['film director film director', 'film gimmick film gimmick'],
#  ['1950s', 'creature  feature'],
#  ['fly', 'vincent price vincent price'],
#  ['film', 'popular  culture'],
#  ['twilight zone phrase twilight zone', 'surreal  experiences'],
#  ['1970s', 'horror films horror films'],
#  ['italian  film', 'nicolas roeg nicolas roeg'],
#  ['murder', 'horror films horror films'],
#  ['poltergeist', 'critics association film critics association'],
#  ['changeling', 'peter medak peter medak'],
#  ['influence', 'still  films'],
#  ['', 'day fiction day fiction'],
#  ['first  shake', 'philippines'],
#  ['horror movies action horror movies', '1980s'],
#  ['horror film fantasy horror which', 'stan winston artist stan winston'],
#  ['', 'horror film fiction horror paul'],
#  ['monster horror monster horror', 'quite  1990s'],
#  ['tremors', 'first  tremors'],
#  ['', 'contrast'],
#  ['others', 'many  awards'],
#  ['it', 'alejandro'],
#  ['book adaptations book adaptations', 'blade series blade series'],
#  ['pronounced  trends', 'horror films horror films'],
#  ['films', 'language countries language countries'],
#  ['notable  film', 'spanish debut filmmaker'],
#  ['cold  prey', 'roar uthaug roar uthaug'],
#  ['others', 'horror film horror film'],
#  ['latter  film', 'sequel'],
#  ['', ''],
#  ['verónica', 'real horror events'],
#  ['death day death day', 'february'],
#  ['themes', 'horror films horror films'],
#  ['category', 'fantasy genre fantasy genre'],
#  ['horror events horror which', 'holiday  season'],
#  ['it', 'christmas'],
#  ['examples', 'all r house'],
#  ['examples', 'frankenstein'],
#  ['common  themes', 'vengeful  ghosts'],
#  ['examples', 'ring'],
#  ['genre', 'science fiction science fiction'],
#  ['examples', 'birds'],
#  ['it', 'most  1964'],
#  ['examples', 'friend request friend request'],
#  ['one', 'side effects side effects'],
#  ['horror films horror films', 'social  controversy'],
#  ['horror movies horror movies', 'positive  endings'],
#  ['comedy - comedy drama', 'love affair love affair'],
#  ['others', ''],
#  ['sometimes  portmanteau', 'words'],
#  ['military  comedies', 'good  morning'],
#  ['film', 'thin  coating'],
#  ['today  it', 'film commerce film commerce'],
#  ['it', 'simple  friends'],
#  ['1968  festival', '19  may'],
#  ['thierry frémaux thierry frémaux', '2007'],
#  ['festival', 'european  films'],
#  ['jill forbes jill forbes', 'european sarah cinema'],
#  ['however  curse', 'black  pearl'],
#  ['second  film', 'pictures logo disney pictures logo'],
#  ['roadshow  studios', 'filming port locations'],
#  ['suddenly  market', 'musicals'],
#  ['many  comedies', 'musical  numbers'],
#  ['', 'box - box office'],
#  ['chicago', 'first  oliver'],
#  ['', 'moulin rouge moulin rouge'],
#  ['musical  films', 'rio'],
#  ['sound film sound film', ''],
#  ['however  colour', 'late  1950s'],
#  ['', 'pagal hai pagal pyaar'],
#  ['movie stars bollywood movie stars', '1990s'],
#  ['juvenile  stars', 'box - box office'],
#  ['american  films', 'greatly  aleksandrov'],
#  ['successful  blend', 'social  message'],
#  ['another', 'popular  films'],
#  ['music', 'singing'],
#  ['here  work', 'spectacle'],
#  ['other  director', 'musical  films'],
#  ['all', 'wife'],
#  ['it', 'most  type'],
#  ['short', 'term'],
#  ['they', 'film grants film grants'],
#  ['it', 'individual'],
#  ['', 'nation'],
#  ['short  comedies', 'typically  serial'],
#  ['animated  cartoons', 'short  subjects'],
#  ['short  films', 'student'],
#  ['they', 'also  period'],
#  ['animated  shorts', 'commercial  distribution'],
#  ['shortstv', 'short television films'],
#  ['such  movies', 'also  internet'],
#  ['it', 'film series it film series'],
#  ['juno rinaldi juno rinaldi', 'adult gretta adult gretta'],
#  ['ideally  we', 'march'],
#  ['part', 'only  kids'],
#  ['sophia lillis sophia lillis', 'jessica chastain jessica chastain'],
#  ['hall exterior town hall exterior', 'derry library derry library'],
#  ['visual  effects', 'atomic  studios'],
#  ['music', 'benjamin wallfisch benjamin wallfisch'],
#  ['it', ''],
#  ['it', 'film series it film series'],
#  ['juno rinaldi juno rinaldi', 'adult gretta adult gretta'],
#  ['ideally  we', 'march'],
#  ['part', 'only  kids'],
#  ['sophia lillis sophia lillis', 'jessica chastain jessica chastain'],
#  ['hall exterior town hall exterior', 'derry library derry library'],
#  ['visual  effects', 'atomic  studios'],
#  ['music', 'benjamin wallfisch benjamin wallfisch'],
#  ['it', ''],
#  ['feature film feature film', 'time'],
#  ['feature film feature film', 'kelly gang kelly gang'],
#  ['early  features', 'noteworthy style events'],
#  ['italian  features', 'last quo pompeii'],
#  ['1913', 'feature film feature film'],
#  ['songs', ''],
#  ['musical  score', 'incidental  stothart'],
#  ['h. cannon h. cannon', 'page outline page outline'],
#  ['part', 'betty jaynes betty jaynes'],
#  ['contract player contract player', 'frank morgan frank september'],
#  ['gale sondergaard gale sondergaard', 'wicked  witch'],
#  ['replacement', 'him'],
#  ['oz sequences oz sequences', 'strip technicolor strip technicolor'],
#  ['arnold gillespie arnold gillespie', 'effects director effects film'],
#  ['', 'tornado scene tornado scene'],
#  ['house', 'small  maquete'],
#  ['cowardly  costume', 'lion skin lion skin'],
#  ['film', 'musical  selections'],
#  ['haley', 'solo parts solo parts'],
#  ['musical  pieces', 'editing process editing process'],
#  ['this', 'ding - ding dong'],
#  ['witch', 'dialogue sequences dialogue sequences'],
#  ['sneak preview sneak preview', 'san bernardino san bernardino'],
#  ['film', 'nationwide  august'],
#  ['it', 'warner bros warner bros'],
#  ['restoration job restoration job', 'focus world focus world'],
#  ['film', 'ultra  hd'],
#  ['2d  version', 'g rating g rating'],
#  ['seven snow dwarfs', 'fantastic  half'],
#  ['film daily film daily', 'parser - parser hidden;margin:1em'],
#  ['major  differences', 'original  book'],
#  ['it', 'james franco james franco'],
#  ['it', 'critical  reception'],
#  ['costume designer costume designer', 'final  design'],
#  ['film version film version', '1982'],
#  ['example', 'police story police story'],
#  ['genre', ''],
#  ['other  examples', 'gunga jumna gunga jumna'],
#  ['they', 'word play word lines'],
#  ['examples', 'angry  men'],
#  ['it', 'sayuthi temat revalina sayuthi temat'],
#  ['rika', 'actor surya actor surya'],
#  ['meanwhile  surya', 'doni   doni affections'],
#  ['individual  characters', 'people bramantyo people bramantyo'],
#  ['film', ''],
#  ['bramantyo', 'cast members cast members'],
#  ['movie musicals movie musicals', 'made  tv'],
#  ['it', 'movie'],
#  ['principal  photography', 'june'],
#  ['first  trailer', 'day  november'],
#  ['final  trailer', 'march'],
#  ['north america north maleficent', 'north america north america'],
#  ['opening weekends opening weekends', 'china'],
#  ['film', 'however  amount'],
#  ['everyone', 'even  presence'],
#  ['it', 'agency'],
#  ['it', 'power'],
#  ['we', 'very  rape'],
#  ['principal  photography', 'august'],
#  ['godfrey reggio director godfrey reggio',
#   'philip glass composer philip music'],
#  ['artistic  merits', 'film music film music'],
#  ['production music production music', 'media producers media producers'],
#  ['us library us library', '250,000  tracks'],
#  ['she', 'strength'],
#  ['garland stops garland zellweger', 'film'],
#  ['she', 'tear'],
#  ['examples', 'killers'],
#  ['this', 'war'],
#  ['title', 'cynical  image'],
#  ['', 'unfortunately  mr'],
#  ['sala   sala we', 'seriously  release'],
#  ['film', 'temporarily  brazil'],
#  ['2012  decision', '5  july'],
#  ['dragan  bjelogrlić', 'film'],
#  ['that', 'something'],
#  ['i', 'it'],
#  ['you', 'serbian  film'],
#  ['i', 'conscience'],
#  ['nota', 'anand shankar anand shankar'],
#  ['film', 'box office box office'],
#  ['', 'game designer video game uk'],
#  ['he', 'house arrest house arrest'],
#  ['varun', 'name rowdy name rowdy'],
#  ['day  she', 'sleeping pills sleeping pills'],
#  ['dam', 'many  lives'],
#  ['vinothan', 'heated  argument'],
#  ['emotional  drama', 'characters'],
#  ['film', 'box office box office'],
#  ['i', 's. shankar s. shankar'],
#  ['soundtrack  score', 'r. rahman a. r. rahman'],
#  ['production design production design', 't. muthuraj t. muthuraj'],
#  ['principal  photography', 'july'],
#  ['main  ambition', 'lingesan  chennai'],
#  ['he', 'diya'],
#  ['well  lingesan', 'diya'],
#  ['diya', 'lingesan  truth'],
#  ['he', 'modelling'],
#  ['eventually body he', 'face'],
#  ['he', 'then  them'],
#  ['they', 'secluded  life'],
#  ['stunt direction stunt direction', 'anl arasu anl arasu'],
#  ['prosthetic  makeup', 'christien tinsley christien tinsley'],
#  ['later  name', 'chopra'],
#  ['film', '14  january'],
#  ['she', 'experience'],
#  ['media rights media rights', 'satellite rights satellite rights'],
#  ['net  collections', 'crores'],
#  ['', 'kanittha kwanyu kanittha kwanyu'],
#  ['atlee kumar atlee kumar', 'film industry tamil film industry'],
#  ['', 'tamil film tamil 2016'],
#  ['atlee kumar atlee kumar', 'film industry tamil film industry'],
#  ['', 'tamil film tamil 2016'],
#  ['film festivals film festivals', 'films'],
#  ['festivals', 'film - film maker'],
#  ['film festivals film festivals', 'world'],
#  ['film festival venice film festival', 'film festival film world'],
#  ['film festival film festival', 'film festival sydney film festival'],
#  ['film festival film festival', 'film festival yorkton film 1947'],
#  ['film festival sundance film festival', 'film festival york film festival'],
#  ['film festival arbor film festival', '1963'],
#  ['film festival film festival', 'uk'],
#  ['film festivals film festivals', 'issues/  subjects'],
#  ['festivals', 'mainstream  films'],
#  ['examples', 'film festivals film festivals'],
#  ['', 'john thimothy john thimothy'],
#  ['hot  docs', 'paul jay filmmaker paul jay'],
#  ['film festival whistler film festival', '80  screenings'],
#  ['film festival film festival', 'film festival film mexico'],
#  ['it', 'film festival film chile'],
#  ['focus', 'american cinema american cinema'],
#  ['film festivals film festivals', 'exclusively  animation'],
#  ['notable  festivals', 'film festival international film festival'],
#  ['they', 'film festivals film world'],
#  ['franchise', 'short  films'],
#  ['it', 'universal  pictures'],
#  ['final  films', '2020'],
#  ['', 'car culture car culture'],
#  ['weta digital company weta digital', 'likeness'],
#  ['ultimately  film', 'april'],
#  ['cast', 'ghost hologram ghost hologram'],
#  ['parkour athletes parkour athletes', 'drivers'],
#  ['following  list', 'website'],
#  ['game', 'mixed  reviews'],
#  ['models', 'eric tscherne designer eric tscherne'],
#  ['franchise', 'short  films'],
#  ['it', 'universal  pictures'],
#  ['final  films', '2020'],
#  ['', 'car culture car culture'],
#  ['weta digital company weta digital', 'likeness'],
#  ['ultimately  film', 'april'],
#  ['cast', 'ghost hologram ghost hologram'],
#  ['parkour athletes parkour athletes', 'drivers'],
#  ['following  list', 'website'],
#  ['game', 'mixed  reviews'],
#  ['models', 'eric tscherne designer eric tscherne'],
#  ['voting system voting system', '1956'],
#  ['filmfare awards filmfare awards', 'first  1954'],
#  ['choice award choice award', 'short  film'],
#  ['so  ceremony', 'next  year'],
#  ['two  reasons', 'change'],
#  ['theme', 'hundred  future'],
#  ['', ''],
#  ['voting system voting system', '1956'],
#  ['filmfare awards filmfare awards', 'first  1954'],
#  ['choice award choice award', 'short  film'],
#  ['so  ceremony', 'next  year'],
#  ['two  reasons', 'change'],
#  ['theme', 'hundred  future'],
#  ['', ''],
#  ['batman series batman series', 'north america north america'],
#  ['film', 'cave'],
#  ['johnny duncan johnny duncan', 'robin'],
#  ['film', 'leslie'],
#  ['late  popularity', 'late  1970s'],
#  ['holden', '1981'],
#  ['nine  rewrites', 'separate  writers'],
#  ['final  salary', '50 million 50 million'],
#  ['rewrites', 'charles warren gems'],
#  ['filming', 'warner bros warner bros'],
#  ['film', 'more  money'],
#  ['arnold schwarzenegger arnold schwarzenegger', 'mr'],
#  ['then  idea', ''],
#  ['he', 'warner bros warner bros'],
#  ['aronofsky', 'franchise'],
#  ['joss whedon joss whedon', 'december'],
#  ['it', 'also  no'],
#  ['knight rises knight rises', 'batman trilogy batman trilogy'],
#  ['anne hathaway anne hathaway', 'selina kyle selina kyle'],
#  ['charles roven charles roven', 'also  film'],
#  ['history', 'killer croc killer croc'],
#  ['film', 'early  2019'],
#  ['calotype process calotype process', 'paper negatives paper negatives'],
#  ['roll film plastic roll film', '1889'],
#  ['it', 'flammable  nitrocellulose'],
#  ['photographic  plates', 'only  blue'],
#  ['however  all', 'these'],
#  ['color film color film', 'plate product glass plate 1907'],
#  ['it', 'snapshot use snapshot use'],
#  ['film', '278  patents'],
#  ['photographic  lenses', 'film'],
#  ['this', 'color film color film'],
#  ['filters', 'film types film types'],
#  ['subject matter subject matter', 'heavy  exposure'],
#  ['automatic  cameras', 'average  density'],
#  ['naming  standard', 'standards authority russian standards authority'],
#  ['film speeds film speeds', 'iso'],
#  ['expensive  lenses', 'quartz'],
#  ['apochromatic  lenses', 'sometimes  spectrum'],
#  ['', 'mm filmkodak mm filmkodak'],
#  ['first  thriller', 'london fog london fog'],
#  ['film', 'bond films james bond films'],
#  ['action scenes action scenes', 'thriller genre thriller genre'],
#  ['such  films', 'silver streak silver streak'],
#  ['such  films', 'rather  policeman'],
#  ['central  topics', 'killers  murders'],
#  ['genre', 'late  1970s'],
#  ['examples', 'pelican  brief'],
#  ['other  examples', 'tall  man'],
#  ['sometimes  protagonist', 'psychic  ability'],
#  ['examples', 'thirteenth  floor'],
#  ['loft', 'van looy erik van looy'],
#  ['', ''],
#  ['he', 'ann'],
#  ['', 'july'],
#  ['loft', 'negative  reviews'],
#  ['brief  saruman', 'gandalf'],
#  ['bilbo', 'sting'],
#  ['fellowship', 'uruk - uruk hai'],
#  ['', 'aragorn  die'],
#  ['gandalf', 'defeated  palantír'],
#  ['sauron', 'capital minas capital minas'],
#  ['gollum', 'frodo  chasm'],
#  ['fellowship', 'ring'],
#  ['peter jackson peter we', 'it'],
#  ['jackson', 'production company film production company'],
#  ['jackson', 'new zealand new zealand'],
#  ['2009  dispute', '8  september'],
#  ['video games video games', 'film series film series'],
#  ['aladdin', 'disney pictures walt disney pictures'],
#  ['aladdin', 'new  life'],
#  ['numan acar numan acar', 'hakim'],
#  ['prince', '1000  dancers'],
#  ['cgi scenes cgi scenes', 'better  notices'],
#  ['international  openings', 'china'],
#  ['you', 'original  film'],
#  ['film', 'july'],
#  ['film', 'may'],
#  ['film', 'may'],
#  ['film', 'may'],
#  ['film', 'june'],
#  ['james mangold james mangold', 'later  film'],
#  ['mark bomback mark bomback', 'then  script'],
#  ['film', 'july'],
#  ['screenplay', 'kinberg'],
#  ['tim miller specialist tim miller', 'april'],
#  ['film', 'february'],
#  ['film', 'may'],
#  ['superheroes', 'risky  missions'],
#  ['additional  filming', 'august'],
#  ['film', 'june'],
#  ['records', 'three  films'],
#  ['morris', 'men'],
#  ['two  films', 'cerebral  tone'],
#  ['later  zombie', 'white zombie white zombie'],
#  ['studio album studio album', 'united states united states'],
#  ['studio album studio album', 'earlier  recordings'],
#  ['he', 'regeneration vendor rat regeneration vendor'],
#  ['live  shows', 'rock theatricality shock rock theatricality'],
#  ['he', 'robert  cummings'],
#  ['younger  brother', 'band powerman band powerman'],
#  ['zombie', 'album rob album rob'],
#  ['studio album studio album', 'sinister  november'],
#  ['second  single', 'single  feel'],
#  ['film', 'theatrically  april'],
#  ['album', 'educated  march'],
#  ['film', 'grossing  date'],
#  ['ii', 'august'],
#  ['series', 'comic  book'],
#  ['hellbilly  deluxe', '2  february'],
#  ['tour', 'officially  december'],
#  ['we', 'plan'],
#  ['album', 'april'],
#  ['album', 'selling album selling date'],
#  ['album', 'april'],
#  ['zombie', 'seriously  heaviest'],
#  ['film', 'release date release date'],
#  ['he', 'white zombie white zombie'],
#  ['later  zombie', 'white zombie white zombie'],
#  ['studio album studio album', 'united states united states'],
#  ['studio album studio album', 'earlier  recordings'],
#  ['he', 'regeneration vendor rat regeneration vendor'],
#  ['live  shows', 'rock theatricality shock rock theatricality'],
#  ['he', 'robert  cummings'],
#  ['younger  brother', 'band powerman band powerman'],
#  ['zombie', 'album rob album rob'],
#  ['studio album studio album', 'sinister  november'],
#  ['second  single', 'single  feel'],
#  ['film', 'theatrically  april'],
#  ['album', 'educated  march'],
#  ['film', 'grossing  date'],
#  ['ii', 'august'],
#  ['series', 'comic  book'],
#  ['hellbilly  deluxe', '2  february'],
#  ['tour', 'officially  december'],
#  ['we', 'plan'],
#  ['album', 'april'],
#  ['album', 'selling album selling date'],
#  ['album', 'april'],
#  ['zombie', 'seriously  heaviest'],
#  ['film', 'release date release date'],
#  ['he', 'white zombie white zombie'],
#  ['parties', 'deal  contracts'],
#  ['step', 'actually  film'],
#  ['actors', 'call times call times'],
#  ['take', 'then  everyone'],
#  ['camera operator camera camera', 'camera operator camera operator'],
#  ['video  film', 'film editor film editor'],
#  ['visual computer effects', 'digitally  artist'],
#  ['film', 'required  exhibition'],
#  ['parties', 'deal  contracts'],
#  ['step', 'actually  film'],
#  ['actors', 'call times call times'],
#  ['take', 'then  everyone'],
#  ['camera operator camera camera', 'camera operator camera operator'],
#  ['video  film', 'film editor film editor'],
#  ['visual computer effects', 'digitally  artist'],
#  ['film', 'required  exhibition'],
#  ['bbfc', 'verification scheme verification scheme'],
#  ['local  authorities', 'films'],
#  ['12a certificate 12a certificate', 'bourne identity bourne identity'],
#  ['turnover', 'vacancies website job vacancies website'],
#  ['bbfc', 'video games video games'],
#  ['bbfc  guidelines', '4–5  years'],
#  ['consultation', 'march'],
#  ['bbfc', 'following  certificates'],
#  ['they', 'licensed  cinemas'],
#  ['language film language film', 'award'],
#  ['film award language film it', 'film award language film award'],
#  ['animated  films', 'also  category'],
#  ['film', 'nomination'],
#  ['one  film', 'country'],
#  ['paradise', 'film award language film award'],
#  ['such  films', 'underground  channels'],
#  ['pornographic  films', 'softcore  pornography'],
#  ['it', 'sexual  activity'],
#  ['two', 'earliest  pioneers'],
#  ['gyrating', 'earliest  films'],
#  ['however  none', 'pornographic  films'],
#  ['entrepreneurs', 'demand'],
#  ['term glamour term glamour', 'modeling  photography'],
#  ['sex films sex films', 'european continent european continent'],
#  ['debbie', 'dallas'],
#  ['nothing', 'this'],
#  ['it', 'industry publications industry publications'],
#  ['film studios film studios', 'also  houston'],
#  ['traditionally  audience', 'pornographic  films'],
#  ['most  actors', 'certain  genres'],
#  ['they', 'normally  jewellery'],
#  ['annie', 'group member support group member'],
#  ['first  you', 'bloody  head'],
#  ['', 'sundance institute sundance institute'],
#  ['film festival sundance film festival', '24  february'],
#  ['it', 'van wagenen sterling van wagenen'],
#  ['capra  award', 'jimmy stewart jimmy stewart'],
#  ['robert redford robert who', 'actor'],
#  ['london festival sundance london festival', 'maker jaguar maker jaguar'],
#  ['2018  events', 'same  venue'],
#  ['war', 'siddharth anand siddharth anand'],
#  ['vaani kapoor vaani kapoor', 'lead  role'],
#  ['who', 'south korea south korea'],
#  ['themes', 'sanchit balhara sanchit balhara'],
#  ['india', 'today  it'],
#  ['it', 'bollywood films bollywood films'],
#  ['production companies film production companies', 'all  world'],
#  ['technical  improvements', 'sound recording sound recording'],
#  ['movies', 'victorian art age'],
#  ['technical  problems', '1923'],
#  ['film', 'painted  slides'],
#  ['first  films', 'device'],
#  ['technique', 'film scrooge film ghost'],
#  ['james williamson james attack', 'mission station china mission station'],
#  ['films', 'scenes'],
#  ['films', 'proper  plots'],
#  ['he', 'silent  films'],
#  ['jacksonville', 'film industry american film industry'],
#  ['film company film company', 'different  approach'],
#  ['trend', 'italy'],
#  ['percy smith f. percy smith',
#   'documentary pioneer nature documentary charles'],
#  ['film companies film companies', '1912'],
#  ['film industry film industry', 'danish  industry'],
#  ['important  man', 'cinema chain cinema chain'],
#  ['khanzhonkov company khanzhonkov company', 'so film 1918'],
#  ['i', 'éclair company éclair company'],
#  ['exhibition venues exhibition venues', 'higher  prices'],
#  ['biggest  success', 'years'],
#  ['', 'wark griffith wark nation'],
#  ['film industry film industry', 'seriously  war'],
#  ['this', 'floodlights'],
#  ['shaped  slits', 'vertical  apertures'],
#  ['new  idea', 'still  photography'],
#  ['untitled  film', 'raymond turner edward raymond turner'],
#  ['technicolor technique technicolor technique', 'subsequently  1916'],
#  ['propaganda films propaganda films', 'desperate  journey'],
#  ['it', 'greatest  time'],
#  ['gimmicks', 'also  audiences'],
#  ['disney', 'peter pan peter beauty'],
#  ['limelight', 'interesting  respect'],
#  ['', 'samurai   samurai blood'],
#  ['hidden  fortress', 'star wars star wars'],
#  ['series', '1962'],
#  ['bonnie', 'new  hollywood'],
#  ['classical  cinema', 'hollywood producers hollywood producers'],
#  ['jeet kune jeet kune', 'style'],
#  ['indian  film', 'time'],
#  ['camera system camera system', 'spy kids spy kids'],
#  ['silent  film', 'recorded  sound'],
#  ['pianists', 'sheet music sheet music'],
#  ['silent  film', 'retroactively  something'],
#  ['town  theatres', 'usually  pianist'],
#  ['', 'groundbreaking w. nation'],
#  ['film  acting', 'day audiences day audiences'],
#  ['vaudeville', 'film actors film actors'],
#  ['', 'silent  films'],
#  ['frame', 'times  screen'],
#  ['', 'bladed era shutters'],
#  ['red', 'mysterious  atmosphere'],
#  ['early  studios', 'city area york city area'],
#  ['others films others films', 'fort lee fort lee'],
#  ['amounts', 'gross  gross'],
#  ['', 'de heer rolf de heer'],
#  ['stage plays stage plays', 'film styles film styles'],
#  ['blancanieves', 'pablo berger pablo berger'],
#  ['short  that', 'film comedies film comedies'],
#  ['sheep', 'positive  reviews'],
#  ['aardman animations aardman animations', 'also  morph'],
#  ['film', 'year'],
#  ['early  forms', 'motion pictures motion pictures'],
#  ['color television color television', 'more  u.s'],
#  ['colour photography colour photography', 'inaccurate  hues'],
#  ['color photography color photography', 'mid-20th century mid-20th century'],
#  ['sometimes  color', 'cover'],
#  ['school yearbooks school yearbooks', 'entirely  black'],
#  ['early  forms', 'motion pictures motion pictures'],
#  ['color television color television', 'more  u.s'],
#  ['colour photography colour photography', 'inaccurate  hues'],
#  ['color photography color photography', 'mid-20th century mid-20th century'],
#  ['sometimes  color', 'cover'],
#  ['school yearbooks school yearbooks', 'entirely  black'],
#  ['it', 'film series it film series'],
#  ['wyatt oleff wyatt oleff', 'stephen bogaert stephen roles'],
#  ['it', 'horror film horror time'],
#  ['kajganich', 'warner bros warner bros'],
#  ['now  they', 'scary  clown'],
#  ['it', 'all  core'],
#  ['i', 'different  approach'],
#  ['kids', 'really  bill'],
#  ['it', 'alexa xt arri alexa xt'],
#  ['look', 'lenses'],
#  ['he', 'natural  look'],
#  ['it', 'like  quality'],
#  ['so  i', 'away  it'],
#  ['it', 'just  sync'],
#  ['overall  response', 'face'],
#  ['internationally  film', '10,560  screens'],
#  ['hollywood reporter hollywood reporter', ''],
#  ['feeling skarsgård feeling performance', 'awards season awards season'],
#  ['clown', 'bill skarsgård bill nightmares'],
#  ['ideally  we', 'march'],
#  ['part', 'only  kids'],
#  ['cinema historians cinema historians', 'category'],
#  ['sensibility', 'warner bros warner bros'],
#  ['falcon   falcon glass', ''],
#  ['one', 'others'],
#  ['it', 'british century subsidiary'],
#  ['film genre film genre', 'cold  war'],
#  ['black christopher debut', 'classic  noir'],
#  ['', ''],
#  ['', 'implacable groundstar conspiracy investigator'],
#  ['film noir film noir', 'many  manners'],
#  ['dead carl men', ''],
#  ['noir parodies noir parodies', 'darker  tones'],
#  ['final  act', 'parodic  strain'],
#  ['still  others', 'mood'],
#  ['survey', 'identifying  characteristics'],
#  ['faces', 'partially  darkness'],
#  ['', 'hollywood filmmaking hollywood filmmaking'],
#  ['robert montgomery robert montgomery', 'only  mirrors'],
#  ['', 'different  ways'],
#  ['archetypal  characters', 'film noirs film noirs'],
#  ['bars', 'frequently gambling action'],
#  ['soundtrack', 'vidyasagar'],
#  ['film', 'box office box office'],
#  ['camera film camera film', 'standard  perforations'],
#  ['135  film', 'emulsion types emulsion types'],
#  ['perforation size perforation size',
#   'specification ks-1870 specification ks-1870'],
#  ['this', '38.00  mm'],
#  ['exposure rolls exposure rolls', 'daily  press'],
#  ['mm exposures mm exposures', '1914'],
#  ['23 daylight loading mm', 'stereo format stereo format'],
#  ['', 'kine exakta kine 1936'],
#  ['gods', 'łukasz palkowski łukasz palkowski'],
#  ['afi', 'private  funding'],
#  ['prior  leaders', 'george stevens director george stevens'],
#  ['training program film training program',
#   'afi conservatory afi conservatory'],
#  ['first  class', 'filmmakers'],
#  ['richard gladstein producer richard gladstein', 'july'],
#  ['afi catalog afi catalog', '1968'],
#  ['afi awards afi awards', 'outstanding  films'],
#  ['awards', 'competitive  excellence'],
#  ['', 'market partner market fest'],
#  ['additional  sponsors', 'american airlines american airlines'],
#  ['', 'documentary festival documentary washington'],
#  ['festival', 'documentary enthusiasts documentary enthusiasts'],
#  ['silver theatre silver center', 'silver image spring'],
#  ['defeat brixton defeat who', 'afterwards  director'],
#  ['group', 'victory'],
#  ['pelenise tuisano lori pelenise tuisano', 'sefina hobbs sefina hobbs'],
#  ['', 'portray luke portray cousins'],
#  ['character', 'future  film'],
#  ['most  filming', 'shepperton studios shepperton studios'],
#  ['', 'officially  january'],
#  ['same  method', 'mclaren'],
#  ['idris elba idris elba', 'human  abilities'],
#  ['finally  they', 'destruction'],
#  ['latter', 'cyber  clearangle'],
#  ['second  trailer', 'april'],
#  ['final  trailer', 'june'],
#  ['3d conversion reald 3d conversion', 'film'],
#  ['defeat brixton defeat who', 'afterwards  director'],
#  ['group', 'victory'],
#  ['pelenise tuisano lori pelenise tuisano', 'sefina hobbs sefina hobbs'],
#  ['', 'portray luke portray cousins'],
#  ['character', 'future  film'],
#  ['most  filming', 'shepperton studios shepperton studios'],
#  ['', 'officially  january'],
#  ['same  method', 'mclaren'],
#  ['idris elba idris elba', 'human  abilities'],
#  ['finally  they', 'destruction'],
#  ['latter', 'cyber  clearangle'],
#  ['second  trailer', 'april'],
#  ['final  trailer', 'june'],
#  ['3d conversion reald 3d conversion', 'film'],
#  ['film', 'long  camera'],
#  ['films', 'scenes'],
#  ['many  directors', 'artistic  bond'],
#  ['', 'montage   montage technique'],
#  ['classic  examples', 'rocky'],
#  ['two  shots', 'tone value tone value'],
#  ['assistant  editors', 'visual  work'],
#  ['budget features budget features', 'one  assistant'],
#  ['aspects job aspects job', 'database management database management'],
#  ['assistant editing assistant editing', 'career path career path'],
#  ['avn awards avn awards', 'magazine avn trade magazine avn'],
#  ['they', 'porn'],
#  ['xrco awards xrco awards', 'critics organization critics organization'],
#  ['arcade attractions penny arcade attractions', 'topless  women'],
#  ['casey donovan casey donovan', 'pornographic  hit'],
#  ['they', 'commonly  20s'],
#  ['a', 'boxcover'],
#  ['she', 'power'],
#  ['five  she', 'phone calls phone calls'],
#  ['she', 'phone calls phone calls'],
#  ['you', 'gangbangs'],
#  ['they', 'phone call phone call'],
#  ['so  it', 'anal girl toy'],
#  ['most  actresses', 'adult industry adult industry'],
#  ['they', 'anyone'],
#  ['contract girls contract girls', '$  60,000'],
#  ['average  male', '$  40,000'],
#  ['claims', 'health authorities health authorities'],
#  ['breakdown voltage breakdown voltage', 'dielectric  films'],
#  ['this', 'current  rating'],
#  ['film', 'less  material'],
#  ['film capacitors film capacitors',
#   'foil construction metal foil construction'],
#  ['foil capacitors metal foil capacitors', 'healing  properties'],
#  ['special  type', 'mku capacitors mku capacitors'],
#  ['characteristics', 'film materials film materials'],
#  ['they', 'metallized  wound'],
#  ['table', 'smaller capacitance 50'],
#  ['they', 'metallized  wound'],
#  ['they', 'metallized  types'],
#  ['they', 'metallized  types'],
#  ['absorption performance dielectric absorption performance',
#   'dielectric  capacitors'],
#  ['ptfe', 'trademark teflon dupont trademark teflon'],
#  ['wound', ''],
#  ['film capacitors series film capacitors', '2012'],
#  ['film capacitor film capacitor', 'kapton capacitorcl11 kapton dhgate'],
#  ['iec standards iec standards', 'european  standards'],
#  ['many  manufacturers', 'standard  abbreviations'],
#  ['capacitance tolerance capacitance tolerance', 'particular  application'],
#  ['derating  factors', 'voltages'],
#  ['peak value peak value', 'alternating voltage alternating voltage'],
#  ['film capacitors film capacitors', 'alternating  voltage'],
#  ['capacitors', 'effect'],
#  ['', 'capacitor \n capacitor s'],
#  ['dissipation factor dissipation factor', 'film capacitors film capacitors'],
#  ['film capacitors film capacitors', 'aging  processes'],
#  ['main  advantages', 'film capacitors film capacitors'],
#  ['', 'capacitor construction esr capacitor construction'],
#  ['important  criteria', 'application'],
#  ['snubber capacitors snubber capacitors',
#   'construction features construction features'],
#  ['ac  capacitors', ''],
#  ['discharge capacitors discharge capacitors', 'current  surges'],
#  ['power capacitors power capacitors', 'physical  dimensions'],
#  ['most  animations', 'generated  imagery'],
#  ['animation', 'technology interfaces information technology interfaces'],
#  ['little winsor nemo', 'detailed  drawings'],
#  ['', 'cutout animation cutout animation'],
#  ['terrytoons', 'tom terrific tom terrific'],
#  ['animation market animation market', '2008'],
#  ['today  drawings', 'computer system computer system'],
#  ['3d  animation', 'digitally  animator'],
#  ['animator', 'polygon mesh polygon mesh'],
#  ['traits', 'live  action'],
#  ['list', 'awardees'],
#  ['most  animations', 'generated  imagery'],
#  ['animation', 'technology interfaces information technology interfaces'],
#  ['little winsor nemo', 'detailed  drawings'],
#  ['', 'cutout animation cutout animation'],
#  ['terrytoons', 'tom terrific tom terrific'],
#  ['animation market animation market', '2008'],
#  ['today  drawings', 'computer system computer system'],
#  ['3d  animation', 'digitally  animator'],
#  ['animator', 'polygon mesh polygon mesh'],
#  ['traits', 'live  action'],
#  ['list', 'awardees'],
#  ['area', 'jubilee hills jubilee hills'],
#  ['train station train station', 'hitec  city'],
#  ['film cameras film roll', 'film cameras film cameras'],
#  ['where  film', 'advantages'],
#  ['imaging systems imaging systems', 'cost emphases cost emphases'],
#  ['digital  cameras', 'film equivalents film equivalents'],
#  ['prices', 'intense  competition'],
#  ['', 'giacomo ciarrapico giacomo ciarrapico'],
#  ['it', 'series boris television series boris'],
#  ['schwarzenegger', 'later  role'],
#  ['story', 'miller'],
#  ['', 'script'],
#  ['she', 'harder  anybody'],
#  ['supervisor neil effects supervisor neil', 'set  piece'],
#  ['', 'october'],
#  ['certain  scenes', 'rated  violence'],
#  ['it', 'internet comments internet comments'],
#  ['theatrical  trailers', 'august'],
#  ['game', 'september'],
#  ['t-800 model t-800 model', 'mortal  kombat'],
#  ['schwarzenegger', 'later  role'],
#  ['story', 'miller'],
#  ['', 'script'],
#  ['she', 'harder  anybody'],
#  ['supervisor neil effects supervisor neil', 'set  piece'],
#  ['', 'october'],
#  ['certain  scenes', 'rated  violence'],
#  ['it', 'internet comments internet comments'],
#  ['theatrical  trailers', 'august'],
#  ['game', 'september'],
#  ['t-800 model t-800 model', 'mortal  kombat'],
#  ['suspense', 'plot element plot element'],
#  ['mystery films mystery films', 'mainly  crime'],
#  ['women', 'films'],
#  ['mystery films mystery films', 'silent  era'],
#  ['film', 'more  1953'],
#  ['two  films', 'now  1909'],
#  ['story', 'again  1993'],
#  ...]

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_54206/2915272249.py in <module>
#       5 target = [i[1] for i in entity_pairs]
#       6
# ----> 7 kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})
#
# NameError: name 'relations' is not defined

# %% [markdown]
# Next, we will use the networkx library to create a network from this dataframe. The nodes will represent the entities and the edges or connections between the nodes will represent the relations between the nodes.
# It is going to be a directed graph. In other words, the relation between any connected node pair is not two-way, it is only from one node to another.

# %%
# create a directed-graph from a dataframe
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_54206/2320675209.py in <module>
#       1 # create a directed-graph from a dataframe
# ----> 2 G=nx.from_pandas_edgelist(kg_df, "source", "target",
#       3                           edge_attr=True, create_using=nx.MultiDiGraph())
#
# NameError: name 'kg_df' is not defined

# %% [markdown]
# #### plot

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_54206/976178200.py in <module>
#       1 plt.figure(figsize=(12,12))
#       2
# ----> 3 pos = nx.spring_layout(G)
#       4 nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
#       5 plt.show()
#
# NameError: name 'G' is not defined

# %% [markdown]
# It turns out that we have created a graph with all the relations that we had. It becomes really hard to visualize a graph with these many relations or predicates.

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="composed by"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_54206/1852986952.py in <module>
# ----> 1 G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="composed by"], "source", "target",
#       2                           edge_attr=True, create_using=nx.MultiDiGraph())
#       3
#       4 plt.figure(figsize=(12,12))
#       5 pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
#
# NameError: name 'kg_df' is not defined

# %% [markdown]
# That’s a much cleaner graph. Here the arrows point towards the composers. For instance, A.R. Rahman, who is a renowned music composer, has entities like “soundtrack score”, “film score”, and “music” connected to him in the graph above.
#
# Let’s check out a few more relations.
#
# Since writing is an important role in any movie, I would like to visualize the graph for the “written by” relation

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="written by"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_54206/1415773125.py in <module>
# ----> 1 G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="written by"], "source", "target",
#       2                           edge_attr=True, create_using=nx.MultiDiGraph())
#       3
#       4 plt.figure(figsize=(12,12))
#       5 pos = nx.spring_layout(G, k = 0.5)
#
# NameError: name 'kg_df' is not defined

# %% [markdown]
# This knowledge graph is giving us some extraordinary information. Guys like Javed Akhtar, Krishna Chaitanya, and Jaideep Sahni are all famous lyricists and this graph beautifully captures this relationship.
#
# Let’s see the knowledge graph of another important predicate, i.e., the “released in”

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="released in"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_54206/1339965172.py in <module>
# ----> 1 G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="released in"], "source", "target",
#       2                           edge_attr=True, create_using=nx.MultiDiGraph())
#       3
#       4 plt.figure(figsize=(12,12))
#       5 pos = nx.spring_layout(G, k = 0.5)
#
# NameError: name 'kg_df' is not defined

# %% [markdown]
# #### Resources
#
#
# https://www.analyticsvidhya.com/blog/2019/10/how-to-build-knowledge-graph-text-using-spacy/
