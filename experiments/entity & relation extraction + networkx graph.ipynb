# %% [markdown]
# # Quick graph creation

# %% [markdown]
# #### Libraries

# %%
import spacy
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline
# Out:
# 2022-01-12 15:57:14.514821: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-12 15:57:14.514856: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/becode/.local/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
nlp = spacy.load('en_core_web_sm')
doc1 = nlp("The 22-year-old recently won ATP Challenger tournament.")
for tok in doc1:
  print(tok.text, "...", tok.dep_)
# Out:
# The ... det
# 22 ... nummod
# - ... punct
# year ... npadvmod
# - ... punct
# old ... nsubj
# recently ... advmod
# won ... ROOT
# ATP ... compound
# Challenger ... compound
# tournament ... dobj
# . ... punct

# %% [markdown]
# We wanted to extract “22-year-old” instead.

# %% [markdown]
# The rule can be something like this — extract the subject/object along with its modifiers and also extract the punctuation marks between them.
# In short, we will use dependency parsing to extract entities.

# %% [markdown]
# #### Extract Relations

# %% [markdown]
# Entity extraction is half the job done. To build a knowledge graph, we need edges to connect the nodes (entities) to one another. These edges are the relations between a pair of nodes.

# %%
doc = nlp("Nagal won the first set.")

for tok in doc:
  print(tok.text, "...", tok.dep_)
# Out:
# Nagal ... nsubj
# won ... ROOT
# the ... det
# first ... amod
# set ... dobj
# . ... punct

# %% [markdown]
# To extract the relation, we have to find the ROOT of the sentence (which is also the verb of the sentence). Hence, the relation extracted from this sentence would be “won”.

# %% [markdown]
# #### Build a Knowledge Graph from Text Data

# %% [markdown]
# The following dataset exists of 4,300 sentences from over 500 Wikipedia articles. Each of these sentences contains exactly two entities – one subject and one object.

# %%
# import wikipedia sentences
candidate_sentences = pd.read_excel("../assets/preprocessed_text.xlsx")
candidate_sentences.shape
# Out:
# (10788, 3)

# %%
candidate_sentences
# Out:
#                  ids  \
# 0         test/14826
# 1         test/14828
# 2         test/14829
# 3         test/14832
# 4         test/14833
# ...              ...
# 10783   training/999
# 10784  training/9992
# 10785  training/9993
# 10786  training/9994
# 10787  training/9995
#
#                                                          categories  \
# 0                                                         ['trade']
# 1                                                         ['grain']
# 2                                              ['crude', 'nat-gas']
# 3      ['corn', 'grain', 'rice', 'rubber', 'sugar', 'tin', 'trade']
# 4                                           ['palm-oil', 'veg-oil']
# ...                                                             ...
# 10783                                      ['interest', 'money-fx']
# 10784                                                      ['earn']
# 10785                                                      ['earn']
# 10786                                                      ['earn']
# 10787                                                      ['earn']
#
#                                                                                                                                                                                                           text
# 0      Mounting trade friction between the  U.S. And Japan has raised fears among many of Asias exporting  nations that the row could inflict far-reaching economic  damage, businessmen and officials said...
# 1      A survey of 19 provinces and seven cities  showed vermin consume between seven and 12 pct of Chinas grain  stocks, the China Daily said.  It also said that each year 1.575 mln tonnes, or 25 pct, o...
# 2      The Ministry of International Trade and  Industry (MITI) will revise its long-term energy supply/demand  outlook by August to meet a forecast downtrend in Japanese  energy demand, ministry officia...
# 3      Thailands trade deficit widened to 4.5  billion baht in the first quarter of 1987 from 2.1 billion a  year ago, the Business Economics Department said.  It said Janunary/March imports rose to 65.1...
# 4      Indonesia expects crude palm oil (CPO)  prices to rise sharply to between 450 and 550 dlrs a tonne FOB  sometime this year because of better European demand and a fall  in Malaysian output, Hasrul...
# ...                                                                                                                                                                                                        ...
# 10783  The Bank of England said it had revised  its forecast of the shortage in the money market down to 450  mln stg before taking account of its morning operations. At  noon the bank had estimated the ...
# 10784                                                                                                                                          Qtly div 25 cts vs 25 cts prior  Pay April 13  Record April Six
# 10785                                                                                                                                        Qtly div 12 cts vs 12 cts prior  Pay April 21  Record April Seven
# 10786  Shr loss six cts vs loss 18 cts  Net loss 89,478 vs loss 178,507  Revs 3,894,844 vs 1,964,141  Avg shrs 1,582,790 vs one mln  Year  Shr loss 43 cts vs loss 81 cts  Net loss 534,099 vs loss 811,836...
# 10787                                                                                                Shr 43 cts vs 52 cts  Shr diluted 41 cts vs 49 cts  Net 1,916,000 vs 2,281,000  Revs 32.6 mln vs 22.6 mln
#
# [10788 rows x 3 columns]

# %% [markdown]
# Inspect a few sentences

# %%
candidate_sentences['text'].sample(5)
# Out:
# 3849    Cable and Wireless Plc CAWL.L said  proposals to resolve a dispute over entry to Japans  telecommunications market were not acceptable.  A company spokesman said the proposals appear to have been ...
# 4710    Shr loss 6.48 DLS VS PROFIT 23 CTS  Net loss 110.6 mln vs profit 4.1 mln  Revs 74.0 mln vs 152.0 mln  Year  Shr loss 6.52 dlrs vs profit 3.87 dlrs  net loss 111.2 mln vs profit 64.2 mln  Revs 501....
# 5084    The Bank of Japan intervened in early  afternoon Tokyo trading to support the dollar against active  selling by institutional investors and speculative selling by  overseas operators, dealers said...
# 67      The Bank of England said it provided the  market with further help totalling 166 mln stg during the  afternoon.  In band one, it bought 31 mln stg of treasury bills and  three mln stg of bank bill...
# 5386                       Toronto Sun Publishing Corp said it  planned a two-for-one split of its common shares, subject to  regulatory approval and approval by shareholders at the April  21 annual meeting.
# Name: text, dtype: object

# %% [markdown]
# check the subject and object of one of these sentences. Ideally, there should be one subject and one object in the sentence

# %%
doc = nlp("Mitsubishi Heavy Industries Ltd MITH.T  (MHI) and C. Itoh and Co Ltd CITT.T have decided to sell  their combined 65 pct stake in Indonesias Pt Triguna Utama  Machinery Industries to Caterpillar")

for tok in doc:
  print(tok.text, "...", tok.dep_)
# Out:
# Mitsubishi ... compound
# Heavy ... compound
# Industries ... compound
# Ltd ... nsubj
# MITH.T ... compound
#   ... dep
# ( ... punct
# MHI ... appos
# ) ... punct
# and ... cc
# C. ... compound
# Itoh ... conj
# and ... cc
# Co ... compound
# Ltd ... compound
# CITT.T ... conj
# have ... aux
# decided ... ROOT
# to ... aux
# sell ... xcomp
#   ... dep
# their ... poss
# combined ... amod
# 65 ... nummod
# pct ... compound
# stake ... dobj
# in ... prep
# Indonesias ... compound
# Pt ... compound
# Triguna ... compound
# Utama ... nmod
#   ... dep
# Machinery ... compound
# Industries ... pobj
# to ... prep
# Caterpillar ... pobj

# %% [markdown]
#  There is only one subject (‘process’) and only one object (‘standard’). You can check for other sentences in a similar manner.

# %% [markdown]
# #### Entity Pairs Extraction

# %% [markdown]
# To build a knowledge graph, the most important things are the nodes and the edges between them.
#
# These nodes are going to be the entities that are present in the Wikipedia sentences. Edges are the relationships connecting these entities to one another. We will extract these elements in an unsupervised manner, i.e., we will use the grammar of the sentences.
#
# The main idea is to go through a sentence and extract the subject and the object as and when they are encountered.

# %% [markdown]
# However, there are a few challenges ⁠— an entity can span across multiple words, eg., “red wine”, and the dependency parsers tag only the individual words as subjects or objects.

# %% [markdown]
# The function below is used to extract the subject and the object (entities) from a sentence while also overcoming the challenges mentioned above.

# %%
sent= "The 22-year-old recently won ATP Challenger tournament."

# %%
def get_entities(sent):
    
    
    ## chunk 1
    ent1 = ""
    ent2 = ""

    prv_tok_dep = ""    # dependency tag of previous token in the sentence
    prv_tok_text = ""   # previous token in the sentence

    prefix = ""
    modifier = ""
    
###########################
    for tok in nlp(sent):
        ## chunk 2
        # if token is a punctuation mark then move on to the next token
        
        if tok.dep_ != "punct":
            # check: token is a compound word or not
            if tok.dep_ == "compound":
                prefix = tok.text
                # if the previous word was also a 'compound' then add the current word to it
                if prv_tok_dep == "compound":
                    prefix = prv_tok_text + " "+ tok.text
                    
            
    # check: token is a modifier or not
        if tok.dep_.endswith("mod") == True:
            modifier = tok.text
    
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
            modifier = prv_tok_text + " "+ tok.text
            
            
        ## chunk 3
        if tok.dep_.find("subj") == True:
            ent1 = modifier +" "+ prefix + " "+ tok.text
            prefix = ""
            modifier = ""
            prv_tok_dep = ""
            prv_tok_text = ""
            
        ## chunk 4
        if tok.dep_.find("obj") == True:
            ent2 = modifier +" "+ prefix +" "+ tok.text
            
        ## chunk 5  
        # update variables
        prv_tok_dep = tok.dep_
        prv_tok_text = tok.text
  ##    ###########################################################

    return [ent1.strip(), ent2.strip()]

# %%
get_entities(sent)
# Out:
# ['year  old', 'Challenger tournament ATP Challenger tournament']

# %% [markdown]
# we can use this function to extract these entity pairs for all the sentences in our data

# %%
entity_pairs = []

for i in tqdm(candidate_sentences["text"]):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|█████████████████████████████████████| 10788/10788 [06:07<00:00, 29.37it/s]

# %%
entity_pairs
# Out:
# [['Michael Smith Representative Michael Smith', 'week International dispute'],
#  ['government', 'further paper details'],
#  ['21 hour they', 'hour basis hour oil'],
#  ['seven  Products', '57 export pct'],
#  ['Indonesian export exports', 'bank   bank figures'],
#  ['it', 'shipping movements shipping movements'],
#  ['Total 6.87 membership', 'exchange'],
#  ['shipment', 'April'],
#  ['ore   ore capacity', 'first treatment mid-1988'],
#  ['strategy', 'that'],
#  ['thirds majority thirds majority', 'extension'],
#  ['dealers', 'call money call money'],
#  ['ore tonnage ore tonnage', 'least operations 1993'],
#  ['further  It', 'further  details'],
#  ['Farm products U.S. Farm issues', 'same  table'],
#  ['pct stake pct it', 'enlarged dividend capital'],
#  ['5.8 timber Interest', 'mln debit mln debit'],
#  ['Partly bankers offsetting', 'mln  system'],
#  ['proper  Kim', 'proper  level'],
#  ['late Alberta statement', 'late Alberta 1989'],
#  ['year Western It', 'gold project gold project'],
#  ['recent industry data', 'pct rise pct rise'],
#  ['10.0 percentage profit', '11.0 U.K. mln'],
#  ['Manhattan Banks Chase Manhattan Banks',
#   'merchant banking merchant banking'],
#  ['which', 'net electrolysis 1985'],
#  ['full 20.20 name', '110 20.20 francs'],
#  ['Spain   Spain which', 'EC stance EC favour'],
#  ['protectionist   protectionist he',
#   'protectionist   protectionist legislation'],
#  ['South Korea South Thailand', 'down zinc 14,937'],
#  ['todays  they', 'todays  result'],
#  ['sugar   sugar traders', 'sugar   sugar June'],
#  ['they', 'sale'],
#  ['Buttrose', 'long  term'],
#  ['these', 'possibly  June'],
#  ['trees   trees effects', 'three  years'],
#  ['BONUS ISSUE BONUS ISSUE', 'B  SHARES'],
#  ['foreign housing earnings', 'housing downturn housing downturn'],
#  ['five  It', 'half   half 1985/86'],
#  ['weeks  talks', 'tariffs'],
#  ['who', 'here company Reuters'],
#  ['rationalisation plan industry rationalisation plan',
#   'few production years'],
#  ['general  which', 'Kong market Hong Kong market'],
#  ['protectionist   protectionist he',
#   'protectionist   protectionist legislation'],
#  ['dollar', 'New   New close'],
#  ['Minister Harmoko Information Minister Harmoko',
#   'economic cabinet situation'],
#  ['central  bank', '11/16 9 pct'],
#  ['net  profit', '50 mln 1985'],
#  ['cane crush cane crush', 'normally  December'],
#  ['tonnage', 'rebate figure rebate figure'],
#  ['Meta INZI.MI Meta INZI.MI', '49.9 Montedison Spa pct'],
#  ['years average years average', '1.55 exchange dlrs'],
#  ['drop', 'fertilizer division companys fertilizer division'],
#  ['dollars value dollars value', 'still  that'],
#  ['Five withdrawal which', 'diluted Auxtons voting basis'],
#  ['150,000  company', '114,000 California Biotech dlrs'],
#  ['', '1/2  cts'],
#  ['1.2 billion 1.2 Unilever', 'toiletry brands toiletry brands'],
#  ['IT', 'SEVERAL  PARTIES'],
#  ['mln dlrs mln It', 'mln shares mln shares'],
#  ['Shintaro Abe Chairman Shintaro Abe', 'April'],
#  ['', '4,865,249 half 4,495,021'],
#  ['industrial  action', 'compensation laws workers compensation laws'],
#  ['', ''],
#  ['written', 'union members union tomorrow'],
#  ['', '8,129,000  Revs'],
#  ['', '188.8  mln'],
#  ['Shr  profit', '180.1 Shr mln'],
#  ['liquidity shortage liquidity it', 'liquidity shortage liquidity shortage'],
#  ['', ''],
#  ['Today  company', 'mln dlrs mln dlrs'],
#  ['', '41  Net'],
#  ['1986  Net', '88,946 loan loss dlrs'],
#  ['1,073,163  Company', '1,073,163  NOTE'],
#  ['', '23.0  mln'],
#  ['1986  figure', '2.4  pct'],
#  ['Canion   Canion We', 'personal  March'],
#  ['planned  purchase', 'financial service services'],
#  ['Shr  nil', 'vs nil 2,100,000'],
#  ['Congress', 'bill'],
#  ['year Oper shr net', 'tax credit dlr tax credit'],
#  ['term debt term matures', 'April'],
#  ['', '276,446  706,130'],
#  ['EC', '46.496 TONNES WHITE ECUS'],
#  ['European  he', 'economy'],
#  ['tonnes whites tonnes whites', '100 European Currency kilos'],
#  ['sales', 'first  quarter'],
#  ['Shr  profit', '7,929,138  3,849,224'],
#  ['61.9  Pay', '28  April'],
#  ['', 'Avg dlrs shrs'],
#  ['it', 'undisclosed Paxar terms'],
#  ['', '32  Net'],
#  ['current Canadian companies', 'current Canadian Erskine'],
#  ['also  it', 'Media   Country Media Group'],
#  ['', '29  Net'],
#  ['WOOLWORTH CO F.W. WOOLWORTH CO', '28 CTS A CTS'],
#  ['', '28  cts'],
#  ['allotted suger This', 'dairy  sugar'],
#  ['', ''],
#  ['100 Currency traders', '1,750 West tonnes'],
#  ['company reserves Parent company reserves', 'three billion three end-1985'],
#  ['', 'Avg dlrs 3,834,117'],
#  ['three health care company', 'three health care months'],
#  ['billion mln dlrs', 'accrual'],
#  ['', '67  cts'],
#  ['two  stock', 'August'],
#  ['10  Hanover', '30  April'],
#  ['it', 'Alarm Services Fargo Alarm Services'],
#  ['Full Pay name', '1/2 7 cts'],
#  ['Ministry', 'Agriculture economist Agriculture economist'],
#  ['completion', 'place'],
#  ['gallon contract barge company', '50 contract barge cts'],
#  ['wheat crop wheat which', 'previous  years'],
#  ['earlier end figure', 'end - end March'],
#  ['', ''],
#  ['February meeting February Italy', 'meaningful  decisions'],
#  ['funds rate funds rate', 'up 6 yesterdays'],
#  ['it', 'mln dlrs mln 1986'],
#  ['', '272.2  mln'],
#  ['common  Continental', 'common  shareholders'],
#  ['Shr loss Shr loss', '18.2743 Atlas year'],
#  ['patent suit patent suit', 'merit'],
#  ['Industrial Valley Industrial Valley',
#   'Financial Corp. IVB Financial Corp.'],
#  ['', '13  Net'],
#  ['U.S. economy U.S. economy', 'modest  growth'],
#  ['736,000 tax Net', '579,000 tax year'],
#  ['pension plan pension Company', 'August'],
#  ['', 'BURLINGTON RUMOR BURLINGTON RUMOR'],
#  ['', ''],
#  ['', ''],
#  ['', '30  cts'],
#  ['', '10  cts'],
#  ['', 'Avg 1.725 shrs'],
#  ['', 'eight  cts'],
#  ['mln dlrs mln Earnings', 'stock   stock March'],
#  ['it', 'textile   textile operations'],
#  ['SYSTEM REPURCHASES OVERNIGHT SYSTEM FED', ''],
#  ['defense contract U.S. defense contract', 'first  quarter'],
#  ['1986 mln qtr', 'tax rate tax rate'],
#  ['80 Ivory meeting', '80 Ivory output'],
#  ['when pct Fed', 'banking system banking system'],
#  ['14 hrs agent', 'hrs EDT hrs EDT'],
#  ['personnel costs personnel Morgan', 'personnel costs personnel costs'],
#  ['', '141.9 mln mln'],
#  ['television reports television which', 'outside  granaries'],
#  ['servicing portfolio mortgage servicing portfolio', 'dlrs   dlrs March'],
#  ['', '35  Net'],
#  ['shareholder meeting shareholder meeting', 'April'],
#  ['also  it', 'Envases'],
#  ['metal associations metal associations', 'White Metals White Metals'],
#  ['', 'nine  cts'],
#  ['stock Tradevest Tradevest', 'outstanding  Madeira'],
#  ['split', 'shareholders   shareholders record'],
#  ['40  company', '40  Montedison'],
#  ['31 merger it', 'merger   merger July'],
#  ['', 'ACQUIRE ALEXANDERS ACQUIRE ALEXANDERS'],
#  ['', '97  Net'],
#  ['statement', 'acquisition'],
#  ['trade sources trade sources', 'last  half'],
#  ['Shr  profit', 'loss carryforward tax loss carryforward'],
#  ['1  they', '150,000  March'],
#  ['1987  net', 'recapitalization plan recapitalization plan'],
#  ['Further E. Key details', 'Key   E. Key unit'],
#  ['', 'stock split stock split'],
#  ['', '95.4  mln'],
#  ['year Shr net', 'nine dlrs mths'],
#  ['when book publishing it', 'last CBS October'],
#  ['Stevens STN J.P. Stevens STN', '39 - 39 3/4'],
#  ['', 'Revs 1,022,00 Revs 344,000'],
#  ['', '746,000 Shr loss'],
#  ['U.S. firms U.S. firms', 'Japanese  market'],
#  ['it', 'fiber facilities textile fiber facilities'],
#  ['', '25  cts'],
#  ['GECs', 'closing   yesterdays closing 201p'],
#  ['it', 'improved  year'],
#  ['I', 'trade dispute trade dispute'],
#  ['', ''],
#  ['', 'Corp DCN Dana Corp DCN'],
#  ['more  he', 'more  market'],
#  ['', '1.05 Nine dlrs'],
#  ['', ''],
#  ['', 'Net Shr profit'],
#  ['half tax net', '2,051,000 dlr accounting'],
#  ['first mln Earnings', 'stock distribution stock June'],
#  ['TEXAS SERIES INCOME TEXAS Daily', '6.2 INCOME cts'],
#  ['good  bars', 'western  money'],
#  ['', 'qtr   qtr Pay'],
#  ['oil 1.5 products', '1.5 billion 1.5 dlrs'],
#  ['Turgut Ozal Turgut contents', 'message'],
#  ['Agency   Liability Agency It', 'details'],
#  ['2,400,000 Oper Net', 'six  year'],
#  ['negotiating group negotiating group', 'again meeting May.'],
#  ['505,000  Company', 'July'],
#  ['', '1/2 12 cts'],
#  ['outstanding  it', 'first corrects company paragraph'],
#  ['1.82 billion 1.82 Results', 'six cts mths'],
#  ['price rises oil price inflation', 'pct rate pct 1987'],
#  ['Siemens AG Siemens AG', 'responsive  pacemaker'],
#  ['he', 'other  details'],
#  ['morning', 'afternoon session afternoon session'],
#  ['mln bales mln which', 'years production years production'],
#  ['', '1,187,828 dlrs 1,223,511'],
#  ['', 'MLN DLRS MLN DLRS'],
#  ['indications', 'effect'],
#  ['third  gaming', 'earlier test gaming week'],
#  ['9.5 billion 9.5 that', 'April'],
#  ['offshore  communique', 'offshore  terminal'],
#  ['13.0 qtr Dividend', '30  holders'],
#  ['ministers', '1900  Treasury'],
#  ['requirement', 'years  disruptions'],
#  ['also  it', 'related  businesses'],
#  ['there  he', 'there  everybody'],
#  ['store   concept store which', 'ties'],
#  ['FEDS  HELLER', 'SUPPLY GROWTH MONEY SUPPLY GROWTH'],
#  ['', ''],
#  ['Iran', 'manpower training manpower training'],
#  ['American  producers', 'effectively  country'],
#  ['Prior 5.88 year', 'RCA Corp. RCA Corp.'],
#  ['also  It', 'natural  gas'],
#  ['blown  meeting', 'progress'],
#  ['panel', 'salmonella'],
#  ['Richard Henderson analyst Richard Henderson', 'also  delay'],
#  ['', '1/2 16 cts'],
#  ['Shr loss Shr loss', '1,751,884 Shr 151,884'],
#  ['CANADA', 'STEEL IMPORTS STEEL IMPORTS'],
#  ['products revenues products revenues', 'year systems RCAs'],
#  ['50  pct', 'Ltd CP Pacific Ltd CP'],
#  ['', '6,215,538  5,757,013'],
#  ['already  it', 'additional  liquidity'],
#  ['1987 Enhancement Program USDA', 'Program   Enhancement Program initiative'],
#  ['30 U.S. department', 'U.S. ports U.S. September'],
#  ['Caterpillars', 'material costs material costs'],
#  ['Christopher Moran investor Christopher who', 'year  Zondervan'],
#  ['21  Kiena', 'split'],
#  ['today  company', 'split  basis'],
#  ['agreement', 'definitive  financing'],
#  ['', '16.5  cts'],
#  ['South Africa South it', 'U.S. prices U.S. prices'],
#  ['July mln most', 'United States United States'],
#  ['it', 'find solutions find solutions'],
#  ['UALs stock UALs stock', 'air fares air industry'],
#  ['', 'eight mln mln'],
#  ['which', 'mln dlrs mln dlrs'],
#  ['', '23  cts'],
#  ['', '20  cts'],
#  ['DISTILLERS', 'AMERICAN BRANDS AMERICAN BRANDS'],
#  ['are', '24  May'],
#  ['product line cosmetic product line', 'mln dlrs mln revenue'],
#  ['shr loss Oper shr loss', '11 Oper shr year'],
#  ['spirits brands Nationals spirits brands', 'Gilbeys gin Gilbeys gin'],
#  ['quarter loss quarter loss', 'investors'],
#  ['1/2 product he', '1/2 product pct'],
#  ['mln dlrs mln Raybestos', 'braking applications braking applications'],
#  ['also  it', 'capital   capital deficit'],
#  ['U.S. lawmakers U.S. lawmakers', '2.4  pct'],
#  ['36  which', 'large  writeoffs'],
#  ['', 'mln mln NOTE'],
#  ['', '1.02 billion 1.02 billion'],
#  ['electric  powerplants', 'necessary  coal'],
#  ['also  it', 'Bancshares Corp. Popular Bancshares Corp.'],
#  ['late distance Williams', 'late distance 1988'],
#  ['1986  earnings', '702,000 subsidiary year'],
#  ['', '114.9 loss mln'],
#  ['May futures May futures', '107.90 New lb'],
#  ['1986  company', '16 mln share'],
#  ['', '56  Net'],
#  ['transactions', 'mln dlrs mln dlrs'],
#  ['EIA', 'STOCKS UNCHANGED DISTILLATE STOCKS 200,000'],
#  ['January agreement January agreement', 'department'],
#  ['mln barrels mln it', 'mln barrels mln 1,561.1'],
#  ['so  Hawkeye', 'requirements'],
#  ['', 'Colson Inc. Colson Inc.'],
#  ['it', 'time'],
#  ['3.08 mln it', '3.08 mln mln'],
#  ['Budget Committee Senate Budget Committee', 'spending cuts spending cuts'],
#  ['4th  qtr', '269.1 mln mln'],
#  ['', '0.63 avg pct'],
#  ['June shipment June Arango', 'June shipment June shipment'],
#  ['', 'stock split stock split'],
#  ['Thompson', 'gradual  sometime'],
#  ['rate policies interest rate Koehler',
#   'rate policies interest rate policies'],
#  ['640,400  persons', '8.5  work'],
#  ['it', 'exploration interests exploration Queensland'],
#  ['September Uruguay trade It', 'four  years'],
#  ['year  he', 'year  equipment'],
#  ['unusual utilities he', 'utilities markets utilities markets'],
#  ['present  progress', 'exchange rates exchange rates'],
#  ['others', '1/4  bank'],
#  ['', '614.4 PRETAX mln'],
#  ['mln 2.63 Interest', '49 equity October'],
#  ['', '79.6  mln'],
#  ['monetary time dealers', 'monetary time growth'],
#  ['price slump oil price which', 'currency earnings currency West'],
#  ['28.2  Companys', '28.2  mln'],
#  ['wheat aphids wheat aphids', 'mln wheat hectares'],
#  ['Metals activities Metals activities', 'net mln profit'],
#  ['35.99  yen', 'current Company year'],
#  ['export policy export they', 'export policy export policy'],
#  ['tax Pre profit', '105.9'],
#  ['full Note name', '2.29 2.20 billion'],
#  ['exchange   exchange rates', 'appropriate  levels'],
#  ['it', 'further  company'],
#  ['Full capital name', '2.50 capital 2.38'],
#  ['mln  shortfall', 'mln  dlrs'],
#  ['Commercial 6 banks', 'spot riyal spot 3.7507/09'],
#  ['confirmation', 'lead manager lead manager'],
#  ['companys profits companys profits', 'dropped  word'],
#  ['tonne cif tonne India', 'shipping period shipping period'],
#  ['first oil phase', 'oil town oil Kertih'],
#  ['Generale SGEN.PA Societe Generale SGEN.PA',
#   'Gobain SGEP.PA Gobain SGEP.PA'],
#  ['PLATINUM - PLATINUM 562', 'parentheses'],
#  ['Lex mln shares', '419p'],
#  ['buffer stock buffer stock', 'banks'],
#  ['still  Oldham', 'firm  value'],
#  ['Extraordinary minority items', '193.5 credit mln'],
#  ['', '1.25 BILLION 1.25 DLRS'],
#  ['full  name', 'company'],
#  ['February imports February imports', '9.86 billion 9.86 February'],
#  ['Bank', 'here  this'],
#  ['that', 'still  place'],
#  ['11/16 9 This', 'stg   stg shortfall'],
#  ['mln  guilders', 'aft'],
#  ['', ''],
#  ['central  banks', 'Paris accord Paris accord'],
#  ['billion  Holdings', '51 billion 51 April'],
#  ['tomorrow 50,000 details', '50,000   50,000 raws'],
#  ['U.S.   U.S. Japan', 'Japanese U.S. market'],
#  ['last payment series', '3.501 issue pct'],
#  ['dollar', 'trading range trading range'],
#  ['officials', 'Louvre meeting Louvre meeting'],
#  ['net  equity', '3.46 billion 3.46 billion'],
#  ['present  progress', 'exchange rates exchange rates'],
#  ['seven currency nations', 'James Baker Secretary James Baker'],
#  ['Trade   U.S. Trade figures', '14.8 billion 14.8 January'],
#  ['exchange   exchange rates', 'appropriate  levels'],
#  ['', 'five  cts'],
#  ['pct interest pct that', 'Corp HIA Holiday Corp HIA'],
#  ['dollar', 'three  months'],
#  ['1980/1985  average', 'down  390,500'],
#  ['warrants', '169,200  dlrs'],
#  ['acquisition', 'Orange Counties Orange areas'],
#  ['Bramall shares Bramall shares', 'lower  278p'],
#  ['gold price gold price', '100 2,045/2,070 grammes'],
#  ['FAOs forecast FAOs forecast', 'substantial world cereals China'],
#  ['19.4  Results', 'Camden   Camden January'],
#  ['1987  net', 'tax credit dlr tax credit'],
#  ['North America North company', 'statement'],
#  ['mln dlrs mln it', 'mln dlrs mln 1986'],
#  ['gold price gold price', '100 2,045/2,070 grammes'],
#  ['profit nil profit nil', '445,379 Shr 2,219,961'],
#  ['that', 'still  place'],
#  ['Todd', 'membership'],
#  ['available  That', 'down  2,480,000'],
#  ['J.P. INDUSTRIES SAYS J.P. INDUSTRIES', 'BUY COMPANY BUY COMPANY'],
#  ['mln dlrs mln Assets', 'mln dlrs mln dlrs'],
#  ['recent  most', 'United States United States'],
#  ['', '69  cts'],
#  ['1986 pct stock Dividend', 'May'],
#  ['export taxes export taxes', 'previous tonne brackets'],
#  ['it', 'financial Clevites results'],
#  ['present  yen', 'Paris accord Paris accord'],
#  ['TRADE SOURCES TRADE SOURCES', 'CANNING 0.56(0.361 CANNING 0.56(0.361'],
#  ['it', 'morning assistance stg morning assistance'],
#  ['it', 'director'],
#  ['full dlrs name', 'bank'],
#  ['morning  June', 'thin  conditions'],
#  ['', '89  1986'],
#  ['BUNDESBANK', 'PRESIDENT SCHLESINGER - PRESIDENT SCHLESINGER'],
#  ['13/16 9 This', 'deficit estimate deficit estimate'],
#  ['which', 'international  value'],
#  ['seven  Company', 'AG Brown BBC AG Cie'],
#  ['Soviet East charterers', 'dlrs daily dlrs daily'],
#  ['Cattle slaughter Cattle slaughter', '128,000  head'],
#  ['', ''],
#  ['SAO LUIZ SAO LUIZ', '4.4  MM'],
#  ['negotiations', 'still  Washington'],
#  ['GUAXUPE NIL GUAXUPE TRES', 'NIL'],
#  ['', 'COURIER EXPIRED PUROLATOR COURIER EXPIRED'],
#  ['de Mel de Mel', 'rupees balance rupees support'],
#  ['SAYS UNIT INC SAYS UNIT', 'PUROLATOR COURIER PUROLATOR COURIER'],
#  ['foreign Giovanni firms', 'bank'],
#  ['full mln name', '1985'],
#  ['67  Net', '74,123,837  73,374,398'],
#  ['February meeting February concept', 'recent currency years'],
#  ['when  it', 'pct rate pct January'],
#  ['however  adjustments', 'more  occasion'],
#  ['However pct employers', 'imbalance'],
#  ['board', 'payable stock May'],
#  ['Three cash months', '313  midsession'],
#  ['1987 pension results', 'Test Divisions System Test NEw'],
#  ['3,193,000  Share', 'stock split stock January'],
#  ['Bank Board Loan Bank Board', '5.00 104 pct'],
#  ['regulatory Anchor Waccamaw', 'mln dlrs mln March'],
#  ['really  dollar', 'current Paris levels'],
#  ['it', 'carload lots carload lots'],
#  ['tendering Purolator Hutton', 'tendering Purolator shareholders'],
#  ['ABBOTT', ''],
#  ['vigrously farm it', 'adequate farm quantities'],
#  ['futures contract cotton futures contract', '1,218 review decertification'],
#  ['Details', 'stockholders'],
#  ['', '865.0 1.00 mln'],
#  ['domestic  company', 'mln shares mln shares'],
#  ['Price details Price details', 'June shipment June shipment'],
#  ['tourism earnings Spains tourism earnings', 'mln dlrs mln February'],
#  ['India', 'edible  oils'],
#  ['John   chairman John acquisition', 'South   South Africa'],
#  ['rates', 'discount notes term discount notes'],
#  ['Mortgage Corp Loan Mortgage Corp', 'discount notes term discount notes'],
#  ['BELT TEMPERATURES GRAIN BELT TEMPERATURES', '12.00  GMT'],
#  ['1985  VW', 'three billion three marks'],
#  ['imports', 'import   import surcharges'],
#  ['', ''],
#  ['board', '32876 KG SALE'],
#  ['record date record company', 'record date record split'],
#  ['Period', '18,257,631 dlrs 17,376,480'],
#  ['abatement concern asbestos abatement LVI',
#   'abatement concern asbestos abatement June'],
#  ['preferred  dividend', 'share company August'],
#  ['mln dlrs Revs', '3.4  mln'],
#  ['Financial Baldwin Nisker terms', 'Nisker   Baldwin Nisker redistribution'],
#  ['four  directors', 'other  board'],
#  ['initital  dividend', 'first  1987'],
#  ['year growth it', 'mln dlrs mln dlrs'],
#  ['takeover bid takeover GenCorps', '130  dlrs'],
#  ['2,158,664  Company', '1,200,000   1,200,000 October'],
#  ['consecutive  quarters', 'earnings growth earnings growth'],
#  ['CHANCELLOR LAWSON U.K. CHANCELLOR LAWSON',
#   'INTEREST RATES INTEREST COUNTRIES'],
#  ['Ownership Plan Stock Ownership plan', 'pension plan pension plan'],
#  ['spot oil traders', 'spot oil markets'],
#  ['Bank Board Loan Bank Board', '5.00 OLD RATE pct'],
#  ['', '5,153,109  7,680,350'],
#  ['Yesterday 6 they', 'seven  close'],
#  ['one Packet Products unit', 'Current Specialty Foods division'],
#  ['works spending works Lawson', 'second package year'],
#  ['105,000 tonnes sources', '105,000 tonnes tonnes'],
#  ['committee', 'situation'],
#  ['G-10  G-10', 'Committee meeting Interim Committee today'],
#  ['it', 'Ontario plants Ontario August'],
#  ['12.54  traders', '12.54  kilo'],
#  ['Belgian 30.03/06 franc', '4.829/831  4.831/833'],
#  ['', '1.01  dlrs'],
#  ['Humana', 'earnings'],
#  ['', 'three  cts'],
#  ['FORD', '75 QTLY CTS'],
#  ['I', 'monetary  policy'],
#  ['', '65  cts'],
#  ['steel imports steel imports', 'last  year'],
#  ['', '268.8  mln'],
#  ['mln dlrs mln Abbott', 'mln dlrs mln dlrs'],
#  ['part bnls part bnls', 'top 167a round'],
#  ['trade sources trade it', 'trade sources trade sources'],
#  ['TREASURYS BAKER TREASURYS BAKER', 'TRADE'],
#  ['EC AUTHORISES EC AUTHORISES', '130 TONNES TRADE'],
#  ['EC AUTHORISES EC AUTHORISES', 'TONNES BARLEY TONNES BARLEY'],
#  ['FIRST QUARTER NABISCO FIRST QUARTER', 'DLR GAIN MLN DLR GAIN'],
#  ['one  source', 'eleven'],
#  ['23  dividend', 'operating period operating period'],
#  ['temporary export he', 'export earnings export earnings'],
#  ['business', 'Video   Ambrose Video Publishing'],
#  ['budget deficit budget deficit', 'trade deficit trade deficit'],
#  ['Forms Division Business Forms which',
#   'Forms Division Business Forms Division'],
#  ['5,931,324 nil Share', 'reverse  split'],
#  ['', '12.5 half mln'],
#  ['stock', 'six  months'],
#  ['2.21 liquor Income', '67 liquor share'],
#  ['orange output orange output', 'frost'],
#  ['feed wheat feed they', 'breadmaking'],
#  ['YORK DEALERS NEW YORK DEALERS', 'OPEN FED BUYING MARKET'],
#  ['157,941 Shr Revs', '858,624 Shr loss'],
#  ['primary  99ct', '1.81 billion 1.81 billion'],
#  ['it', 'investment purposes investment purposes'],
#  ['Major  reasons', 'decline'],
#  ['', 'eight  cts'],
#  ['dealer reports dealer dollar', 'just  midday'],
#  ['expenses', 'coupon debt coupon debt'],
#  ['net Oper excludes', 'depreciation expense depreciation expense'],
#  ['economic  currencies', 'economic  which'],
#  ['', '15.66 billion 15.66 billion'],
#  ['raw  Tate', 'raw  Silvertown'],
#  ['it', 'other  stock'],
#  ['', '38  cts'],
#  ['Other Beckman Corp drugs', 'GENE TPA GENE marketing'],
#  ['game operations amusement game operations', 'nine dlrs mths'],
#  ['', '20  cts'],
#  ['', '35  cts'],
#  ['', '1/2 21 cts'],
#  ['grain ships grain ships', 'Orleans elevators New Orleans elevators'],
#  ['unspecified tender conditions', 'tender offer tender offer'],
#  ['', '10.05 dlrs mln'],
#  ['next  it', 'next  year'],
#  ['', '67  cts'],
#  ['30  which', 'United States United States'],
#  ['trade sources trade sources', 'May shipment May shipment'],
#  ['', '5.08 billion 5.08 billion'],
#  ['planning department planning department', '1.5 billion 1.5 dlrs'],
#  ['8  they', '22 East Spain'],
#  ['sugar   sugar indications', '1 Reunion/1 c'],
#  ['17,000  hss', 'mt mt barley flour'],
#  ['1987 tax net', 'credit   tax credit goodwill'],
#  ['6,057,000  Net', '5,900,000 securities sales dlrs'],
#  ['oil reserves oil reserves', 'nine 4.7 pct'],
#  ['common  stock', '- rights ex - basis'],
#  ['planning department planning department', 'total  exports'],
#  ['stations', 'sale'],
#  ['756 4.8 MLN', '464 12.7 MLN'],
#  ['', 'MLN DLRS MLN DLRS'],
#  ['12,300  they', '12,300  September'],
#  ['Shr', 'Bancorp Inc Continental Bancorp January'],
#  ['831,398  Share', 'stock split stock May'],
#  ['', '35  cts'],
#  ['ago mln reserve', 'outstanding pct March'],
#  ['immediately grade price', 'carload quantities carload quantities'],
#  ['currency position currency position', 'mln dlrs mln dlrs'],
#  ['Shr', 'Previous  loss'],
#  ['1,600,258  Share', '1986 pct stock Mayaguez'],
#  ['', '4,618,232 dlrs 2,959,141'],
#  ['regulatory group Terms', 'regulatory group approvals'],
#  ['', '20 Class cts'],
#  ['1987  net', 'stock dividends stock dividends'],
#  ['it', 'Dillon Read Dillon Read'],
#  ['', 'Avg  shrs'],
#  ['capital operations sector capital operations', '56.9 billion 56.9 1985'],
#  ['', '27.4 Shr mln'],
#  ['mln dlrs mln he', 'mln dlrs mln result'],
#  ['', '6,300,000 Loan loss dlrs'],
#  ['However water filtration revenues', 'Cosentino   Louis Cosentino analysts'],
#  ['expansion', 'day Cape Spencer year'],
#  ['sugar growers sugar it', 'sugar industry sugar industry'],
#  ['BILLS AVERAGE BILLS AVERAGE', ''],
#  ['1,624,000 Nine Company', 'stock ownership stock ownership'],
#  ['six  holder', 'outstanding American shares'],
#  ['4.5 billion 4.5 which', 'companys'],
#  ['expansion', 'day Cape Spencer year'],
#  ['week day Tenders', 'day bills day bills'],
#  ['Council session Council session',
#   'coordination meeting Community coordination 1100'],
#  ['', '82,000  Sales'],
#  ['accounting   accounting results', 'mln dlrs mln dlrs'],
#  ['', '2.55 billion 2.55 billion'],
#  ['Shr', '19 tax share'],
#  ['price cut price cut', '51 heating cts'],
#  ['Mining Corp Newmont Mining it', '65.75 copper cents'],
#  ['', '14.35 billion 14.35 billion'],
#  ['', '5.14 billion 5.14 billion'],
#  ['qtr figures qtr figures', 'one carryforward share'],
#  ['trade reports trade government', 'original Islamic tender'],
#  ['stockpile   stockpile he', 'stockpile   stockpile management'],
#  ['car sales car it', 'trade figures trade figures'],
#  ['charge offs charge offs', 'mln dlrs mln dlrs'],
#  ['', '26.0 MLN MARCH'],
#  ['', '210 MLN TONNES MARCH'],
#  ['USDA - USDA U.S.', '610 MLN MLN'],
#  ['', ''],
#  ['JUICE YIELD ORANGE JUICE YIELD', 'FLORIDA CROP FLORIDA CROP'],
#  ['Operating dlrs net', 'loss carryforwards tax loss carryforwards'],
#  ['', ''],
#  ['Cake Exports Meal', 'month  6,036'],
#  ['departments estimates departments estimates', 'crop   crop conditions'],
#  ['estimates', '1986/87  April'],
#  ['Agriculture Department U.S. Agriculture Department',
#   'fourth Soviets agreement'],
#  ['ago  USDA', '261  acre'],
#  ['previously cwt department', 'cwt   cwt acre'],
#  ['Loan Program Storage Loan Program', 'Month Loan Nine Month Loan'],
#  ['debt restrictions debt restrictions', 'rights'],
#  ['grain imports grain imports', 'miscellaneous  grains'],
#  ['Note - Note Season', 'End Stocks End Stocks'],
#  ['month  USDA', '1.20  mln'],
#  ['USDA forecast USDA forecast', '9.58 grain mln'],
#  ['', 'FOR-1 SPLIT FOR-1 SPLIT'],
#  ['month  exports', '15.96  mln'],
#  ['month  USDA', '6.60 wheat mln'],
#  ['month  Exports', '17.71  mln'],
#  ['West   West Europe', 'thousand 29.4 1986/87'],
#  ['stockpile   stockpile he', 'stockpile   stockpile management'],
#  ['month  Exports', 'mln  27.62'],
#  ['1986/87 Residual projections', 'marketing loan marketing loan'],
#  ['month mln bales department', 'mln cotton bales'],
#  ['month  USDA', 'mln exports tonnes'],
#  ['29  it', 'One  May'],
#  ['National   National Beverage', 'mln dlrs mln dlrs'],
#  ['full  name', 'company'],
#  ['mln dlrs mln Fluorocarbon', 'mln dlrs mln dlrs'],
#  ['Current  qtr', 'sale   sale securities'],
#  ['mln  Avg', 'Avg shares Avg 11,200,000'],
#  ['', '35  Net'],
#  ['thousand  Prev', 'Sept - Sept Aug.'],
#  ['which', 'current  management'],
#  ['Moscow', 'mln tonnes mln 1986/87'],
#  ['it', '8  letter'],
#  ['TONNES WHEAT TONNES WHEAT', '1987/88  DELIVERY'],
#  ['Realty Income Health Realty Quarter', 'full  earnings'],
#  ['', 'six  cts'],
#  ['Telkon Corp. Telkon companies', 'electronic  merchandise'],
#  ['NOTE:1986 net NOTE:1986 net', '3rd qtr 3rd qtr'],
#  ['Overall Television Centel', 'seven  states'],
#  ['', '10  cts'],
#  ['Class B Class B', '1/2 1 cts'],
#  ['U.S. EXPORTERS U.S. EXPORTERS', 'SPLIT DELIVERY SPLIT DELIVERY'],
#  ['TONNES CORN TONNES CORN', '1986/87  DELIVERY'],
#  ['transit Note Rice', 'End Stocks End 21.19'],
#  ['lastest dlrs assets', '2.55 capital gain December'],
#  ['latest dlrs assets', 'preferred capital gain stock'],
#  ['14.55 14.55 14.55 Domes', 'Nil Nil Nil Nil Nil'],
#  ['marketing year marketing year', 'wheat'],
#  ['diligence investigations diligence company',
#   'diligence investigations diligence investigations'],
#  ['onwards  He', 'reporters'],
#  ['NIL NIL NIL Domes', 'End Stocks End Stocks'],
#  ['CCC stocks CCC purchases',
#   'Program initiative Enhancement Program December'],
#  ['BREAD WHEAT BREAD WHEAT', '1986  tonnes'],
#  ['entire  transaction', 'Central District Central District'],
#  ['which', 'United States United States'],
#  ['4.80 4.80 4.80 Domes', '5.06 5.06 5.10 5.06 Exports'],
#  ['13.48 13.48 13.48 Domes', '1985/86 EC-12 SOYBEAN 03/09/86'],
#  ['0.25 0.35 Domes', '0.07 0.12 0.07 0.07'],
#  ['22.25 pct it', '22.25 pct dlrs'],
#  ['Start Stocks Start Stocks', 'lbs bales lbs bales'],
#  ['1987 Enhancement Program department',
#   'Program   Enhancement Program initiative'],
#  ['NIL NIL NIL Domes', 'mln rice tonnes'],
#  ['yield   yield increase', 'box count box count'],
#  ['', '10  cts'],
#  ['stockpiled  Noranda', 'stockpiled  supplies'],
#  ['', '10  cts'],
#  ['', '15  cts'],
#  ['', ''],
#  ['federal  government', 'alternative pilot energy'],
#  ['eight grain ships ships', 'Merchants Exchange Portland Merchants Exchange'],
#  ['88  Shr', '154.5 2.55 mln'],
#  ['mln dlrs mln it', 'mln dlrs mln dlrs'],
#  ['loan data business loan data', '334.28 billion 334.28 billion'],
#  ['Average  borrowings', 'first mln period'],
#  ['Level VI Level VI', 'Y - Y CWT'],
#  ['Ill', 'ago  period'],
#  ['brokering service brokering service', 'substantially  markets'],
#  ['it', 'one  record'],
#  ['ago  Inventory', '75,985,696'],
#  ['28  National', 'home properties nursing home properties'],
#  ['its', '93 companys pct'],
#  ['offshore  hydrocarbons', 'commercial  quantities'],
#  ['1986  Patient', 'backlog   backlog orders'],
#  ['also  it', 'acquisition alternatives acquisition alternatives'],
#  ['', 'preferred Shr dividends'],
#  ['Isis', 'part'],
#  ['world price world price', '0.53 U.S. Adjustments'],
#  ['Sorghum sales Sorghum sales', 'main  buyers'],
#  ['30 TWO FED', 'TWO BILLION TWO MARCH'],
#  ['FED', 'MLN DLRS MLN APRIL'],
#  ['', 'TWO MLN APRIL'],
#  ['billion mln Danworth', 'operating  energy'],
#  ['', '306.8  Assets'],
#  ['', 'Revs  2,199,238'],
#  ['795,009 Shr Revs', '3,818,258  2,070,772'],
#  ['qtr   qtr Net', 'vs  year'],
#  ['second week they', 'two Friday days'],
#  ['stockpiled  Noranda', 'stockpiled  supplies'],
#  ['M-1', 'Reuters'],
#  ['it', 'operating units operating units'],
#  ['Communications Commission Communications Jacor',
#   'Communications Commission Communications Commission'],
#  ['purpose funds purpose funds', '63.8 billion 63.8 dlrs'],
#  ['over  It', 'sales'],
#  ['which', '1,518,700  soybeans'],
#  ['IT', 'INVESTOR GROUP INVESTOR GROUP'],
#  ['', 'five  cts'],
#  ['RATE SYSTEM EXCHANGE RATE SYSTEM', 'GREATER STABILITY GREATER STABILITY'],
#  ['netback values netback values', 'gasoline prices gasoline prices'],
#  ['key  he', 'key  variables'],
#  ['previous  field', 'southern  Louisiana'],
#  ['time  farmers', 'market animals market animals'],
#  ['export sources export sources', 'September shipments September shipments'],
#  ['accounting change accounting which', 'ago  1st'],
#  ['', ''],
#  ['', '25  Net'],
#  ['Full reduction name', 'reduction expenses reduction expenses'],
#  ['Atcor shares Atcor It', '191,400  shares'],
#  ['5,632,044 Oper Oper', 'operations   operations 49,040'],
#  ['only  I', 'time'],
#  ['Gabelli New York subsidiary', 'Stock Exchange Philadelphia Stock Exchange'],
#  ['asset sale asset partnership', 'Marcus Schloss Marcus Schloss'],
#  ['oper excludes oper excludes', 'discontinued pension plan 1,015,000'],
#  ['IT', 'ACQUISITION PROPOSALS ACQUISITION PROPOSALS'],
#  ['offers', 'further  details'],
#  ['', ''],
#  ['Inc INTF Systems Inc acquisition', 'Winterhalter share Winterhalter share'],
#  ['', '1,546,000 Shr profit'],
#  ['trade surplus trade surplus', 'mln dlrs mln dlrs'],
#  ['Fed', '6.10 funds rate pct'],
#  ['mln Shr Revs', 'tax   tax 51,294'],
#  ['Total  deposits', '17.18 billion 17.18 January'],
#  ['', 'YEN - YEN DEALERS'],
#  ['AT RECORD AT RECORD', ''],
#  ['York close New York Sterling', '1.6190/00  1.6195/05'],
#  ['institutional securities firms they', 'heavy  selling'],
#  ['Buenos Aires Buenos Millet', 'Buenos Aires Buenos Aires'],
#  ['bond market bond Giordano', 'bond market bond helmets'],
#  ['acceptance rates bankers acceptance rates', '60 term days'],
#  ['they', 'yen'],
#  ['only  sectors', 'Sydneys ports Sydneys ports'],
#  ['normal Balao spokesman', 'normal Balao levels'],
#  ['ago mln It', '353,045  tonnes'],
#  ['Domestic  supplies', 'origin oils origin oils'],
#  ['interest rates interest he', 'interest rates interest rates'],
#  ['it', 'company restructuring company restructuring'],
#  ['why explanation it', 'tariffs'],
#  ['property development property shares', 'beneficial Sdn owner'],
#  ['who', 'five  dependents'],
#  ['more  he', 'more  U.S.'],
#  ['trade sanctions trade it', 'trade sanctions trade Tokyo'],
#  ['last point SAMA', 'day paper day kingdom'],
#  ['growing  Uganda', 'more mln 1985/6'],
#  ['Industry Association Confectionery Industry Association', 'statement'],
#  ['dry production spell', 'actual  damage'],
#  ['21.5  figures', '21  workforce'],
#  ['social  that', 'Bloc states East Bloc states'],
#  ['BUYING DOLLARS ACTIVELY BUYING DOLLARS', 'TOKYO - TOKYO DEALERS'],
#  ['mln mln they', 'mln mln bales'],
#  ['real  ANZ', 'real  wages'],
#  ['Pty Ltd Australia Pty it', '2,160 Refinery Copper dlrs'],
#  ['142.30   142.30 It', '141.85  yen'],
#  ['Texacos assets Texacos assets', 'Pennzoil judgment Pennzoil judgment'],
#  ['Co Inc Co It', '4,540,000  time'],
#  ['when bonus Amax', 'local pct companies'],
#  ['highest  depreciation', 'U.S. Dollar U.S. Dollar'],
#  ['market price market group', 'dividend imputation dividend imputation'],
#  ['six 6 maturities', '6 6 pct'],
#  ['iron ore iron which', 'high  quality'],
#  ['it', '355,652  1985'],
#  ['components   components it', 'oil  trade'],
#  ['weak commodity he', 'commodity exports commodity exports'],
#  ['financial  details', 'debt restructuring Domes debt value'],
#  ['circulation', 'mln exchequer target'],
#  ['1986  inflation', 'pct rate pct rate'],
#  ['which', '0838  GMT'],
#  ['open  they', 'open  Frankfurt'],
#  ['Morgan shares Morgan shares', 'pence  Fridays'],
#  ['Operating mln credit profit', '0.1 Speciality mln'],
#  ['highest  rises', 'forest  industries'],
#  ['Kenyan  shilling', '16  shillings'],
#  ['wheat markets wheat markets', 'China'],
#  ['26p Norcros shares Williams', '785p'],
#  ['Comites actions Het Comites actions',
#   'Animal Feed European Animal Manufacturers'],
#  ['they', 'other  crops'],
#  ['German Confectionery Industry grindings', 'European  countries'],
#  ['ECU bond ECU bond', '490 exercise dlrs'],
#  ['18 trading Commonwealths', 'early pct February'],
#  ['0.9 mln proceeds', '0.5p Hepworth 227.5p'],
#  ['exploration  Bond', 'exploration  U.S.'],
#  ['they', '0.5  pct'],
#  ['Arrow shares Blue Arrow shares', 'lower  670'],
#  ['spot riyal spot riyal', '3.7498/7503'],
#  ['500  Platinum', 'highest  October'],
#  ['common Borg board', 'five share purchase right'],
#  ['price index input price index', 'pct drop pct February'],
#  ['Statoil', 'field'],
#  ['sale price sale price', 'flotation offer flotation April'],
#  ['more  it', 'more  competition'],
#  ['', 'six  months'],
#  ['Hillsdown shares Hillsdown shares', '266p'],
#  ['Turnover', 'Respiratory Far system'],
#  ['Common Toronto Stock stock', '25.00  1981'],
#  ['it', 'dollar purchases bank dollar purchases'],
#  ['LME Board LME Board', '1 T July'],
#  ['5/8  SAMA', 'day accounts day Kingdom'],
#  ['arrival whites June arrival they', 'arrival whites June arrival whites'],
#  ['central  bank', '11/16 9 pct'],
#  ['142.30   142.30 It', '141.85  yen'],
#  ['Peter Huggler Peter Huggler', 'recent Bank Switzerland'],
#  ['1/10 palm traders', '1/10 palm shipment'],
#  ['trade journal trade journal', '790.00 brand zinc tonne'],
#  ['few input Tinker', 'year oil index'],
#  ['pessimistic  He', 'world trade world trade'],
#  ['Fixed quarter investments', '1985 pct quarter'],
#  ['still  Washington', 'budget deficit budget deficit'],
#  ['braking effects braking effects', 'most  year'],
#  ['dlrs   dlrs Shr', '1.02  dlrs'],
#  ['owning', 'tender price tender price'],
#  ['', '32 half Net'],
#  ['Pretax mln profit', '12.6  mln'],
#  ['Other tape details', 'metropolitan tape area'],
#  ['possible  stock', 'friendly  inquiries'],
#  ['Thirty four Thirty workers', 'coal   coal mine'],
#  ['defence   defence spokesman', 'British  luxuries'],
#  ['budget compromise budget that', 'budget process budget process'],
#  ['financial  details', 'debt restructuring Domes debt value'],
#  ['approval process approval process', 'expiration date expiration date'],
#  ['Compact Video Compact Video', 'fiscal companys year'],
#  ['1986 Oper net', 'tax credit dlr tax credit'],
#  ['USAIR', 'PIEDMONT SHARES MLN PIEDMONT SHARES'],
#  ['import licences tea import licences', 'Reuters reports Reuters reports'],
#  ['economic  results', 'PSD   PSD policies'],
#  ['', ''],
#  ['one  dlr', '2.17 billion 2.17 billion'],
#  ['Corona warrants Corona warrants', 'C share series C Royex'],
#  ['South Atlantic South Atlantic', 'investment banks investment boards'],
#  ['Savings Home Association', 'Upper East Upper East'],
#  ['feeder steers feeder that', 'slaughter weight slaughter weight'],
#  ['Southwestern  producers', 'gas supply gas supply'],
#  ['pct  It', 'higher  pensions'],
#  ['IT', 'MLN DLRS MLN CASH'],
#  ['Shr  profit', '16,000 loss loss'],
#  ['', '1.10 billion 1.10 billion'],
#  ['it', '55  those'],
#  ['Great Britain Great he', 'manufactured percentage goods'],
#  ['Bank notes Bank notes', '941.5 mln mln'],
#  ['11/16 bank rates', 'intervention levels intervention levels'],
#  ['buyback   stock buyback that', 'debt'],
#  ['Cattle slaughter Cattle slaughter', '126,000  head'],
#  ['trade deficit trade deficit', '1.94 billion 1.94 February'],
#  ['trade surplus Japans trade surplus', '2.13 billion 2.13 March'],
#  ['it', 'May'],
#  ['', ''],
#  ['it', 'one mln one'],
#  ['', '30.0  mln'],
#  ['18.1  it', '18.1  1986'],
#  ['203,000  figures', 'Rotterdam traffic Rotterdam products'],
#  ['1986  net', 'share  property'],
#  ['1979/81 price inflation', 'oil prices oil prices'],
#  ['', 'Avg 1.12 shrs'],
#  ['pct  coffee', 'pct gas February'],
#  ['also  department', 'protein protein wheat premium'],
#  ['Bank Board Loan Bank Board', '275 OLD RATE days'],
#  ['six  months', 'tax   investment tax credits'],
#  ['24 1.2 It', 'New Hampshire New Hampshire'],
#  ['bottom core he', 'bottom core line'],
#  ['Colombia', 'calendar year calendar year'],
#  ['', 'RISE - DECEMBER RISE OFFICIAL'],
#  ['lower  ALP', '11.4  1986'],
#  ['Reebok', 'October'],
#  ['excludes', 'mln dlrs mln dlrs'],
#  ['353 mln This', '400 liquidity stg'],
#  ['gold ore gold ore', '0.1 sulphide ounce'],
#  ['service contracts term service agreement',
#   'Arrow shareholders Blue Arrow shareholders'],
#  ['board', 'May One May record'],
#  ['it', 'carload lots carload lots'],
#  ['', ''],
#  ['', '12 billion 12 billion'],
#  ['', 'stock distribution stock distribution'],
#  ['BILL AVERAGE BILL RATE', 'PCT - PCT OFFICIAL'],
#  ['', '29.5  mln'],
#  ['NVHomes LP NVHomes LP', 'two distribution unitholders'],
#  ['', ''],
#  ['DEPARTMENT STORES DILLARD DEPARTMENT STORES', 'DLRS CASH MLN DLRS CASH'],
#  ['', ''],
#  ['Trust Co U.S. Trust Co', '1/2 7 pct'],
#  ['offering', 'May.'],
#  ['federal  agency', '1.0  December'],
#  ['', '169,000 Investment securitiesd dollars'],
#  ['first 1.75 bank', 'same  period'],
#  ['21.85 pct it', 'unchanged pct 22.50'],
#  ['billion 1.04 dlrs', 'non Brazil accrual'],
#  ['1986 Program it', 'Program initiative Program initiative'],
#  ['54 Shr cts', 'shrs primary shrs 14,500,737'],
#  ['which', '600,000  tonnes'],
#  ['Shr', 'loss   loan loss provision'],
#  ['interested talks Commonwealth', '400  workers'],
#  ['', 'stock split stock May'],
#  ['25,000 medium they', '25,000 medium tonnes'],
#  ['which', '6 6 pct'],
#  ['Plymouth Shops Plymouth divisions', 'fiscal store 1985'],
#  ['it', 'U.S.'],
#  ['Period', '11,690,000 Shr 8,724,000'],
#  ['overseas  operations', 'future  growth'],
#  ['year Shr net', '1,977,000 tax half'],
#  ['insurance revenues insurance revenues', 'last mln years'],
#  ['11.1 profit Net', '2,557,000 tax year'],
#  ['1,533,273  Period', '1,533,273  half'],
#  ['', '2.6 Shr mln'],
#  ['Full dlrs name', 'mln dlrs NOTE'],
#  ['company spokesman company spokesman', 'further  investigation'],
#  ['more  he', 'more  U.S.'],
#  ['30  it', '30  pct'],
#  ['3rd qtr 3rd qtr', '260,000 loss carryforward dlrs'],
#  ['freight Jeddah freight traders', 'tonne cost tonne cost'],
#  ['', 'stock ownserhip stock ownserhip'],
#  ['Net', '553,000 loan loss dlrs'],
#  ['Kuwait', 'way United Arab Gulf'],
#  ['accruing  loans', '1.22 billion 1.22 end'],
#  ['first  quarter', '937,000  dlrs'],
#  ['public brokerage Kahn', 'brokerage offices brokerage offices'],
#  ['Period', 'tax provision dlr tax provision'],
#  ['', ''],
#  ['1,173,000 securities Company', 'December'],
#  ['', 'Avg  shrs'],
#  ['six  Share', 'stock split stock June'],
#  ['government approval government Swift',
#   'government approval government plant'],
#  ['cts  Shr', '1.80 billion 1.80 billion'],
#  ['Fed', 'so  dollar'],
#  ['', 'Avg  shrs'],
#  ['', '29.5  mln'],
#  ['', '32  Net'],
#  ['', '36  cts'],
#  ['', '6.9  cts'],
#  ['', '7.1  cts'],
#  ['board', '30  April'],
#  ['which', '100 AFG Industries dlr'],
#  ['Fund Fund Securities Fund Fund', '30 board record'],
#  ['previously  It', 'Warners stock Warners stock'],
#  ['Bank USA Westminster Bank USA', 'Bank PLC Westminster Bank PLC'],
#  ['', '4.5 Shr mln'],
#  ['', '1/2 54 cts'],
#  ['Buitonis consolidated Buitonis revenue', 'mln lire mln 1985'],
#  ['that', 'apartheid system apartheid system'],
#  ['acquisition', 'compatible cost reduction companies'],
#  ['mln dlrs mln Company', 'stock ownership stock December'],
#  ['REVLON GROUP REVLON GROUP', 'SHR CASH SHR CASH'],
#  ['which', '1/2 7 pct'],
#  ['more Crazy Adds', 'rights expiration rights expiration'],
#  ['', '22.6  Note'],
#  ['11.1  government', 'eight  pct'],
#  ['', 'share figures share figures'],
#  ['', ''],
#  ['Bar share Bar Resdel', 'Bar share Bar share'],
#  ['outstanding  acquisition', 'regulatory  approvals'],
#  ['31  company', 'common mln stock'],
#  ['Net Shr loss', 'Avg Shr 4,322,816'],
#  ['', '319.0 3.6 mln'],
#  ['', 'US SPRINT US SPRINT'],
#  ['VBI', '10.000 prices dlrs'],
#  ['', '73  Net'],
#  ['50  pct', 'Total Exploration Total S.A.'],
#  ['it', 'well  year'],
#  ['oper data oper data', 'six  mths'],
#  ['trade sources trade sources', 'June shipment June shipment'],
#  ['earlier mln provision', 'first loan 1986'],
#  ['', 'six 7 cts'],
#  ['Other  owners', '3.34 Prudential Insurance pct'],
#  ['', ''],
#  ['', '3,959,011  2,608,571'],
#  ['final time reporting', 'trade balance trade balance'],
#  ['lawsuits', 'original  offer'],
#  ['five Intermagnetics it', 'companys stock companys stock'],
#  ['', '31  4,078,000'],
#  ['Co subsidiary Electric Co Reliance', 'former  owner'],
#  ['year mln It', '1986 Arthurs revenues'],
#  ['Current  periods', 'shr figures shr splits'],
#  ['closing date closing date', 'Co Ltd Electric Co Ltd'],
#  ['Period', '12.2  9,214,000'],
#  ['also  it', 'Pierre three Schoenheimer'],
#  ['Amsouths assets Amsouths assets', 'mln dlrs mln dlrs'],
#  ['', '20.1  mln'],
#  ['Hadsons stock Hadsons Seaxe', 'Paris basin Paris France'],
#  ['companies', 'microcomputer software market microcomputer software'],
#  ['', '6.5  cts'],
#  ['', '6.6  cts'],
#  ['', '7.1  cts'],
#  ['', '6.1  cts'],
#  ['', '7.1  cts'],
#  ['', '6.5  cts'],
#  ['Dome   Current Dome shareholders', 'new  subsidiary'],
#  ['Per  results', 'dividend requirements dividend requirements'],
#  ['', 'loss carryforwards tax loss carryforwards'],
#  ['which', 'mln dlrs mln year'],
#  ['', '2,154,000 Shr profit'],
#  ['mln dlrs mln Revenues', 'billion telephone dlrs'],
#  ['Goodyears share Goodyears share', 'takeover   takeover bid'],
#  ['', 'ownership Aug stock ownership Aug'],
#  ['National Corp American National Corp', 'Chicago Corp. First Chicago Corp.'],
#  ['Astra voting stock', 'free  shares'],
#  ['Investment securities Investment securities',
#   'Corrects name Corrects parent'],
#  ['shr figures shr figures', 'April'],
#  ['Nor British Quests', '1200  area'],
#  ['three capital Marshall', 'three capital years'],
#  ['transition', 'network use network use'],
#  ['Contract terms Contract terms', 'Energy Board National Energy Board'],
#  ['company spokesman company spokesman', 'month  May'],
#  ['final time reporting', 'trade balance trade balance'],
#  ['it', 'Half International Robert Half International'],
#  ['mln dlrs mln Atlantic', 'mln dlrs mln dlrs'],
#  ['U.S. competitors U.S. competitors', 'mln dlrs mln 1986'],
#  ['', 'five  cts'],
#  ['government approval government Swift',
#   'government approval government plant'],
#  ['NASDAQ listing NASDAQ it', 'acquisition'],
#  ['', '714,670  Sales'],
#  ['Modern Mailers Modern Mailers', 'computer   computer service'],
#  ['Export guesses Export guesses', '16.4  mln'],
#  ['it', 'earnings'],
#  ['', ''],
#  ['mln dlrs mln purchase', 'undisclosed  cast'],
#  ['87 standards board Net', 'mln dlrs mln 1986'],
#  ['3,397,000  Company', 'February'],
#  ['', ''],
#  ['', '28.60 billion 28.60 billion'],
#  ['Per 9.27 results', 'preferred  dividends'],
#  ['stock split stock it', '24  record'],
#  ['Nine  mths', '2,543,711  2,453,520'],
#  ['', 'six  cts'],
#  ['Winchester', 'cigar market cigar market'],
#  ['', '7,277,340 Shr 1,378,372'],
#  ['Gander Mountain Gander Mountain', 'outdoor brand name catalogs'],
#  ['USTR official USTR official', 'EC regulation EC regulation'],
#  ['abate  it', 'policy'],
#  ['dividend', 'first  1987'],
#  ['mth net mth net', 'mining operations coal mining operations'],
#  ['working   working Ericsson', 'working   working Telefonica'],
#  ['outlook', 'year'],
#  ['net  profit', 'product prices product prices'],
#  ['major  product', 'New York New York'],
#  ['MCC shareholders MCC shareholders', '35 cash distribution share'],
#  ['', 'Avg  shrs'],
#  ['qtr figures qtr figures', 'FHLB borrowings FHLB borrowings'],
#  ['operating Sperry net', 'mln dlrs mln dlrs'],
#  ['whatsoever  he', 'impact'],
#  ['share impact share he', '1987  results'],
#  ['1986  net', 'manufacturing equipment manufacturing equipment'],
#  ['preferred A Empire share', 'holders option holders May'],
#  ...]

# %% [markdown]
# clean the entity pairs..

# %% [markdown]
# #### Relation / Predicate Extraction

# %% [markdown]
# This is going to be a very interesting aspect of this article. Our hypothesis is that the predicate is actually the main verb in a sentence.

# %% [markdown]
# The function below is capable of capturing such predicates from the sentences. Here, I have used spaCy’s rule-based matching

# %%
sent= candidate_sentences["text"]

# %%
def get_relation(entity_pairs):
    
    doc = nlp(sent)
    
    # Matcher class object 
    matcher = Matcher(nlp.vocab)
    
    #define the pattern 
    pattern = [#{'DEP':'ROOT'}, 
               {'DEP':'prep','OP':"?"},
               {'DEP':'agent','OP':"?"},  
               {'POS':'VERB'#,'OP':"?"
               }] 
    
    matcher.add("matching_1", [pattern]) 
    matches = matcher(doc)
    
    k= len(matches) - 1
    
    span= doc[matches[k][1]:matches[k][2]]
    rel= [doc[matches[k][1]: matches[k][2]] for k in range(len(matches))]
    
    return rel

# %%
get_relation(entity_pairs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_64245/3003485940.py in <module>
# ----> 1 get_relation(entity_pairs)
#
# /tmp/ipykernel_64245/3394858710.py in get_relation(entity_pairs)
#       1 def get_relation(entity_pairs):
#       2
# ----> 3     doc = nlp(sent)
#       4
#       5     # Matcher class object
#
# ~/.local/lib/python3.10/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1000         DOCS: https://spacy.io/api/language#call
#    1001         """
# -> 1002         doc = self._ensure_doc(text)
#    1003         if component_cfg is None:
#    1004             component_cfg = {}
#
# ~/.local/lib/python3.10/site-packages/spacy/language.py in _ensure_doc(self, doc_like)
#    1091         if isinstance(doc_like, str):
#    1092             return self.make_doc(doc_like)
# -> 1093         raise ValueError(Errors.E866.format(type=type(doc_like)))
#    1094
#    1095     def _ensure_doc_with_context(self, doc_like: Union[str, Doc], context: Any) -> Doc:
#
# ValueError: [E866] Expected a string or 'Doc' as input, but got: <class 'pandas.core.series.Series'>.

# %%
#get_relation("John completed the task")

# %%
relations = [get_relation(i) for i in tqdm(entity_pairs)]
# Out:
# 100%|████████████████████████████████████| 10788/10788 [01:42<00:00, 105.52it/s]

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# [(won)]    1
# dtype: int64

# %% [markdown]
# #### Build a Knowledge Graph

# %% [markdown]
# We will finally create a knowledge graph from the extracted entities (subject-object pairs) and the predicates (relation between entities).
#
# Let’s create a dataframe of entities and predicates

# %%
entity_pairs
# Out:
# [['Michael Smith Representative Michael Smith', 'week International dispute'],
#  ['government', 'further paper details'],
#  ['21 hour they', 'hour basis hour oil'],
#  ['seven  Products', '57 export pct'],
#  ['Indonesian export exports', 'bank   bank figures'],
#  ['it', 'shipping movements shipping movements'],
#  ['Total 6.87 membership', 'exchange'],
#  ['shipment', 'April'],
#  ['ore   ore capacity', 'first treatment mid-1988'],
#  ['strategy', 'that'],
#  ['thirds majority thirds majority', 'extension'],
#  ['dealers', 'call money call money'],
#  ['ore tonnage ore tonnage', 'least operations 1993'],
#  ['further  It', 'further  details'],
#  ['Farm products U.S. Farm issues', 'same  table'],
#  ['pct stake pct it', 'enlarged dividend capital'],
#  ['5.8 timber Interest', 'mln debit mln debit'],
#  ['Partly bankers offsetting', 'mln  system'],
#  ['proper  Kim', 'proper  level'],
#  ['late Alberta statement', 'late Alberta 1989'],
#  ['year Western It', 'gold project gold project'],
#  ['recent industry data', 'pct rise pct rise'],
#  ['10.0 percentage profit', '11.0 U.K. mln'],
#  ['Manhattan Banks Chase Manhattan Banks',
#   'merchant banking merchant banking'],
#  ['which', 'net electrolysis 1985'],
#  ['full 20.20 name', '110 20.20 francs'],
#  ['Spain   Spain which', 'EC stance EC favour'],
#  ['protectionist   protectionist he',
#   'protectionist   protectionist legislation'],
#  ['South Korea South Thailand', 'down zinc 14,937'],
#  ['todays  they', 'todays  result'],
#  ['sugar   sugar traders', 'sugar   sugar June'],
#  ['they', 'sale'],
#  ['Buttrose', 'long  term'],
#  ['these', 'possibly  June'],
#  ['trees   trees effects', 'three  years'],
#  ['BONUS ISSUE BONUS ISSUE', 'B  SHARES'],
#  ['foreign housing earnings', 'housing downturn housing downturn'],
#  ['five  It', 'half   half 1985/86'],
#  ['weeks  talks', 'tariffs'],
#  ['who', 'here company Reuters'],
#  ['rationalisation plan industry rationalisation plan',
#   'few production years'],
#  ['general  which', 'Kong market Hong Kong market'],
#  ['protectionist   protectionist he',
#   'protectionist   protectionist legislation'],
#  ['dollar', 'New   New close'],
#  ['Minister Harmoko Information Minister Harmoko',
#   'economic cabinet situation'],
#  ['central  bank', '11/16 9 pct'],
#  ['net  profit', '50 mln 1985'],
#  ['cane crush cane crush', 'normally  December'],
#  ['tonnage', 'rebate figure rebate figure'],
#  ['Meta INZI.MI Meta INZI.MI', '49.9 Montedison Spa pct'],
#  ['years average years average', '1.55 exchange dlrs'],
#  ['drop', 'fertilizer division companys fertilizer division'],
#  ['dollars value dollars value', 'still  that'],
#  ['Five withdrawal which', 'diluted Auxtons voting basis'],
#  ['150,000  company', '114,000 California Biotech dlrs'],
#  ['', '1/2  cts'],
#  ['1.2 billion 1.2 Unilever', 'toiletry brands toiletry brands'],
#  ['IT', 'SEVERAL  PARTIES'],
#  ['mln dlrs mln It', 'mln shares mln shares'],
#  ['Shintaro Abe Chairman Shintaro Abe', 'April'],
#  ['', '4,865,249 half 4,495,021'],
#  ['industrial  action', 'compensation laws workers compensation laws'],
#  ['', ''],
#  ['written', 'union members union tomorrow'],
#  ['', '8,129,000  Revs'],
#  ['', '188.8  mln'],
#  ['Shr  profit', '180.1 Shr mln'],
#  ['liquidity shortage liquidity it', 'liquidity shortage liquidity shortage'],
#  ['', ''],
#  ['Today  company', 'mln dlrs mln dlrs'],
#  ['', '41  Net'],
#  ['1986  Net', '88,946 loan loss dlrs'],
#  ['1,073,163  Company', '1,073,163  NOTE'],
#  ['', '23.0  mln'],
#  ['1986  figure', '2.4  pct'],
#  ['Canion   Canion We', 'personal  March'],
#  ['planned  purchase', 'financial service services'],
#  ['Shr  nil', 'vs nil 2,100,000'],
#  ['Congress', 'bill'],
#  ['year Oper shr net', 'tax credit dlr tax credit'],
#  ['term debt term matures', 'April'],
#  ['', '276,446  706,130'],
#  ['EC', '46.496 TONNES WHITE ECUS'],
#  ['European  he', 'economy'],
#  ['tonnes whites tonnes whites', '100 European Currency kilos'],
#  ['sales', 'first  quarter'],
#  ['Shr  profit', '7,929,138  3,849,224'],
#  ['61.9  Pay', '28  April'],
#  ['', 'Avg dlrs shrs'],
#  ['it', 'undisclosed Paxar terms'],
#  ['', '32  Net'],
#  ['current Canadian companies', 'current Canadian Erskine'],
#  ['also  it', 'Media   Country Media Group'],
#  ['', '29  Net'],
#  ['WOOLWORTH CO F.W. WOOLWORTH CO', '28 CTS A CTS'],
#  ['', '28  cts'],
#  ['allotted suger This', 'dairy  sugar'],
#  ['', ''],
#  ['100 Currency traders', '1,750 West tonnes'],
#  ['company reserves Parent company reserves', 'three billion three end-1985'],
#  ['', 'Avg dlrs 3,834,117'],
#  ['three health care company', 'three health care months'],
#  ['billion mln dlrs', 'accrual'],
#  ['', '67  cts'],
#  ['two  stock', 'August'],
#  ['10  Hanover', '30  April'],
#  ['it', 'Alarm Services Fargo Alarm Services'],
#  ['Full Pay name', '1/2 7 cts'],
#  ['Ministry', 'Agriculture economist Agriculture economist'],
#  ['completion', 'place'],
#  ['gallon contract barge company', '50 contract barge cts'],
#  ['wheat crop wheat which', 'previous  years'],
#  ['earlier end figure', 'end - end March'],
#  ['', ''],
#  ['February meeting February Italy', 'meaningful  decisions'],
#  ['funds rate funds rate', 'up 6 yesterdays'],
#  ['it', 'mln dlrs mln 1986'],
#  ['', '272.2  mln'],
#  ['common  Continental', 'common  shareholders'],
#  ['Shr loss Shr loss', '18.2743 Atlas year'],
#  ['patent suit patent suit', 'merit'],
#  ['Industrial Valley Industrial Valley',
#   'Financial Corp. IVB Financial Corp.'],
#  ['', '13  Net'],
#  ['U.S. economy U.S. economy', 'modest  growth'],
#  ['736,000 tax Net', '579,000 tax year'],
#  ['pension plan pension Company', 'August'],
#  ['', 'BURLINGTON RUMOR BURLINGTON RUMOR'],
#  ['', ''],
#  ['', ''],
#  ['', '30  cts'],
#  ['', '10  cts'],
#  ['', 'Avg 1.725 shrs'],
#  ['', 'eight  cts'],
#  ['mln dlrs mln Earnings', 'stock   stock March'],
#  ['it', 'textile   textile operations'],
#  ['SYSTEM REPURCHASES OVERNIGHT SYSTEM FED', ''],
#  ['defense contract U.S. defense contract', 'first  quarter'],
#  ['1986 mln qtr', 'tax rate tax rate'],
#  ['80 Ivory meeting', '80 Ivory output'],
#  ['when pct Fed', 'banking system banking system'],
#  ['14 hrs agent', 'hrs EDT hrs EDT'],
#  ['personnel costs personnel Morgan', 'personnel costs personnel costs'],
#  ['', '141.9 mln mln'],
#  ['television reports television which', 'outside  granaries'],
#  ['servicing portfolio mortgage servicing portfolio', 'dlrs   dlrs March'],
#  ['', '35  Net'],
#  ['shareholder meeting shareholder meeting', 'April'],
#  ['also  it', 'Envases'],
#  ['metal associations metal associations', 'White Metals White Metals'],
#  ['', 'nine  cts'],
#  ['stock Tradevest Tradevest', 'outstanding  Madeira'],
#  ['split', 'shareholders   shareholders record'],
#  ['40  company', '40  Montedison'],
#  ['31 merger it', 'merger   merger July'],
#  ['', 'ACQUIRE ALEXANDERS ACQUIRE ALEXANDERS'],
#  ['', '97  Net'],
#  ['statement', 'acquisition'],
#  ['trade sources trade sources', 'last  half'],
#  ['Shr  profit', 'loss carryforward tax loss carryforward'],
#  ['1  they', '150,000  March'],
#  ['1987  net', 'recapitalization plan recapitalization plan'],
#  ['Further E. Key details', 'Key   E. Key unit'],
#  ['', 'stock split stock split'],
#  ['', '95.4  mln'],
#  ['year Shr net', 'nine dlrs mths'],
#  ['when book publishing it', 'last CBS October'],
#  ['Stevens STN J.P. Stevens STN', '39 - 39 3/4'],
#  ['', 'Revs 1,022,00 Revs 344,000'],
#  ['', '746,000 Shr loss'],
#  ['U.S. firms U.S. firms', 'Japanese  market'],
#  ['it', 'fiber facilities textile fiber facilities'],
#  ['', '25  cts'],
#  ['GECs', 'closing   yesterdays closing 201p'],
#  ['it', 'improved  year'],
#  ['I', 'trade dispute trade dispute'],
#  ['', ''],
#  ['', 'Corp DCN Dana Corp DCN'],
#  ['more  he', 'more  market'],
#  ['', '1.05 Nine dlrs'],
#  ['', ''],
#  ['', 'Net Shr profit'],
#  ['half tax net', '2,051,000 dlr accounting'],
#  ['first mln Earnings', 'stock distribution stock June'],
#  ['TEXAS SERIES INCOME TEXAS Daily', '6.2 INCOME cts'],
#  ['good  bars', 'western  money'],
#  ['', 'qtr   qtr Pay'],
#  ['oil 1.5 products', '1.5 billion 1.5 dlrs'],
#  ['Turgut Ozal Turgut contents', 'message'],
#  ['Agency   Liability Agency It', 'details'],
#  ['2,400,000 Oper Net', 'six  year'],
#  ['negotiating group negotiating group', 'again meeting May.'],
#  ['505,000  Company', 'July'],
#  ['', '1/2 12 cts'],
#  ['outstanding  it', 'first corrects company paragraph'],
#  ['1.82 billion 1.82 Results', 'six cts mths'],
#  ['price rises oil price inflation', 'pct rate pct 1987'],
#  ['Siemens AG Siemens AG', 'responsive  pacemaker'],
#  ['he', 'other  details'],
#  ['morning', 'afternoon session afternoon session'],
#  ['mln bales mln which', 'years production years production'],
#  ['', '1,187,828 dlrs 1,223,511'],
#  ['', 'MLN DLRS MLN DLRS'],
#  ['indications', 'effect'],
#  ['third  gaming', 'earlier test gaming week'],
#  ['9.5 billion 9.5 that', 'April'],
#  ['offshore  communique', 'offshore  terminal'],
#  ['13.0 qtr Dividend', '30  holders'],
#  ['ministers', '1900  Treasury'],
#  ['requirement', 'years  disruptions'],
#  ['also  it', 'related  businesses'],
#  ['there  he', 'there  everybody'],
#  ['store   concept store which', 'ties'],
#  ['FEDS  HELLER', 'SUPPLY GROWTH MONEY SUPPLY GROWTH'],
#  ['', ''],
#  ['Iran', 'manpower training manpower training'],
#  ['American  producers', 'effectively  country'],
#  ['Prior 5.88 year', 'RCA Corp. RCA Corp.'],
#  ['also  It', 'natural  gas'],
#  ['blown  meeting', 'progress'],
#  ['panel', 'salmonella'],
#  ['Richard Henderson analyst Richard Henderson', 'also  delay'],
#  ['', '1/2 16 cts'],
#  ['Shr loss Shr loss', '1,751,884 Shr 151,884'],
#  ['CANADA', 'STEEL IMPORTS STEEL IMPORTS'],
#  ['products revenues products revenues', 'year systems RCAs'],
#  ['50  pct', 'Ltd CP Pacific Ltd CP'],
#  ['', '6,215,538  5,757,013'],
#  ['already  it', 'additional  liquidity'],
#  ['1987 Enhancement Program USDA', 'Program   Enhancement Program initiative'],
#  ['30 U.S. department', 'U.S. ports U.S. September'],
#  ['Caterpillars', 'material costs material costs'],
#  ['Christopher Moran investor Christopher who', 'year  Zondervan'],
#  ['21  Kiena', 'split'],
#  ['today  company', 'split  basis'],
#  ['agreement', 'definitive  financing'],
#  ['', '16.5  cts'],
#  ['South Africa South it', 'U.S. prices U.S. prices'],
#  ['July mln most', 'United States United States'],
#  ['it', 'find solutions find solutions'],
#  ['UALs stock UALs stock', 'air fares air industry'],
#  ['', 'eight mln mln'],
#  ['which', 'mln dlrs mln dlrs'],
#  ['', '23  cts'],
#  ['', '20  cts'],
#  ['DISTILLERS', 'AMERICAN BRANDS AMERICAN BRANDS'],
#  ['are', '24  May'],
#  ['product line cosmetic product line', 'mln dlrs mln revenue'],
#  ['shr loss Oper shr loss', '11 Oper shr year'],
#  ['spirits brands Nationals spirits brands', 'Gilbeys gin Gilbeys gin'],
#  ['quarter loss quarter loss', 'investors'],
#  ['1/2 product he', '1/2 product pct'],
#  ['mln dlrs mln Raybestos', 'braking applications braking applications'],
#  ['also  it', 'capital   capital deficit'],
#  ['U.S. lawmakers U.S. lawmakers', '2.4  pct'],
#  ['36  which', 'large  writeoffs'],
#  ['', 'mln mln NOTE'],
#  ['', '1.02 billion 1.02 billion'],
#  ['electric  powerplants', 'necessary  coal'],
#  ['also  it', 'Bancshares Corp. Popular Bancshares Corp.'],
#  ['late distance Williams', 'late distance 1988'],
#  ['1986  earnings', '702,000 subsidiary year'],
#  ['', '114.9 loss mln'],
#  ['May futures May futures', '107.90 New lb'],
#  ['1986  company', '16 mln share'],
#  ['', '56  Net'],
#  ['transactions', 'mln dlrs mln dlrs'],
#  ['EIA', 'STOCKS UNCHANGED DISTILLATE STOCKS 200,000'],
#  ['January agreement January agreement', 'department'],
#  ['mln barrels mln it', 'mln barrels mln 1,561.1'],
#  ['so  Hawkeye', 'requirements'],
#  ['', 'Colson Inc. Colson Inc.'],
#  ['it', 'time'],
#  ['3.08 mln it', '3.08 mln mln'],
#  ['Budget Committee Senate Budget Committee', 'spending cuts spending cuts'],
#  ['4th  qtr', '269.1 mln mln'],
#  ['', '0.63 avg pct'],
#  ['June shipment June Arango', 'June shipment June shipment'],
#  ['', 'stock split stock split'],
#  ['Thompson', 'gradual  sometime'],
#  ['rate policies interest rate Koehler',
#   'rate policies interest rate policies'],
#  ['640,400  persons', '8.5  work'],
#  ['it', 'exploration interests exploration Queensland'],
#  ['September Uruguay trade It', 'four  years'],
#  ['year  he', 'year  equipment'],
#  ['unusual utilities he', 'utilities markets utilities markets'],
#  ['present  progress', 'exchange rates exchange rates'],
#  ['others', '1/4  bank'],
#  ['', '614.4 PRETAX mln'],
#  ['mln 2.63 Interest', '49 equity October'],
#  ['', '79.6  mln'],
#  ['monetary time dealers', 'monetary time growth'],
#  ['price slump oil price which', 'currency earnings currency West'],
#  ['28.2  Companys', '28.2  mln'],
#  ['wheat aphids wheat aphids', 'mln wheat hectares'],
#  ['Metals activities Metals activities', 'net mln profit'],
#  ['35.99  yen', 'current Company year'],
#  ['export policy export they', 'export policy export policy'],
#  ['tax Pre profit', '105.9'],
#  ['full Note name', '2.29 2.20 billion'],
#  ['exchange   exchange rates', 'appropriate  levels'],
#  ['it', 'further  company'],
#  ['Full capital name', '2.50 capital 2.38'],
#  ['mln  shortfall', 'mln  dlrs'],
#  ['Commercial 6 banks', 'spot riyal spot 3.7507/09'],
#  ['confirmation', 'lead manager lead manager'],
#  ['companys profits companys profits', 'dropped  word'],
#  ['tonne cif tonne India', 'shipping period shipping period'],
#  ['first oil phase', 'oil town oil Kertih'],
#  ['Generale SGEN.PA Societe Generale SGEN.PA',
#   'Gobain SGEP.PA Gobain SGEP.PA'],
#  ['PLATINUM - PLATINUM 562', 'parentheses'],
#  ['Lex mln shares', '419p'],
#  ['buffer stock buffer stock', 'banks'],
#  ['still  Oldham', 'firm  value'],
#  ['Extraordinary minority items', '193.5 credit mln'],
#  ['', '1.25 BILLION 1.25 DLRS'],
#  ['full  name', 'company'],
#  ['February imports February imports', '9.86 billion 9.86 February'],
#  ['Bank', 'here  this'],
#  ['that', 'still  place'],
#  ['11/16 9 This', 'stg   stg shortfall'],
#  ['mln  guilders', 'aft'],
#  ['', ''],
#  ['central  banks', 'Paris accord Paris accord'],
#  ['billion  Holdings', '51 billion 51 April'],
#  ['tomorrow 50,000 details', '50,000   50,000 raws'],
#  ['U.S.   U.S. Japan', 'Japanese U.S. market'],
#  ['last payment series', '3.501 issue pct'],
#  ['dollar', 'trading range trading range'],
#  ['officials', 'Louvre meeting Louvre meeting'],
#  ['net  equity', '3.46 billion 3.46 billion'],
#  ['present  progress', 'exchange rates exchange rates'],
#  ['seven currency nations', 'James Baker Secretary James Baker'],
#  ['Trade   U.S. Trade figures', '14.8 billion 14.8 January'],
#  ['exchange   exchange rates', 'appropriate  levels'],
#  ['', 'five  cts'],
#  ['pct interest pct that', 'Corp HIA Holiday Corp HIA'],
#  ['dollar', 'three  months'],
#  ['1980/1985  average', 'down  390,500'],
#  ['warrants', '169,200  dlrs'],
#  ['acquisition', 'Orange Counties Orange areas'],
#  ['Bramall shares Bramall shares', 'lower  278p'],
#  ['gold price gold price', '100 2,045/2,070 grammes'],
#  ['FAOs forecast FAOs forecast', 'substantial world cereals China'],
#  ['19.4  Results', 'Camden   Camden January'],
#  ['1987  net', 'tax credit dlr tax credit'],
#  ['North America North company', 'statement'],
#  ['mln dlrs mln it', 'mln dlrs mln 1986'],
#  ['gold price gold price', '100 2,045/2,070 grammes'],
#  ['profit nil profit nil', '445,379 Shr 2,219,961'],
#  ['that', 'still  place'],
#  ['Todd', 'membership'],
#  ['available  That', 'down  2,480,000'],
#  ['J.P. INDUSTRIES SAYS J.P. INDUSTRIES', 'BUY COMPANY BUY COMPANY'],
#  ['mln dlrs mln Assets', 'mln dlrs mln dlrs'],
#  ['recent  most', 'United States United States'],
#  ['', '69  cts'],
#  ['1986 pct stock Dividend', 'May'],
#  ['export taxes export taxes', 'previous tonne brackets'],
#  ['it', 'financial Clevites results'],
#  ['present  yen', 'Paris accord Paris accord'],
#  ['TRADE SOURCES TRADE SOURCES', 'CANNING 0.56(0.361 CANNING 0.56(0.361'],
#  ['it', 'morning assistance stg morning assistance'],
#  ['it', 'director'],
#  ['full dlrs name', 'bank'],
#  ['morning  June', 'thin  conditions'],
#  ['', '89  1986'],
#  ['BUNDESBANK', 'PRESIDENT SCHLESINGER - PRESIDENT SCHLESINGER'],
#  ['13/16 9 This', 'deficit estimate deficit estimate'],
#  ['which', 'international  value'],
#  ['seven  Company', 'AG Brown BBC AG Cie'],
#  ['Soviet East charterers', 'dlrs daily dlrs daily'],
#  ['Cattle slaughter Cattle slaughter', '128,000  head'],
#  ['', ''],
#  ['SAO LUIZ SAO LUIZ', '4.4  MM'],
#  ['negotiations', 'still  Washington'],
#  ['GUAXUPE NIL GUAXUPE TRES', 'NIL'],
#  ['', 'COURIER EXPIRED PUROLATOR COURIER EXPIRED'],
#  ['de Mel de Mel', 'rupees balance rupees support'],
#  ['SAYS UNIT INC SAYS UNIT', 'PUROLATOR COURIER PUROLATOR COURIER'],
#  ['foreign Giovanni firms', 'bank'],
#  ['full mln name', '1985'],
#  ['67  Net', '74,123,837  73,374,398'],
#  ['February meeting February concept', 'recent currency years'],
#  ['when  it', 'pct rate pct January'],
#  ['however  adjustments', 'more  occasion'],
#  ['However pct employers', 'imbalance'],
#  ['board', 'payable stock May'],
#  ['Three cash months', '313  midsession'],
#  ['1987 pension results', 'Test Divisions System Test NEw'],
#  ['3,193,000  Share', 'stock split stock January'],
#  ['Bank Board Loan Bank Board', '5.00 104 pct'],
#  ['regulatory Anchor Waccamaw', 'mln dlrs mln March'],
#  ['really  dollar', 'current Paris levels'],
#  ['it', 'carload lots carload lots'],
#  ['tendering Purolator Hutton', 'tendering Purolator shareholders'],
#  ['ABBOTT', ''],
#  ['vigrously farm it', 'adequate farm quantities'],
#  ['futures contract cotton futures contract', '1,218 review decertification'],
#  ['Details', 'stockholders'],
#  ['', '865.0 1.00 mln'],
#  ['domestic  company', 'mln shares mln shares'],
#  ['Price details Price details', 'June shipment June shipment'],
#  ['tourism earnings Spains tourism earnings', 'mln dlrs mln February'],
#  ['India', 'edible  oils'],
#  ['John   chairman John acquisition', 'South   South Africa'],
#  ['rates', 'discount notes term discount notes'],
#  ['Mortgage Corp Loan Mortgage Corp', 'discount notes term discount notes'],
#  ['BELT TEMPERATURES GRAIN BELT TEMPERATURES', '12.00  GMT'],
#  ['1985  VW', 'three billion three marks'],
#  ['imports', 'import   import surcharges'],
#  ['', ''],
#  ['board', '32876 KG SALE'],
#  ['record date record company', 'record date record split'],
#  ['Period', '18,257,631 dlrs 17,376,480'],
#  ['abatement concern asbestos abatement LVI',
#   'abatement concern asbestos abatement June'],
#  ['preferred  dividend', 'share company August'],
#  ['mln dlrs Revs', '3.4  mln'],
#  ['Financial Baldwin Nisker terms', 'Nisker   Baldwin Nisker redistribution'],
#  ['four  directors', 'other  board'],
#  ['initital  dividend', 'first  1987'],
#  ['year growth it', 'mln dlrs mln dlrs'],
#  ['takeover bid takeover GenCorps', '130  dlrs'],
#  ['2,158,664  Company', '1,200,000   1,200,000 October'],
#  ['consecutive  quarters', 'earnings growth earnings growth'],
#  ['CHANCELLOR LAWSON U.K. CHANCELLOR LAWSON',
#   'INTEREST RATES INTEREST COUNTRIES'],
#  ['Ownership Plan Stock Ownership plan', 'pension plan pension plan'],
#  ['spot oil traders', 'spot oil markets'],
#  ['Bank Board Loan Bank Board', '5.00 OLD RATE pct'],
#  ['', '5,153,109  7,680,350'],
#  ['Yesterday 6 they', 'seven  close'],
#  ['one Packet Products unit', 'Current Specialty Foods division'],
#  ['works spending works Lawson', 'second package year'],
#  ['105,000 tonnes sources', '105,000 tonnes tonnes'],
#  ['committee', 'situation'],
#  ['G-10  G-10', 'Committee meeting Interim Committee today'],
#  ['it', 'Ontario plants Ontario August'],
#  ['12.54  traders', '12.54  kilo'],
#  ['Belgian 30.03/06 franc', '4.829/831  4.831/833'],
#  ['', '1.01  dlrs'],
#  ['Humana', 'earnings'],
#  ['', 'three  cts'],
#  ['FORD', '75 QTLY CTS'],
#  ['I', 'monetary  policy'],
#  ['', '65  cts'],
#  ['steel imports steel imports', 'last  year'],
#  ['', '268.8  mln'],
#  ['mln dlrs mln Abbott', 'mln dlrs mln dlrs'],
#  ['part bnls part bnls', 'top 167a round'],
#  ['trade sources trade it', 'trade sources trade sources'],
#  ['TREASURYS BAKER TREASURYS BAKER', 'TRADE'],
#  ['EC AUTHORISES EC AUTHORISES', '130 TONNES TRADE'],
#  ['EC AUTHORISES EC AUTHORISES', 'TONNES BARLEY TONNES BARLEY'],
#  ['FIRST QUARTER NABISCO FIRST QUARTER', 'DLR GAIN MLN DLR GAIN'],
#  ['one  source', 'eleven'],
#  ['23  dividend', 'operating period operating period'],
#  ['temporary export he', 'export earnings export earnings'],
#  ['business', 'Video   Ambrose Video Publishing'],
#  ['budget deficit budget deficit', 'trade deficit trade deficit'],
#  ['Forms Division Business Forms which',
#   'Forms Division Business Forms Division'],
#  ['5,931,324 nil Share', 'reverse  split'],
#  ['', '12.5 half mln'],
#  ['stock', 'six  months'],
#  ['2.21 liquor Income', '67 liquor share'],
#  ['orange output orange output', 'frost'],
#  ['feed wheat feed they', 'breadmaking'],
#  ['YORK DEALERS NEW YORK DEALERS', 'OPEN FED BUYING MARKET'],
#  ['157,941 Shr Revs', '858,624 Shr loss'],
#  ['primary  99ct', '1.81 billion 1.81 billion'],
#  ['it', 'investment purposes investment purposes'],
#  ['Major  reasons', 'decline'],
#  ['', 'eight  cts'],
#  ['dealer reports dealer dollar', 'just  midday'],
#  ['expenses', 'coupon debt coupon debt'],
#  ['net Oper excludes', 'depreciation expense depreciation expense'],
#  ['economic  currencies', 'economic  which'],
#  ['', '15.66 billion 15.66 billion'],
#  ['raw  Tate', 'raw  Silvertown'],
#  ['it', 'other  stock'],
#  ['', '38  cts'],
#  ['Other Beckman Corp drugs', 'GENE TPA GENE marketing'],
#  ['game operations amusement game operations', 'nine dlrs mths'],
#  ['', '20  cts'],
#  ['', '35  cts'],
#  ['', '1/2 21 cts'],
#  ['grain ships grain ships', 'Orleans elevators New Orleans elevators'],
#  ['unspecified tender conditions', 'tender offer tender offer'],
#  ['', '10.05 dlrs mln'],
#  ['next  it', 'next  year'],
#  ['', '67  cts'],
#  ['30  which', 'United States United States'],
#  ['trade sources trade sources', 'May shipment May shipment'],
#  ['', '5.08 billion 5.08 billion'],
#  ['planning department planning department', '1.5 billion 1.5 dlrs'],
#  ['8  they', '22 East Spain'],
#  ['sugar   sugar indications', '1 Reunion/1 c'],
#  ['17,000  hss', 'mt mt barley flour'],
#  ['1987 tax net', 'credit   tax credit goodwill'],
#  ['6,057,000  Net', '5,900,000 securities sales dlrs'],
#  ['oil reserves oil reserves', 'nine 4.7 pct'],
#  ['common  stock', '- rights ex - basis'],
#  ['planning department planning department', 'total  exports'],
#  ['stations', 'sale'],
#  ['756 4.8 MLN', '464 12.7 MLN'],
#  ['', 'MLN DLRS MLN DLRS'],
#  ['12,300  they', '12,300  September'],
#  ['Shr', 'Bancorp Inc Continental Bancorp January'],
#  ['831,398  Share', 'stock split stock May'],
#  ['', '35  cts'],
#  ['ago mln reserve', 'outstanding pct March'],
#  ['immediately grade price', 'carload quantities carload quantities'],
#  ['currency position currency position', 'mln dlrs mln dlrs'],
#  ['Shr', 'Previous  loss'],
#  ['1,600,258  Share', '1986 pct stock Mayaguez'],
#  ['', '4,618,232 dlrs 2,959,141'],
#  ['regulatory group Terms', 'regulatory group approvals'],
#  ['', '20 Class cts'],
#  ['1987  net', 'stock dividends stock dividends'],
#  ['it', 'Dillon Read Dillon Read'],
#  ['', 'Avg  shrs'],
#  ['capital operations sector capital operations', '56.9 billion 56.9 1985'],
#  ['', '27.4 Shr mln'],
#  ['mln dlrs mln he', 'mln dlrs mln result'],
#  ['', '6,300,000 Loan loss dlrs'],
#  ['However water filtration revenues', 'Cosentino   Louis Cosentino analysts'],
#  ['expansion', 'day Cape Spencer year'],
#  ['sugar growers sugar it', 'sugar industry sugar industry'],
#  ['BILLS AVERAGE BILLS AVERAGE', ''],
#  ['1,624,000 Nine Company', 'stock ownership stock ownership'],
#  ['six  holder', 'outstanding American shares'],
#  ['4.5 billion 4.5 which', 'companys'],
#  ['expansion', 'day Cape Spencer year'],
#  ['week day Tenders', 'day bills day bills'],
#  ['Council session Council session',
#   'coordination meeting Community coordination 1100'],
#  ['', '82,000  Sales'],
#  ['accounting   accounting results', 'mln dlrs mln dlrs'],
#  ['', '2.55 billion 2.55 billion'],
#  ['Shr', '19 tax share'],
#  ['price cut price cut', '51 heating cts'],
#  ['Mining Corp Newmont Mining it', '65.75 copper cents'],
#  ['', '14.35 billion 14.35 billion'],
#  ['', '5.14 billion 5.14 billion'],
#  ['qtr figures qtr figures', 'one carryforward share'],
#  ['trade reports trade government', 'original Islamic tender'],
#  ['stockpile   stockpile he', 'stockpile   stockpile management'],
#  ['car sales car it', 'trade figures trade figures'],
#  ['charge offs charge offs', 'mln dlrs mln dlrs'],
#  ['', '26.0 MLN MARCH'],
#  ['', '210 MLN TONNES MARCH'],
#  ['USDA - USDA U.S.', '610 MLN MLN'],
#  ['', ''],
#  ['JUICE YIELD ORANGE JUICE YIELD', 'FLORIDA CROP FLORIDA CROP'],
#  ['Operating dlrs net', 'loss carryforwards tax loss carryforwards'],
#  ['', ''],
#  ['Cake Exports Meal', 'month  6,036'],
#  ['departments estimates departments estimates', 'crop   crop conditions'],
#  ['estimates', '1986/87  April'],
#  ['Agriculture Department U.S. Agriculture Department',
#   'fourth Soviets agreement'],
#  ['ago  USDA', '261  acre'],
#  ['previously cwt department', 'cwt   cwt acre'],
#  ['Loan Program Storage Loan Program', 'Month Loan Nine Month Loan'],
#  ['debt restrictions debt restrictions', 'rights'],
#  ['grain imports grain imports', 'miscellaneous  grains'],
#  ['Note - Note Season', 'End Stocks End Stocks'],
#  ['month  USDA', '1.20  mln'],
#  ['USDA forecast USDA forecast', '9.58 grain mln'],
#  ['', 'FOR-1 SPLIT FOR-1 SPLIT'],
#  ['month  exports', '15.96  mln'],
#  ['month  USDA', '6.60 wheat mln'],
#  ['month  Exports', '17.71  mln'],
#  ['West   West Europe', 'thousand 29.4 1986/87'],
#  ['stockpile   stockpile he', 'stockpile   stockpile management'],
#  ['month  Exports', 'mln  27.62'],
#  ['1986/87 Residual projections', 'marketing loan marketing loan'],
#  ['month mln bales department', 'mln cotton bales'],
#  ['month  USDA', 'mln exports tonnes'],
#  ['29  it', 'One  May'],
#  ['National   National Beverage', 'mln dlrs mln dlrs'],
#  ['full  name', 'company'],
#  ['mln dlrs mln Fluorocarbon', 'mln dlrs mln dlrs'],
#  ['Current  qtr', 'sale   sale securities'],
#  ['mln  Avg', 'Avg shares Avg 11,200,000'],
#  ['', '35  Net'],
#  ['thousand  Prev', 'Sept - Sept Aug.'],
#  ['which', 'current  management'],
#  ['Moscow', 'mln tonnes mln 1986/87'],
#  ['it', '8  letter'],
#  ['TONNES WHEAT TONNES WHEAT', '1987/88  DELIVERY'],
#  ['Realty Income Health Realty Quarter', 'full  earnings'],
#  ['', 'six  cts'],
#  ['Telkon Corp. Telkon companies', 'electronic  merchandise'],
#  ['NOTE:1986 net NOTE:1986 net', '3rd qtr 3rd qtr'],
#  ['Overall Television Centel', 'seven  states'],
#  ['', '10  cts'],
#  ['Class B Class B', '1/2 1 cts'],
#  ['U.S. EXPORTERS U.S. EXPORTERS', 'SPLIT DELIVERY SPLIT DELIVERY'],
#  ['TONNES CORN TONNES CORN', '1986/87  DELIVERY'],
#  ['transit Note Rice', 'End Stocks End 21.19'],
#  ['lastest dlrs assets', '2.55 capital gain December'],
#  ['latest dlrs assets', 'preferred capital gain stock'],
#  ['14.55 14.55 14.55 Domes', 'Nil Nil Nil Nil Nil'],
#  ['marketing year marketing year', 'wheat'],
#  ['diligence investigations diligence company',
#   'diligence investigations diligence investigations'],
#  ['onwards  He', 'reporters'],
#  ['NIL NIL NIL Domes', 'End Stocks End Stocks'],
#  ['CCC stocks CCC purchases',
#   'Program initiative Enhancement Program December'],
#  ['BREAD WHEAT BREAD WHEAT', '1986  tonnes'],
#  ['entire  transaction', 'Central District Central District'],
#  ['which', 'United States United States'],
#  ['4.80 4.80 4.80 Domes', '5.06 5.06 5.10 5.06 Exports'],
#  ['13.48 13.48 13.48 Domes', '1985/86 EC-12 SOYBEAN 03/09/86'],
#  ['0.25 0.35 Domes', '0.07 0.12 0.07 0.07'],
#  ['22.25 pct it', '22.25 pct dlrs'],
#  ['Start Stocks Start Stocks', 'lbs bales lbs bales'],
#  ['1987 Enhancement Program department',
#   'Program   Enhancement Program initiative'],
#  ['NIL NIL NIL Domes', 'mln rice tonnes'],
#  ['yield   yield increase', 'box count box count'],
#  ['', '10  cts'],
#  ['stockpiled  Noranda', 'stockpiled  supplies'],
#  ['', '10  cts'],
#  ['', '15  cts'],
#  ['', ''],
#  ['federal  government', 'alternative pilot energy'],
#  ['eight grain ships ships', 'Merchants Exchange Portland Merchants Exchange'],
#  ['88  Shr', '154.5 2.55 mln'],
#  ['mln dlrs mln it', 'mln dlrs mln dlrs'],
#  ['loan data business loan data', '334.28 billion 334.28 billion'],
#  ['Average  borrowings', 'first mln period'],
#  ['Level VI Level VI', 'Y - Y CWT'],
#  ['Ill', 'ago  period'],
#  ['brokering service brokering service', 'substantially  markets'],
#  ['it', 'one  record'],
#  ['ago  Inventory', '75,985,696'],
#  ['28  National', 'home properties nursing home properties'],
#  ['its', '93 companys pct'],
#  ['offshore  hydrocarbons', 'commercial  quantities'],
#  ['1986  Patient', 'backlog   backlog orders'],
#  ['also  it', 'acquisition alternatives acquisition alternatives'],
#  ['', 'preferred Shr dividends'],
#  ['Isis', 'part'],
#  ['world price world price', '0.53 U.S. Adjustments'],
#  ['Sorghum sales Sorghum sales', 'main  buyers'],
#  ['30 TWO FED', 'TWO BILLION TWO MARCH'],
#  ['FED', 'MLN DLRS MLN APRIL'],
#  ['', 'TWO MLN APRIL'],
#  ['billion mln Danworth', 'operating  energy'],
#  ['', '306.8  Assets'],
#  ['', 'Revs  2,199,238'],
#  ['795,009 Shr Revs', '3,818,258  2,070,772'],
#  ['qtr   qtr Net', 'vs  year'],
#  ['second week they', 'two Friday days'],
#  ['stockpiled  Noranda', 'stockpiled  supplies'],
#  ['M-1', 'Reuters'],
#  ['it', 'operating units operating units'],
#  ['Communications Commission Communications Jacor',
#   'Communications Commission Communications Commission'],
#  ['purpose funds purpose funds', '63.8 billion 63.8 dlrs'],
#  ['over  It', 'sales'],
#  ['which', '1,518,700  soybeans'],
#  ['IT', 'INVESTOR GROUP INVESTOR GROUP'],
#  ['', 'five  cts'],
#  ['RATE SYSTEM EXCHANGE RATE SYSTEM', 'GREATER STABILITY GREATER STABILITY'],
#  ['netback values netback values', 'gasoline prices gasoline prices'],
#  ['key  he', 'key  variables'],
#  ['previous  field', 'southern  Louisiana'],
#  ['time  farmers', 'market animals market animals'],
#  ['export sources export sources', 'September shipments September shipments'],
#  ['accounting change accounting which', 'ago  1st'],
#  ['', ''],
#  ['', '25  Net'],
#  ['Full reduction name', 'reduction expenses reduction expenses'],
#  ['Atcor shares Atcor It', '191,400  shares'],
#  ['5,632,044 Oper Oper', 'operations   operations 49,040'],
#  ['only  I', 'time'],
#  ['Gabelli New York subsidiary', 'Stock Exchange Philadelphia Stock Exchange'],
#  ['asset sale asset partnership', 'Marcus Schloss Marcus Schloss'],
#  ['oper excludes oper excludes', 'discontinued pension plan 1,015,000'],
#  ['IT', 'ACQUISITION PROPOSALS ACQUISITION PROPOSALS'],
#  ['offers', 'further  details'],
#  ['', ''],
#  ['Inc INTF Systems Inc acquisition', 'Winterhalter share Winterhalter share'],
#  ['', '1,546,000 Shr profit'],
#  ['trade surplus trade surplus', 'mln dlrs mln dlrs'],
#  ['Fed', '6.10 funds rate pct'],
#  ['mln Shr Revs', 'tax   tax 51,294'],
#  ['Total  deposits', '17.18 billion 17.18 January'],
#  ['', 'YEN - YEN DEALERS'],
#  ['AT RECORD AT RECORD', ''],
#  ['York close New York Sterling', '1.6190/00  1.6195/05'],
#  ['institutional securities firms they', 'heavy  selling'],
#  ['Buenos Aires Buenos Millet', 'Buenos Aires Buenos Aires'],
#  ['bond market bond Giordano', 'bond market bond helmets'],
#  ['acceptance rates bankers acceptance rates', '60 term days'],
#  ['they', 'yen'],
#  ['only  sectors', 'Sydneys ports Sydneys ports'],
#  ['normal Balao spokesman', 'normal Balao levels'],
#  ['ago mln It', '353,045  tonnes'],
#  ['Domestic  supplies', 'origin oils origin oils'],
#  ['interest rates interest he', 'interest rates interest rates'],
#  ['it', 'company restructuring company restructuring'],
#  ['why explanation it', 'tariffs'],
#  ['property development property shares', 'beneficial Sdn owner'],
#  ['who', 'five  dependents'],
#  ['more  he', 'more  U.S.'],
#  ['trade sanctions trade it', 'trade sanctions trade Tokyo'],
#  ['last point SAMA', 'day paper day kingdom'],
#  ['growing  Uganda', 'more mln 1985/6'],
#  ['Industry Association Confectionery Industry Association', 'statement'],
#  ['dry production spell', 'actual  damage'],
#  ['21.5  figures', '21  workforce'],
#  ['social  that', 'Bloc states East Bloc states'],
#  ['BUYING DOLLARS ACTIVELY BUYING DOLLARS', 'TOKYO - TOKYO DEALERS'],
#  ['mln mln they', 'mln mln bales'],
#  ['real  ANZ', 'real  wages'],
#  ['Pty Ltd Australia Pty it', '2,160 Refinery Copper dlrs'],
#  ['142.30   142.30 It', '141.85  yen'],
#  ['Texacos assets Texacos assets', 'Pennzoil judgment Pennzoil judgment'],
#  ['Co Inc Co It', '4,540,000  time'],
#  ['when bonus Amax', 'local pct companies'],
#  ['highest  depreciation', 'U.S. Dollar U.S. Dollar'],
#  ['market price market group', 'dividend imputation dividend imputation'],
#  ['six 6 maturities', '6 6 pct'],
#  ['iron ore iron which', 'high  quality'],
#  ['it', '355,652  1985'],
#  ['components   components it', 'oil  trade'],
#  ['weak commodity he', 'commodity exports commodity exports'],
#  ['financial  details', 'debt restructuring Domes debt value'],
#  ['circulation', 'mln exchequer target'],
#  ['1986  inflation', 'pct rate pct rate'],
#  ['which', '0838  GMT'],
#  ['open  they', 'open  Frankfurt'],
#  ['Morgan shares Morgan shares', 'pence  Fridays'],
#  ['Operating mln credit profit', '0.1 Speciality mln'],
#  ['highest  rises', 'forest  industries'],
#  ['Kenyan  shilling', '16  shillings'],
#  ['wheat markets wheat markets', 'China'],
#  ['26p Norcros shares Williams', '785p'],
#  ['Comites actions Het Comites actions',
#   'Animal Feed European Animal Manufacturers'],
#  ['they', 'other  crops'],
#  ['German Confectionery Industry grindings', 'European  countries'],
#  ['ECU bond ECU bond', '490 exercise dlrs'],
#  ['18 trading Commonwealths', 'early pct February'],
#  ['0.9 mln proceeds', '0.5p Hepworth 227.5p'],
#  ['exploration  Bond', 'exploration  U.S.'],
#  ['they', '0.5  pct'],
#  ['Arrow shares Blue Arrow shares', 'lower  670'],
#  ['spot riyal spot riyal', '3.7498/7503'],
#  ['500  Platinum', 'highest  October'],
#  ['common Borg board', 'five share purchase right'],
#  ['price index input price index', 'pct drop pct February'],
#  ['Statoil', 'field'],
#  ['sale price sale price', 'flotation offer flotation April'],
#  ['more  it', 'more  competition'],
#  ['', 'six  months'],
#  ['Hillsdown shares Hillsdown shares', '266p'],
#  ['Turnover', 'Respiratory Far system'],
#  ['Common Toronto Stock stock', '25.00  1981'],
#  ['it', 'dollar purchases bank dollar purchases'],
#  ['LME Board LME Board', '1 T July'],
#  ['5/8  SAMA', 'day accounts day Kingdom'],
#  ['arrival whites June arrival they', 'arrival whites June arrival whites'],
#  ['central  bank', '11/16 9 pct'],
#  ['142.30   142.30 It', '141.85  yen'],
#  ['Peter Huggler Peter Huggler', 'recent Bank Switzerland'],
#  ['1/10 palm traders', '1/10 palm shipment'],
#  ['trade journal trade journal', '790.00 brand zinc tonne'],
#  ['few input Tinker', 'year oil index'],
#  ['pessimistic  He', 'world trade world trade'],
#  ['Fixed quarter investments', '1985 pct quarter'],
#  ['still  Washington', 'budget deficit budget deficit'],
#  ['braking effects braking effects', 'most  year'],
#  ['dlrs   dlrs Shr', '1.02  dlrs'],
#  ['owning', 'tender price tender price'],
#  ['', '32 half Net'],
#  ['Pretax mln profit', '12.6  mln'],
#  ['Other tape details', 'metropolitan tape area'],
#  ['possible  stock', 'friendly  inquiries'],
#  ['Thirty four Thirty workers', 'coal   coal mine'],
#  ['defence   defence spokesman', 'British  luxuries'],
#  ['budget compromise budget that', 'budget process budget process'],
#  ['financial  details', 'debt restructuring Domes debt value'],
#  ['approval process approval process', 'expiration date expiration date'],
#  ['Compact Video Compact Video', 'fiscal companys year'],
#  ['1986 Oper net', 'tax credit dlr tax credit'],
#  ['USAIR', 'PIEDMONT SHARES MLN PIEDMONT SHARES'],
#  ['import licences tea import licences', 'Reuters reports Reuters reports'],
#  ['economic  results', 'PSD   PSD policies'],
#  ['', ''],
#  ['one  dlr', '2.17 billion 2.17 billion'],
#  ['Corona warrants Corona warrants', 'C share series C Royex'],
#  ['South Atlantic South Atlantic', 'investment banks investment boards'],
#  ['Savings Home Association', 'Upper East Upper East'],
#  ['feeder steers feeder that', 'slaughter weight slaughter weight'],
#  ['Southwestern  producers', 'gas supply gas supply'],
#  ['pct  It', 'higher  pensions'],
#  ['IT', 'MLN DLRS MLN CASH'],
#  ['Shr  profit', '16,000 loss loss'],
#  ['', '1.10 billion 1.10 billion'],
#  ['it', '55  those'],
#  ['Great Britain Great he', 'manufactured percentage goods'],
#  ['Bank notes Bank notes', '941.5 mln mln'],
#  ['11/16 bank rates', 'intervention levels intervention levels'],
#  ['buyback   stock buyback that', 'debt'],
#  ['Cattle slaughter Cattle slaughter', '126,000  head'],
#  ['trade deficit trade deficit', '1.94 billion 1.94 February'],
#  ['trade surplus Japans trade surplus', '2.13 billion 2.13 March'],
#  ['it', 'May'],
#  ['', ''],
#  ['it', 'one mln one'],
#  ['', '30.0  mln'],
#  ['18.1  it', '18.1  1986'],
#  ['203,000  figures', 'Rotterdam traffic Rotterdam products'],
#  ['1986  net', 'share  property'],
#  ['1979/81 price inflation', 'oil prices oil prices'],
#  ['', 'Avg 1.12 shrs'],
#  ['pct  coffee', 'pct gas February'],
#  ['also  department', 'protein protein wheat premium'],
#  ['Bank Board Loan Bank Board', '275 OLD RATE days'],
#  ['six  months', 'tax   investment tax credits'],
#  ['24 1.2 It', 'New Hampshire New Hampshire'],
#  ['bottom core he', 'bottom core line'],
#  ['Colombia', 'calendar year calendar year'],
#  ['', 'RISE - DECEMBER RISE OFFICIAL'],
#  ['lower  ALP', '11.4  1986'],
#  ['Reebok', 'October'],
#  ['excludes', 'mln dlrs mln dlrs'],
#  ['353 mln This', '400 liquidity stg'],
#  ['gold ore gold ore', '0.1 sulphide ounce'],
#  ['service contracts term service agreement',
#   'Arrow shareholders Blue Arrow shareholders'],
#  ['board', 'May One May record'],
#  ['it', 'carload lots carload lots'],
#  ['', ''],
#  ['', '12 billion 12 billion'],
#  ['', 'stock distribution stock distribution'],
#  ['BILL AVERAGE BILL RATE', 'PCT - PCT OFFICIAL'],
#  ['', '29.5  mln'],
#  ['NVHomes LP NVHomes LP', 'two distribution unitholders'],
#  ['', ''],
#  ['DEPARTMENT STORES DILLARD DEPARTMENT STORES', 'DLRS CASH MLN DLRS CASH'],
#  ['', ''],
#  ['Trust Co U.S. Trust Co', '1/2 7 pct'],
#  ['offering', 'May.'],
#  ['federal  agency', '1.0  December'],
#  ['', '169,000 Investment securitiesd dollars'],
#  ['first 1.75 bank', 'same  period'],
#  ['21.85 pct it', 'unchanged pct 22.50'],
#  ['billion 1.04 dlrs', 'non Brazil accrual'],
#  ['1986 Program it', 'Program initiative Program initiative'],
#  ['54 Shr cts', 'shrs primary shrs 14,500,737'],
#  ['which', '600,000  tonnes'],
#  ['Shr', 'loss   loan loss provision'],
#  ['interested talks Commonwealth', '400  workers'],
#  ['', 'stock split stock May'],
#  ['25,000 medium they', '25,000 medium tonnes'],
#  ['which', '6 6 pct'],
#  ['Plymouth Shops Plymouth divisions', 'fiscal store 1985'],
#  ['it', 'U.S.'],
#  ['Period', '11,690,000 Shr 8,724,000'],
#  ['overseas  operations', 'future  growth'],
#  ['year Shr net', '1,977,000 tax half'],
#  ['insurance revenues insurance revenues', 'last mln years'],
#  ['11.1 profit Net', '2,557,000 tax year'],
#  ['1,533,273  Period', '1,533,273  half'],
#  ['', '2.6 Shr mln'],
#  ['Full dlrs name', 'mln dlrs NOTE'],
#  ['company spokesman company spokesman', 'further  investigation'],
#  ['more  he', 'more  U.S.'],
#  ['30  it', '30  pct'],
#  ['3rd qtr 3rd qtr', '260,000 loss carryforward dlrs'],
#  ['freight Jeddah freight traders', 'tonne cost tonne cost'],
#  ['', 'stock ownserhip stock ownserhip'],
#  ['Net', '553,000 loan loss dlrs'],
#  ['Kuwait', 'way United Arab Gulf'],
#  ['accruing  loans', '1.22 billion 1.22 end'],
#  ['first  quarter', '937,000  dlrs'],
#  ['public brokerage Kahn', 'brokerage offices brokerage offices'],
#  ['Period', 'tax provision dlr tax provision'],
#  ['', ''],
#  ['1,173,000 securities Company', 'December'],
#  ['', 'Avg  shrs'],
#  ['six  Share', 'stock split stock June'],
#  ['government approval government Swift',
#   'government approval government plant'],
#  ['cts  Shr', '1.80 billion 1.80 billion'],
#  ['Fed', 'so  dollar'],
#  ['', 'Avg  shrs'],
#  ['', '29.5  mln'],
#  ['', '32  Net'],
#  ['', '36  cts'],
#  ['', '6.9  cts'],
#  ['', '7.1  cts'],
#  ['board', '30  April'],
#  ['which', '100 AFG Industries dlr'],
#  ['Fund Fund Securities Fund Fund', '30 board record'],
#  ['previously  It', 'Warners stock Warners stock'],
#  ['Bank USA Westminster Bank USA', 'Bank PLC Westminster Bank PLC'],
#  ['', '4.5 Shr mln'],
#  ['', '1/2 54 cts'],
#  ['Buitonis consolidated Buitonis revenue', 'mln lire mln 1985'],
#  ['that', 'apartheid system apartheid system'],
#  ['acquisition', 'compatible cost reduction companies'],
#  ['mln dlrs mln Company', 'stock ownership stock December'],
#  ['REVLON GROUP REVLON GROUP', 'SHR CASH SHR CASH'],
#  ['which', '1/2 7 pct'],
#  ['more Crazy Adds', 'rights expiration rights expiration'],
#  ['', '22.6  Note'],
#  ['11.1  government', 'eight  pct'],
#  ['', 'share figures share figures'],
#  ['', ''],
#  ['Bar share Bar Resdel', 'Bar share Bar share'],
#  ['outstanding  acquisition', 'regulatory  approvals'],
#  ['31  company', 'common mln stock'],
#  ['Net Shr loss', 'Avg Shr 4,322,816'],
#  ['', '319.0 3.6 mln'],
#  ['', 'US SPRINT US SPRINT'],
#  ['VBI', '10.000 prices dlrs'],
#  ['', '73  Net'],
#  ['50  pct', 'Total Exploration Total S.A.'],
#  ['it', 'well  year'],
#  ['oper data oper data', 'six  mths'],
#  ['trade sources trade sources', 'June shipment June shipment'],
#  ['earlier mln provision', 'first loan 1986'],
#  ['', 'six 7 cts'],
#  ['Other  owners', '3.34 Prudential Insurance pct'],
#  ['', ''],
#  ['', '3,959,011  2,608,571'],
#  ['final time reporting', 'trade balance trade balance'],
#  ['lawsuits', 'original  offer'],
#  ['five Intermagnetics it', 'companys stock companys stock'],
#  ['', '31  4,078,000'],
#  ['Co subsidiary Electric Co Reliance', 'former  owner'],
#  ['year mln It', '1986 Arthurs revenues'],
#  ['Current  periods', 'shr figures shr splits'],
#  ['closing date closing date', 'Co Ltd Electric Co Ltd'],
#  ['Period', '12.2  9,214,000'],
#  ['also  it', 'Pierre three Schoenheimer'],
#  ['Amsouths assets Amsouths assets', 'mln dlrs mln dlrs'],
#  ['', '20.1  mln'],
#  ['Hadsons stock Hadsons Seaxe', 'Paris basin Paris France'],
#  ['companies', 'microcomputer software market microcomputer software'],
#  ['', '6.5  cts'],
#  ['', '6.6  cts'],
#  ['', '7.1  cts'],
#  ['', '6.1  cts'],
#  ['', '7.1  cts'],
#  ['', '6.5  cts'],
#  ['Dome   Current Dome shareholders', 'new  subsidiary'],
#  ['Per  results', 'dividend requirements dividend requirements'],
#  ['', 'loss carryforwards tax loss carryforwards'],
#  ['which', 'mln dlrs mln year'],
#  ['', '2,154,000 Shr profit'],
#  ['mln dlrs mln Revenues', 'billion telephone dlrs'],
#  ['Goodyears share Goodyears share', 'takeover   takeover bid'],
#  ['', 'ownership Aug stock ownership Aug'],
#  ['National Corp American National Corp', 'Chicago Corp. First Chicago Corp.'],
#  ['Astra voting stock', 'free  shares'],
#  ['Investment securities Investment securities',
#   'Corrects name Corrects parent'],
#  ['shr figures shr figures', 'April'],
#  ['Nor British Quests', '1200  area'],
#  ['three capital Marshall', 'three capital years'],
#  ['transition', 'network use network use'],
#  ['Contract terms Contract terms', 'Energy Board National Energy Board'],
#  ['company spokesman company spokesman', 'month  May'],
#  ['final time reporting', 'trade balance trade balance'],
#  ['it', 'Half International Robert Half International'],
#  ['mln dlrs mln Atlantic', 'mln dlrs mln dlrs'],
#  ['U.S. competitors U.S. competitors', 'mln dlrs mln 1986'],
#  ['', 'five  cts'],
#  ['government approval government Swift',
#   'government approval government plant'],
#  ['NASDAQ listing NASDAQ it', 'acquisition'],
#  ['', '714,670  Sales'],
#  ['Modern Mailers Modern Mailers', 'computer   computer service'],
#  ['Export guesses Export guesses', '16.4  mln'],
#  ['it', 'earnings'],
#  ['', ''],
#  ['mln dlrs mln purchase', 'undisclosed  cast'],
#  ['87 standards board Net', 'mln dlrs mln 1986'],
#  ['3,397,000  Company', 'February'],
#  ['', ''],
#  ['', '28.60 billion 28.60 billion'],
#  ['Per 9.27 results', 'preferred  dividends'],
#  ['stock split stock it', '24  record'],
#  ['Nine  mths', '2,543,711  2,453,520'],
#  ['', 'six  cts'],
#  ['Winchester', 'cigar market cigar market'],
#  ['', '7,277,340 Shr 1,378,372'],
#  ['Gander Mountain Gander Mountain', 'outdoor brand name catalogs'],
#  ['USTR official USTR official', 'EC regulation EC regulation'],
#  ['abate  it', 'policy'],
#  ['dividend', 'first  1987'],
#  ['mth net mth net', 'mining operations coal mining operations'],
#  ['working   working Ericsson', 'working   working Telefonica'],
#  ['outlook', 'year'],
#  ['net  profit', 'product prices product prices'],
#  ['major  product', 'New York New York'],
#  ['MCC shareholders MCC shareholders', '35 cash distribution share'],
#  ['', 'Avg  shrs'],
#  ['qtr figures qtr figures', 'FHLB borrowings FHLB borrowings'],
#  ['operating Sperry net', 'mln dlrs mln dlrs'],
#  ['whatsoever  he', 'impact'],
#  ['share impact share he', '1987  results'],
#  ['1986  net', 'manufacturing equipment manufacturing equipment'],
#  ['preferred A Empire share', 'holders option holders May'],
#  ...]

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
kg_df
# Out:
#                                            source                      target  \
# 0      Michael Smith Representative Michael Smith  week International dispute
# 1                                      government       further paper details
# 2                                    21 hour they         hour basis hour oil
# 3                                 seven  Products               57 export pct
# 4                       Indonesian export exports         bank   bank figures
# ...                                           ...                         ...
# 10783             morning operations morning bank                    500  mln
# 10784                                                                 25  cts
# 10785                                                                 12  cts
# 10786                                                        534,099 Shr loss
# 10787                                    cts  Shr                     49  cts
#
#           edge
# 0      [(won)]
# 1      [(won)]
# 2      [(won)]
# 3      [(won)]
# 4      [(won)]
# ...        ...
# 10783  [(won)]
# 10784  [(won)]
# 10785  [(won)]
# 10786  [(won)]
# 10787  [(won)]
#
# [10788 rows x 3 columns]

# %% [markdown]
# Next, we will use the networkx library to create a network from this dataframe. The nodes will represent the entities and the edges or connections between the nodes will represent the relations between the nodes.
# It is going to be a directed graph. In other words, the relation between any connected node pair is not two-way, it is only from one node to another.

# %%
# create a directed-graph from a dataframe
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %% [markdown]
# #### plot

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_64245/976178200.py in <module>
#       1 plt.figure(figsize=(12,12))
#       2
# ----> 3 pos = nx.spring_layout(G)
#       4 nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
#       5 plt.show()
#
# ~/.local/lib/python3.10/site-packages/networkx/utils/decorators.py in func(_argmap__wrapper, *args, **kwargs)
#     793
#     794             def func(*args, __wrapper=None, **kwargs):
# --> 795                 return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#     796
#     797         # standard function-wrapping stuff
#
# ~/.local/lib/python3.10/site-packages/networkx/utils/decorators.py in argmap_spring_layout_5(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#       2 from os.path import splitext
#       3 from contextlib import contextmanager
# ----> 4 from pathlib import Path
#       5 import warnings
#       6
#
# ~/.local/lib/python3.10/site-packages/networkx/drawing/layout.py in spring_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     479             nnodes, _ = A.shape
#     480             k = dom_size / np.sqrt(nnodes)
# --> 481         pos = _sparse_fruchterman_reingold(
#     482             A, k, pos_arr, fixed, iterations, threshold, dim, seed
#     483         )
#
# ~/.local/lib/python3.10/site-packages/networkx/utils/decorators.py in func(_argmap__wrapper, *args, **kwargs)
#     793
#     794             def func(*args, __wrapper=None, **kwargs):
# --> 795                 return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#     796
#     797         # standard function-wrapping stuff
#
# ~/.local/lib/python3.10/site-packages/networkx/utils/decorators.py in argmap__sparse_fruchterman_reingold_9(A, k, pos, fixed, iterations, threshold, dim, seed)
#       2 from os.path import splitext
#       3 from contextlib import contextmanager
# ----> 4 from pathlib import Path
#       5 import warnings
#       6
#
# ~/.local/lib/python3.10/site-packages/networkx/drawing/layout.py in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     620             distance = np.where(distance < 0.01, 0.01, distance)
#     621             # the adjacency matrix row
# --> 622             Ai = np.asarray(A.getrowview(i).toarray())
#     623             # displacement "force"
#     624             displacement[:, i] += (
#
# ~/.local/lib/python3.10/site-packages/scipy/sparse/lil.py in getrowview(self, i)
#     185         """Returns a view of the 'i'th row (without copying).
#     186         """
# --> 187         new = lil_matrix((1, self.shape[1]), dtype=self.dtype)
#     188         new.rows[0] = self.rows[i]
#     189         new.data[0] = self.data[i]
#
# ~/.local/lib/python3.10/site-packages/scipy/sparse/lil.py in __init__(self, arg1, shape, dtype, copy)
#     107                 M, N = arg1
#     108                 self._shape = check_shape((M, N))
# --> 109                 self.rows = np.empty((M,), dtype=object)
#     110                 self.data = np.empty((M,), dtype=object)
#     111                 for i in range(M):
#
# KeyboardInterrupt:

# %% [markdown]
# It turns out that we have created a graph with all the relations that we had. It becomes really hard to visualize a graph with these many relations or predicates.

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="composed by"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %% [markdown]
# That’s a much cleaner graph. Here the arrows point towards the composers. For instance, A.R. Rahman, who is a renowned music composer, has entities like “soundtrack score”, “film score”, and “music” connected to him in the graph above.
#
# Let’s check out a few more relations.
#
# Since writing is an important role in any movie, I would like to visualize the graph for the “written by” relation

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="written by"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_54206/1415773125.py in <module>
# ----> 1 G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="written by"], "source", "target",
#       2                           edge_attr=True, create_using=nx.MultiDiGraph())
#       3
#       4 plt.figure(figsize=(12,12))
#       5 pos = nx.spring_layout(G, k = 0.5)
#
# NameError: name 'kg_df' is not defined

# %% [markdown]
# This knowledge graph is giving us some extraordinary information. Guys like Javed Akhtar, Krishna Chaitanya, and Jaideep Sahni are all famous lyricists and this graph beautifully captures this relationship.
#
# Let’s see the knowledge graph of another important predicate, i.e., the “released in”

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="released in"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_54206/1339965172.py in <module>
# ----> 1 G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="released in"], "source", "target",
#       2                           edge_attr=True, create_using=nx.MultiDiGraph())
#       3
#       4 plt.figure(figsize=(12,12))
#       5 pos = nx.spring_layout(G, k = 0.5)
#
# NameError: name 'kg_df' is not defined

# %% [markdown]
# #### Resources
#
#
# https://www.analyticsvidhya.com/blog/2019/10/how-to-build-knowledge-graph-text-using-spacy/
